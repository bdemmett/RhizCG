# %% [markdown]
# # Relative abundance trace graphs

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(phyloseq)
# library(ggplot2)
# library(plyr); library(dplyr)
# library(RColorBrewer)
# library(gridExtra)
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning:
# Attaching package: ‘gridExtra’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# # Load data

# %%
# %%R
# log2foldFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/DeSeq2/bare-plant.csv'
#
# # use non-rarified relative abundance phylogseq object for consistency with DeSeq
# F = file.path('/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/physeq/Full-Sparsity3in3_relabund')
#
# physeq.Full = readRDS(F)
# physeq.Full = filter_taxa(physeq.Full, function(x) sum(x > 0) > 0, TRUE)

# %% [markdown]
# #  Bare soils by time graph

# %%
# %%R
# physeq.Bare = subset_samples(physeq.Full, Type == "BARE", TRUE)
# mdf = psmelt(physeq.Bare)
# physeq.Bare = NULL
# head(mdf)
# Out:
#           OTU            Sample  Abundance          X.sample Library
# 34714  OTU.12 sample8-3.07_Npos 0.02789850 sample8-3.07_Npos       2
# 246137  OTU.6 sample8-3.07_Npos 0.02523482 sample8-3.07_Npos       2
# 246087  OTU.6 sample6-2.05_Npos 0.02493613 sample6-2.05_Npos       2
# 246118  OTU.6 sample2-2.05_Npos 0.02408155 sample2-2.05_Npos       1
# 246142  OTU.6 sample8-2.05_Npos 0.02323952 sample8-2.05_Npos       2
# 246109  OTU.6 sample4-1.06_Npos 0.02293637 sample4-1.06_Npos       2
#        Primer_Plate Primer_Well_ID primerFR_ID_byPlate primerFR_ID_total
# 34714             1             F7                  54                54
# 246137            1             F7                  54                54
# 246087            1             F1                   6                 6
# 246118            1            B10                  74                74
# 246142            1             D7                  52                52
# 246109            1             E1                   5                 5
#        barcode_ID    PlotID Plant Plot Treatment Rep DAP Sampling  PlantSample
# 34714          54 3.07_Npos  BARE 3.07      Npos   3  88  sample8 BARE_sample8
# 246137         54 3.07_Npos  BARE 3.07      Npos   3  88  sample8 BARE_sample8
# 246087          6 2.05_Npos  BARE 2.05      Npos   2  79  sample6 BARE_sample6
# 246118         74 2.05_Npos  BARE 2.05      Npos   2  53  sample2 BARE_sample2
# 246142         52 2.05_Npos  BARE 2.05      Npos   2  88  sample8 BARE_sample8
# 246109          5 1.06_Npos  BARE 1.06      Npos   1  61  sample4 BARE_sample4
#        Type Grass_Broad    Status Subfamily fwd_barcode rev_barcode Planted
# 34714  BARE   Bare_Soil Bare_Soil      <NA>    CGTGAGTG    GGAGACTA    BARE
# 246137 BARE   Bare_Soil Bare_Soil      <NA>    CGTGAGTG    GGAGACTA    BARE
# 246087 BARE   Bare_Soil Bare_Soil      <NA>    CGTGAGTG    AACTCTCG    BARE
# 246118 BARE   Bare_Soil Bare_Soil      <NA>    ACTATCTG    TAGCAGAC    BARE
# 246142 BARE   Bare_Soil Bare_Soil      <NA>    CTGCGTGT    GGAGACTA    BARE
# 246109 BARE   Bare_Soil Bare_Soil      <NA>    TCATCGAG    AACTCTCG    BARE
#        Biomass_P SLA Leaf_N Leaf_C LeafC_N LNa Plant_N Plant_C Plant_CN d15N
# 34714         NA  NA     NA     NA      NA  NA      NA      NA       NA   NA
# 246137        NA  NA     NA     NA      NA  NA      NA      NA       NA   NA
# 246087        NA  NA     NA     NA      NA  NA      NA      NA       NA   NA
# 246118        NA  NA     NA     NA      NA  NA      NA      NA       NA   NA
# 246142        NA  NA     NA     NA      NA  NA      NA      NA       NA   NA
# 246109        NA  NA     NA     NA      NA  NA      NA      NA       NA   NA
#        tN_p BX_activity_g CB_activity_g LAP_activity_g NAG_activity_g    BX_rel
# 34714    NA      9.738044      9.090855       123.8981       7.541973 0.7976818
# 246137   NA      9.738044      9.090855       123.8981       7.541973 0.7976818
# 246087   NA     20.509199     16.763494       180.9449      11.743008 1.1718093
# 246118   NA     17.209035     16.774864       129.7699       8.901158 1.1512941
# 246142   NA     13.693715     12.028220       135.4462      10.226966 1.1217065
# 246109   NA     13.221197     12.735309       144.3746       9.985836 1.0527823
#           CB_rel   LAP_rel   NAG_rel NO3_ug_g NH4_ug_g InorganicN Resid_logB
# 34714  0.7809623 0.9827892 0.7606637       NA       NA         NA         NA
# 246137 0.7809623 0.9827892 0.7606637       NA       NA         NA         NA
# 246087 1.1999667 1.0551246 1.0948644 18.14535 4.329916   22.47527         NA
# 246118 1.0994550 1.0648465 1.0507737 29.19341 6.858501   36.05191         NA
# 246142 1.0333007 1.0743917 1.0314652       NA       NA         NA         NA
# 246109 0.9693180 0.9861565 0.8755359 20.63496 4.193225   24.82819         NA
#        Resid_logN Resid_logCN Resid_logSLA Resid_LeafN A_Resid_logB
# 34714          NA          NA           NA          NA           NA
# 246137         NA          NA           NA          NA           NA
# 246087         NA          NA           NA          NA           NA
# 246118         NA          NA           NA          NA           NA
# 246142         NA          NA           NA          NA           NA
# 246109         NA          NA           NA          NA           NA
#        A_Resid_logN A_Resid_logCN M_Resid_logB M_Resid_logN M_Resid_logCN
# 34714            NA            NA           NA           NA            NA
# 246137           NA            NA           NA           NA            NA
# 246087           NA            NA           NA           NA            NA
# 246118           NA            NA           NA           NA            NA
# 246142           NA            NA           NA           NA            NA
# 246109           NA            NA           NA           NA            NA
#           Rank1                  Rank2                Rank3
# 34714  Bacteria Candidate_division_WS3 uncultured_bacterium
# 246137 Bacteria         Actinobacteria            MB-A2-108
# 246087 Bacteria         Actinobacteria            MB-A2-108
# 246118 Bacteria         Actinobacteria            MB-A2-108
# 246142 Bacteria         Actinobacteria            MB-A2-108
# 246109 Bacteria         Actinobacteria            MB-A2-108
#                       Rank4 Rank5 Rank6 Rank7 Rank8
# 34714                  <NA>  <NA>  <NA>  <NA>  <NA>
# 246137 uncultured_bacterium  <NA>  <NA>  <NA>  <NA>
# 246087 uncultured_bacterium  <NA>  <NA>  <NA>  <NA>
# 246118 uncultured_bacterium  <NA>  <NA>  <NA>  <NA>
# 246142 uncultured_bacterium  <NA>  <NA>  <NA>  <NA>
# 246109 uncultured_bacterium  <NA>  <NA>  <NA>  <NA>

# %%
# %%R
# # split dataframe by day and OTU, sumarize mean abundance
# mdf.byday = ddply(mdf, .(DAP, OTU), summarize, mean_day_abundance = mean(Abundance))
# head(mdf.byday)
# Out:
#   DAP       OTU mean_day_abundance
# 1  36    OTU.10       1.881108e-03
# 2  36   OTU.100       2.943948e-03
# 3  36  OTU.1000       5.313401e-05
# 4  36 OTU.10004       1.019494e-04
# 5  36 OTU.10009       2.386498e-06
# 6  36  OTU.1001       0.000000e+00

# %%
# %%R
# #Order by day, then rank abundance within day
# mdf.byday = mdf.byday[order( mdf.byday$DAP, -mdf.byday$mean_day_abundance),]
# #Subset to first bulk soil day
# mdf.36 = subset(mdf.byday, DAP == 36)
#
# mdf.36$Rank = rank(-mdf.36$mean_day_abundance, ties.method = "random")
# mdf.byday.ranked = join(mdf.byday, mdf.36[,c("OTU","Rank")], by = "OTU")
#
# head(mdf.byday.ranked)
# Out:
#   DAP    OTU mean_day_abundance Rank
# 1  36  OTU.6        0.017623251    1
# 2  36 OTU.28        0.011306851    2
# 3  36 OTU.11        0.009433516    3
# 4  36 OTU.12        0.008705002    4
# 5  36 OTU.47        0.008015766    5
# 6  36 OTU.13        0.007286370    6

# %%
# %%R
# FDR = 0.05
#
# # read rhizosphere log2fold change file and
# l2f = read.csv(log2foldFile, header = TRUE)
#
# df.l2fc.rspndr = l2f %>%
#     group_by(OTU) %>%
#      summarize(minP = min(p.adj)) %>%
#      filter(minP <= FDR)

# %%
# %%R
# head(df.l2fc.rspndr)
# Out:
# # A tibble: 6 × 2
#         OTU         minP
#      <fctr>        <dbl>
# 1    OTU.10 4.845532e-48
# 2   OTU.100 5.591617e-04
# 3  OTU.1000 4.432166e-03
# 4 OTU.10009 7.550763e-06
# 5  OTU.1001 5.877994e-04
# 6 OTU.10030 5.634186e-08

# %%
# %%R
#
# d.rhiz = left_join(df.l2fc.rspndr, mdf.byday.ranked)
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: Joining, by = "OTU"
#
#   warnings.warn(x, RRuntimeWarning)

# %%
# %%R -w 600 -h 350
# getPalette = colorRampPalette(brewer.pal(8, "Set1"))
#
# p = ggplot(mdf.byday.ranked, aes(x = Rank, y = mean_day_abundance, color = factor(DAP)))
#
# #p = p + geom_vline(data = d.rhiz, aes(xintercept = Rank), color = "#377eb8", alpha = 0.25, size = 1)
# #p = p + geom_vline(data = d.xyl, aes(xintercept = Rank), color = "#4daf4a", alpha = 0.25, size = 1)
#
# p = p + geom_line(alpha = 0.5, size = 0.5)
#
# #p = p + geom_rug(data = d.cell, color = "black", sides = "b", size = 1.25)
# p = p + geom_rug(data = d.rhiz, color = "black", sides = "t", size = 1.25)
#
# p = p + geom_line(data = subset(mdf.byday.ranked, DAP == 36), size = 2)
#
# p = p + scale_color_manual(values=getPalette(8))
#
# p = p + scale_y_log10()
#
# p = p + scale_x_log10()
#
# p = p + theme_bw()
#
# p = p + labs(x = "Day 36 Rank", y = "Relative Abundance", color = "Day")
#
# p1 = p
# p1

# %%
# Now rhizosphere plots

# %%
# %%R
# physeq.Plant = subset_samples(physeq.Full, DAP == 84 | DAP == 36 & Plant == "BARE" , TRUE)
#
# mdf = psmelt(physeq.Plant)
# physeq.Plant = NULL

# %%
# %%R
# # split dataframe by day and OTU, sumarize mean abundance
# mdf.byday.byplant = ddply(mdf, .(DAP, Plant, OTU), summarize, mean_day_abundance = mean(Abundance))
# head(mdf.byday.byplant)
# Out:
#   DAP Plant       OTU mean_day_abundance
# 1  36  BARE    OTU.10       1.881108e-03
# 2  36  BARE   OTU.100       2.943948e-03
# 3  36  BARE  OTU.1000       5.313401e-05
# 4  36  BARE OTU.10004       1.019494e-04
# 5  36  BARE OTU.10009       2.386498e-06
# 6  36  BARE  OTU.1001       0.000000e+00

# %%
# %%R
# #Order by day, then rank abundance within day
# mdf.byday.byplant = mdf.byday.byplant[order( mdf.byday.byplant$DAP, -mdf.byday.byplant$mean_day_abundance),]
# #Subset to first bulk soil day
# mdf.36 = subset(mdf.byday.byplant, DAP == 36 & Plant == "BARE")
#
# mdf.36$Rank = rank(-mdf.36$mean_day_abundance, ties.method = "random")
# mdf.byday.byplant.ranked = join(mdf.byday.byplant, mdf.36[,c("OTU","Rank")], by = "OTU")
#
# head(mdf.byday.byplant.ranked)
# Out:
#   DAP Plant    OTU mean_day_abundance Rank
# 1  36  BARE  OTU.6        0.017623251    1
# 2  36  BARE OTU.28        0.011306851    2
# 3  36  BARE OTU.11        0.009433516    3
# 4  36  BARE OTU.12        0.008705002    4
# 5  36  BARE OTU.47        0.008015766    5
# 6  36  BARE OTU.13        0.007286370    6

# %%
# %%R
# FDR = 0.05
#
# # read rhizosphere log2fold change file and
# l2f = read.csv(log2foldFile, header = TRUE)
#
# df.l2fc.rspndr = l2f %>%
#     filter(Day == 84 & log2FoldChange > 0) %>%
#     group_by(OTU) %>%
#      summarize(minP = min(p.adj)) %>%
#      filter(minP <= FDR)

# %%
# %%R
# head(df.l2fc.rspndr)
# Out:
# # A tibble: 6 × 2
#         OTU         minP
#      <fctr>        <dbl>
# 1    OTU.10 9.458241e-20
# 2   OTU.101 1.822706e-03
# 3  OTU.1010 4.076361e-02
# 4  OTU.1016 2.854686e-03
# 5 OTU.10219 1.004318e-02
# 6 OTU.10249 1.877634e-02

# %%
# %%R
#
# d.rhiz = left_join(df.l2fc.rspndr, mdf.byday.byplant.ranked)

# %%
# %%R
# mdf.byday.byplant.ranked$Plant_Day = paste(mdf.byday.byplant.ranked$Plant, mdf.byday.byplant.ranked$DAP, sep = "-")

# %%
# %%R -w 1000 -h 350
#
# getPalette = colorRampPalette(brewer.pal(5, "Set1"))
#
# p = ggplot(mdf.byday.byplant.ranked, aes(x = Rank, y = mean_day_abundance, color = Plant_Day))
#
# #p = p + geom_vline(data = d.rhiz, aes(xintercept = Rank), color = "#377eb8", alpha = 0.25, size = 1)
# #p = p + geom_vline(data = d.xyl, aes(xintercept = Rank), color = "#4daf4a", alpha = 0.25, size = 1)
#
# p = p + geom_line(alpha = 0.5, size = 0.8)
#
# #p = p + geom_rug(data = d.cell, color = "black", sides = "b", size = 1.25)
# p = p + geom_rug(data = d.rhiz, color = "black", sides = "t", size = .5)
#
# p = p + geom_line(data = subset(mdf.byday.byplant.ranked, DAP == 36), size = 2)
# p = p + geom_line(data = subset(mdf.byday.byplant.ranked, DAP == 84 & Plant == "BARE"), alpha = .5, size = 1.2)
#
# p = p + scale_color_manual(values=getPalette(5))
#
# p = p + scale_y_log10()
#
# p = p + scale_x_log10()
#
# p = p + theme_bw()
#
# p = p + labs(x = "Day 36 Bare Soil Rank", y = "Relative Abundance", color = "Day")
#
# p3 = p

# %%
# %%R
# p3

# %%
## format for

# %%
# %%R
# grid.arrange(p1,p3,p2, ncol = 1)

# %%
# %%R -w 1000 -h 400
# p2

# %% [markdown]
# # by day Rhizosphere samples and bulk 36

# %%
# %%R
# physeq.Plant = subset_samples(physeq.Full, Planted == "Rhizosphere" | DAP == 36 & Plant == "BARE" , TRUE)
#
# mdf = psmelt(physeq.Plant)
# physeq.Plant = NULL

# %%
# %%R
# head(mdf)
# Out:
#           OTU            Sample Abundance          X.sample Library
# 821181 OTU.84 sample3-3.30_Npos 0.2773169 sample3-3.30_Npos       2
# 271824 OTU.20 sample2-2.10_Nneg 0.2432191 sample2-2.10_Nneg       2
# 271887 OTU.20 sample2-1.08_Nneg 0.1414608 sample2-1.08_Nneg       1
# 747536  OTU.7 sample5-3.17_Nneg 0.1369265 sample5-3.17_Nneg       1
# 452845  OTU.3 sample5-3.13_Nneg 0.1360758 sample5-3.13_Nneg       1
# 578452  OTU.4 sample3-4.18_Nneg 0.1355695 sample3-4.18_Nneg       2
#        Primer_Plate Primer_Well_ID primerFR_ID_byPlate primerFR_ID_total
# 821181            1            E12                  93                93
# 271824            1             A2                   9                 9
# 271887            1             A7                  49                49
# 747536            1             E2                  13                13
# 452845            2             E1                   5               101
# 578452            1             A3                  17                17
#        barcode_ID    PlotID Plant Plot Treatment Rep DAP Sampling   PlantSample
# 821181         93 3.30_Npos ABUTH 3.30      Npos   3  57  sample3 ABUTH_sample3
# 271824          9 2.10_Nneg ECHCG 2.10      Nneg   2  53  sample2 ECHCG_sample2
# 271887         49 1.08_Nneg AMAPO 1.08      Nneg   1  53  sample2 AMAPO_sample2
# 747536         13 3.17_Nneg Il14H 3.17      Nneg   3  72  sample5 Il14H_sample5
# 452845        101 3.13_Nneg  MS71 3.13      Nneg   3  72  sample5  MS71_sample5
# 578452         17 4.18_Nneg ABUTH 4.18      Nneg   4  57  sample3 ABUTH_sample3
#             Type Grass_Broad Status Subfamily fwd_barcode rev_barcode
# 821181 Dicot-Myc       Dicot   Weed      <NA>    TCATCGAG    TCGCTATA
# 271824  C4_Grass     Monocot   Weed  Paniceae    ATCGTACG    ACTATGTC
# 271887  Dicot-NM       Dicot   Weed      <NA>    ATCGTACG    GGAGACTA
# 747536     Maize     Monocot   Crop  Paniceae    TCATCGAG    ACTATGTC
# 452845     Maize     Monocot   Crop  Paniceae    ACGTCTCG    AACTCTCG
# 578452 Dicot-Myc       Dicot   Weed      <NA>    ATCGTACG    AGTAGCGT
#            Planted Biomass_P      SLA   Leaf_N   Leaf_C   LeafC_N         LNa
# 821181 Rhizosphere   39.7700 153.1536 4.574450 42.95550  9.390576 0.000298684
# 271824 Rhizosphere   30.3725 200.1681 4.329409 47.27514 10.920300 0.000216289
# 271887 Rhizosphere   50.3425 157.0701 3.958750 40.55850 10.245861 0.000252037
# 747536 Rhizosphere   68.9500       NA       NA       NA        NA          NA
# 452845 Rhizosphere  134.3000 133.5175 2.448400 46.32800 18.923491 0.000183377
# 578452 Rhizosphere   41.9550 169.6809 4.554700 43.63950  9.581383 0.000268427
#         Plant_N  Plant_C Plant_CN   d15N      tN_p BX_activity_g CB_activity_g
# 821181 2.892197 40.98441 14.17076 11.090 1.1502269      34.18699      32.36006
# 271824 2.541865 41.49796 16.32575  9.930 0.7720279      23.41488      26.68962
# 271887 2.889765 38.99108 13.49282  5.360 1.4547797      32.96834      30.86420
# 747536 1.345475 44.27391 32.90579  5.180 0.9277048      15.44548      14.61428
# 452845 1.629188 43.91659 26.95630  4.125 2.1880001      16.80066      18.47709
# 578452 2.976931 40.64505 13.65334  2.630 1.2489713      13.21742      14.42999
#        LAP_activity_g NAG_activity_g   BX_rel   CB_rel   LAP_rel   NAG_rel
# 821181      160.67846      23.394453 3.266483 2.521899 1.4845552 2.6864813
# 271824      131.35723       8.226534 1.592345 1.818391 1.0962045 0.9317485
# 271887      144.20762      10.567817 2.242035 2.102809 1.2034438 1.1969255
# 747536       95.66032      15.231145 1.106648 1.151823 0.8849253 1.4888939
# 452845      119.23155      12.708625 1.203744 1.456270 1.1029758 1.2423093
# 578452       81.45153      14.897496 1.186719 1.066820 0.7730427 1.5534363
#          NO3_ug_g NH4_ug_g InorganicN Resid_logB Resid_logN Resid_logCN
# 821181 13.4000199 9.648024  23.048044  0.1072261  0.3061423 -0.18640388
# 271824  1.7734351 5.020633   6.794068  0.1642339  0.1510643  0.04301182
# 271887  0.9965788 4.792906   5.789485  0.6695460  0.7846533 -0.14757390
# 747536         NA       NA         NA -0.2564646 -0.5322772  0.32661461
# 452845  8.6430615 6.748484  15.391546  0.4102299  0.3257525  0.12718284
# 578452 15.6586661 7.182228  22.840894  0.1607109  0.3885033 -0.22360034
#        Resid_logSLA Resid_LeafN A_Resid_logB A_Resid_logN A_Resid_logCN
# 821181  -0.12254012   0.6542724   0.01732470   0.09938886   -0.07588932
# 271824   0.12084259   0.2035473   0.07518489  -0.06017185    0.15892692
# 271887  -0.12162279  -0.1671116   0.58049694   0.57341718   -0.03165880
# 747536           NA          NA  -0.43140141  -0.80023305    0.41687718
# 452845  -0.16849932  -0.7004628   0.23529309   0.05779662    0.21744541
# 578452  -0.02006217   0.6345224   0.07080946   0.18174987   -0.11308577
#        M_Resid_logB M_Resid_logN M_Resid_logCN    Rank1          Rank2
# 821181    0.2634676    0.7055075   -0.30606673 Bacteria     Firmicutes
# 271824    0.3187212    0.5389987   -0.08188216 Bacteria     Firmicutes
# 271887    0.8240333    1.1725877   -0.27246787 Bacteria     Firmicutes
# 747536   -0.1071357   -0.2018547    0.22656850 Bacteria Proteobacteria
# 452845    0.5595588    0.6561749    0.02713673 Bacteria Actinobacteria
# 578452    0.3169524    0.7878685   -0.34326319 Bacteria Proteobacteria
#                     Rank3             Rank4            Rank5      Rank6
# 821181            Bacilli        Bacillales      Bacillaceae   Bacillus
# 271824            Bacilli        Bacillales      Bacillaceae   Bacillus
# 271887            Bacilli        Bacillales      Bacillaceae   Bacillus
# 747536 Betaproteobacteria   Burkholderiales   Comamonadaceae uncultured
# 452845   Streptomycetales Streptomycetaceae     Streptomyces       <NA>
# 578452 Betaproteobacteria   Burkholderiales Oxalobacteraceae       <NA>
#                      Rank7 Rank8
# 821181     Bacillus_cereus  <NA>
# 271824 Bacillus_megaterium  <NA>
# 271887 Bacillus_megaterium  <NA>
# 747536                <NA>  <NA>
# 452845                <NA>  <NA>
# 578452                <NA>  <NA>

# %%
# %%R
# # split dataframe by day and OTU, sumarize mean abundance
# mdf.byday = ddply(mdf, .(DAP, Planted, OTU), summarize, mean_day_abundance = mean(Abundance))
# head(mdf.byday)
# Out:
#   DAP Planted       OTU mean_day_abundance
# 1  36    BARE    OTU.10       1.881108e-03
# 2  36    BARE   OTU.100       2.943948e-03
# 3  36    BARE  OTU.1000       5.313401e-05
# 4  36    BARE OTU.10004       1.019494e-04
# 5  36    BARE OTU.10009       2.386498e-06
# 6  36    BARE  OTU.1001       0.000000e+00

# %%
# %%R
# #Order by day, then rank abundance within day
# mdf.byday = mdf.byday[order( mdf.byday$DAP, -mdf.byday$mean_day_abundance),]
# #Subset to first bulk soil day
# mdf.36 = subset(mdf.byday, DAP == 36 & Planted == "BARE")
#
# mdf.36$Rank = rank(-mdf.36$mean_day_abundance, ties.method = "random")
# mdf.byday.ranked = join(mdf.byday, mdf.36[,c("OTU","Rank")], by = "OTU")
#
# head(mdf.byday.ranked)
# Out:
#   DAP     Planted    OTU mean_day_abundance Rank
# 1  36 Rhizosphere  OTU.8        0.020629371  547
# 2  36        BARE  OTU.6        0.017623251    1
# 3  36 Rhizosphere  OTU.4        0.012971579  274
# 4  36        BARE OTU.28        0.011306851    2
# 5  36 Rhizosphere OTU.11        0.010989811    3
# 6  36        BARE OTU.11        0.009433516    3

# %%
# %%R
# FDR = 0.05
#
# # read rhizosphere log2fold change file and
# l2f = read.csv(log2foldFile, header = TRUE)
#
# df.l2fc.rspndr = l2f %>%
#     filter(Day == 84 & log2FoldChange > 0) %>%
#     group_by(OTU) %>%
#      summarize(minP = min(p.adj)) %>%
#      filter(minP <= FDR)

# %%
# %%R
# head(df.l2fc.rspndr)
# Out:
# # A tibble: 6 × 2
#         OTU         minP
#      <fctr>        <dbl>
# 1    OTU.10 9.458241e-20
# 2   OTU.101 1.822706e-03
# 3  OTU.1010 4.076361e-02
# 4  OTU.1016 2.854686e-03
# 5 OTU.10219 1.004318e-02
# 6 OTU.10249 1.877634e-02

# %%
# %%R
#
# d.rhiz = left_join(df.l2fc.rspndr, mdf.byday.ranked)

# %%
# %%R
# mdf.byday.ranked$Planted_Day = paste(mdf.byday.ranked$Planted, mdf.byday.ranked$DAP, sep = "-")

# %%
# %%R -w 1000 -h 350
#
# getPalette = colorRampPalette(brewer.pal(9, "Set1"))
#
# p = ggplot(mdf.byday.ranked, aes(x = Rank, y = mean_day_abundance, color = Planted_Day))
#
# #p = p + geom_vline(data = d.rhiz, aes(xintercept = Rank), color = "#377eb8", alpha = 0.25, size = 1)
# #p = p + geom_vline(data = d.xyl, aes(xintercept = Rank), color = "#4daf4a", alpha = 0.25, size = 1)
#
# p = p + geom_line(alpha = 0.5, size = 0.8)
#
# #p = p + geom_rug(data = d.cell, color = "black", sides = "b", size = 1.25)
# p = p + geom_rug(data = d.rhiz, color = "black", sides = "t", size = .5)
#
# p = p + geom_line(data = subset(mdf.byday.ranked, Planted == "BARE"), size = 2)
#
# p = p + scale_color_manual(values=getPalette(9))
#
# p = p + scale_y_log10()
#
# p = p + scale_x_log10()
#
# p = p + theme_bw()
#
# p = p + labs(x = "Day 36 Bare Soil Rank", y = "Relative Abundance", color = "Day")
#
# p4 = p

# %% [markdown]
# # Use B73 for rank abundance and plot maize variation on the same day

# %%
# %%R
# physeq.Plant = subset_samples(physeq.Full, DAP == 79 , TRUE)
#
# mdf = psmelt(physeq.Plant)
# physeq.Plant = NULL

# %%
# %%R
# # split dataframe by day and OTU, sumarize mean abundance
# mdf.byplant = ddply(mdf, .(Plant, OTU), summarize, mean_plant_abundance = mean(Abundance))
# head(mdf.byplant)
# Out:
#   Plant       OTU mean_plant_abundance
# 1   B73    OTU.10         2.055621e-02
# 2   B73   OTU.100         1.196080e-03
# 3   B73  OTU.1000         3.497794e-05
# 4   B73 OTU.10004         6.959503e-05
# 5   B73 OTU.10009         4.747308e-05
# 6   B73  OTU.1001         3.801253e-05

# %%
# %%R
# #Order by day, then rank abundance within day
# mdf.byplant = mdf.byplant[order(mdf.byplant$Plant, -mdf.byplant$mean_plant_abundance),]
#
# #Subset to first bulk soil day
# mdf.B73 = subset(mdf.byplant, Plant == "B73")
# mdf.B73$Rank = rank(-mdf.B73$mean_plant_abundance, ties.method = "random")
# mdf.byplant.ranked = join(mdf.byplant, mdf.B73[,c("OTU","Rank")], by = "OTU")
#
# head(mdf.byplant.ranked)
# Out:
#   Plant    OTU mean_plant_abundance Rank
# 1   B73  OTU.3           0.04035030    1
# 2   B73  OTU.7           0.04032706    2
# 3   B73  OTU.9           0.03414476    3
# 4   B73  OTU.8           0.02222233    4
# 5   B73 OTU.10           0.02055621    5
# 6   B73  OTU.4           0.02021365    6

# %%
# %%R
# FDR = 0.05
#
# # read rhizosphere log2fold change file and
# l2f = read.csv(log2foldFile, header = TRUE)
#
# df.l2fc.rspndr = l2f %>%
#     filter(Day == 79 & log2FoldChange > 0) %>%
#     group_by(OTU) %>%
#      summarize(minP = min(p.adj)) %>%
#      filter(minP <= FDR)

# %%
# %%R
#
# d.rhiz = left_join(df.l2fc.rspndr, mdf.byplant.ranked)

# %%
# %%R
# #mdf.byplant.ranked$Planted_Day = paste(mdf.byday.ranked$Planted, mdf.byday.ranked$DAP, sep = "-")

# %%
# %%R -w 1000 -h 350
#
# getPalette = colorRampPalette(brewer.pal(9, "Set1"))
#
# p = ggplot(mdf.byplant.ranked, aes(x = Rank, y = mean_plant_abundance, color = Plant))
#
# #p = p + geom_vline(data = d.rhiz, aes(xintercept = Rank), color = "#377eb8", alpha = 0.25, size = 1)
# #p = p + geom_vline(data = d.xyl, aes(xintercept = Rank), color = "#4daf4a", alpha = 0.25, size = 1)
#
# p = p + geom_line(data = subset(mdf.byplant.ranked, Plant != "BARE"), alpha = 0.5, size = 0.8)
#
# #p = p + geom_rug(data = d.cell, color = "black", sides = "b", size = 1.25)
# p = p + geom_rug(data = d.rhiz, color = "black", sides = "t", size = .5)
#
# p = p + geom_line(data = subset(mdf.byplant.ranked, Plant == "B73"), size = 2)
#
# p = p + scale_color_manual(values=getPalette(9))
#
# p = p + scale_y_log10()
#
# p = p + scale_x_log10()
#
# p = p + theme_bw()
#
# p = p + labs(x = "B73 Rank", y = "Relative Abundance", color = "Day")
#
# p5 = p

# %%
# %%R
# grid.arrange(p1, p3, p4, ncol = 1)
