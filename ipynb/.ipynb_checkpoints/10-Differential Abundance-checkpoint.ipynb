# %% [markdown]
# ##Description:
#
#     Use DeSeq2 to identify differential abundance among treatments
#     Following  Ashley's succ-C notebook

# %% [markdown]
# # Setting variables

# %%
workDir = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/DeSeq2/'
biomFileDir = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/'

biomFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/otu_table_wtax.biom'
metadataFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/metadata_RhizCG_merged.txt'
treeFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/fasttree/otusn.tree'

# %% [markdown]
# # Init

# %%
import pandas as pd
import pandas.rpy.common as com
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import brewer2mpl
from mpltools import style
from IPython.display import FileLink
style.use("ggplot")
# %matplotlib inline
# Out:
# /opt/anaconda/lib/python2.7/site-packages/pandas/rpy/__init__.py:8: FutureWarning: The pandas.rpy module is deprecated and will be removed in a future version. We refer to external packages like rpy2, found here: http://rpy.sourceforge.net
#   "like rpy2, found here: http://rpy.sourceforge.net", FutureWarning)

# %%
# %matplotlib inline
# %load_ext rpy2.ipython

# %%
# %%R
# # The required package list:
# reqpkg = c("plyr","BiocParallel","doParallel", "DESeq2", "foreach", "ggplot2",
#    "gridExtra","scales", "metagenomeSeq", "phyloseq", "dplyr", "tidyr",
#            "reshape", "vegan")
# # Load all required packages and show version
# for (i in reqpkg) {
#     print(i)
#     print(packageVersion(i))
#     suppressMessages(library(i, quietly = TRUE, verbose = FALSE,
#                              warn.conflicts = FALSE, character.only = TRUE))
# }
# Out:
# [1] "plyr"
# [1] ‘1.8.3’
# [1] "BiocParallel"
# [1] ‘1.0.3’
# [1] "doParallel"
# [1] ‘1.0.8’
# [1] "DESeq2"
# [1] ‘1.6.3’
# [1] "foreach"
# [1] ‘1.4.2’
# [1] "ggplot2"
# [1] ‘1.0.1’
# [1] "gridExtra"
# [1] ‘0.9.1’
# [1] "scales"
# [1] ‘0.2.5’
# [1] "metagenomeSeq"
# [1] ‘1.11.10’
# [1] "phyloseq"
# [1] ‘1.10.0’
# [1] "dplyr"
# [1] ‘0.4.2’
# [1] "tidyr"
# [1] ‘0.2.0’
# [1] "reshape"
# [1] ‘0.8.5’
# [1] "vegan"
# [1] ‘2.3.0’

# %%
if not os.path.isdir(workDir):
    os.mkdir(workDir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e67778bf86a4> in <module>()
# ----> 1 if not os.path.isdir(workDir):
#       2     os.mkdir(workDir)
#
# NameError: name 'os' is not defined

# %% [markdown]
# # Setting files

# %%
# !cd $workDir; ln -f -s $biomFileDir$biomFile
# !cd $workDir; ln -f -s $biomFileDir'../'$metadataFile
# !cd $workDir; ls -thlc
# Out:
# total 16M
# lrwxrwxrwx 1 bryan bryan 130 Jul 28 19:12 metadata_RhizCG_merged.txt -> /home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/..//home/bryan/RhizCG/data/MiSeq_amplicon/metadata_RhizCG_merged.txt
# lrwxrwxrwx 1 bryan bryan 143 Jul 28 19:12 otu_table_wtax.biom -> /home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning//home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/otu_table_wtax.biom
# -rw-rw-r-- 1 bryan bryan 16M Jul 28 12:47 bare-plant.csv

# %% [markdown]
# # Loading/editting OTU table

# %%
# %%R -i biomFile -i metadataFile -i workDir -i treeFile
# # loading
# setwd(workDir)
#
# ## biom file
# physeq = import_biom(biomFile, treeFile)
#
# ## loading sample metadata
# sample.data = import_qiime_sample_data(metadataFile)
# physeq = merge_phyloseq(physeq,sample.data)

# %% [markdown]
# ##apply gsub across columns replacing __ w/ "" reload tax_table to phyloseq object

# %%
# %%R
# t = tax_table(physeq)
# t = apply(t, 2, function(y) gsub("__", "", y))
# tax_table(physeq) = t

# %% [markdown]
# Remove controls and relevel factors so that bare is the reference level

# %%
# %%R
# #remove controls
# physeq = subset_samples(physeq, !is.na(Plant))
# #re-order levels
# sample_data(physeq)$Plant = relevel(sample_data(physeq)$Plant, "BARE")

# %% [markdown]
# ##Filter samples
# Initial run without filtering, consider filtering to test effects

# %% [markdown]
# ##Create DeSeq2 object

# %%
# %%R
# library("BiocParallel")
# register(MulticoreParam(6))

# %% [markdown]
# ###Initial run is all plants, which will group bare soils into a single group

# %%
# %%R
# #s = sample_data(physeq)
# #s$Planted = factor(ifelse(s$Plant == "BARE", "BARE", "Rhizosphere"))
# #sample_data(physeq) = s
# #sample_data(physeq) %>% str()
# Out:
# NULL

# %%
# %%R
# #p.dds = phyloseq_to_deseq2(physeq, ~Planted)
# #p.dds = DESeq(p.dds, test = "Wald", fitType="parametric", parallel = TRUE)
# Out:
# NULL

# %%
# %%R
# plotDispEsts(p.dds)
# Out:
# Error in plotDispEsts(p.dds) :
#   error in evaluating the argument 'object' in selecting a method for function 'plotDispEsts': Error: object 'p.dds' not found

# %%
# %%R
# sample_data(physeq)$DAP = factor(sample_data(physeq)$DAP)
# sample_data(physeq)$DAP %>% levels
# Out:
# [1] "36" "53" "57" "61" "72" "79" "84" "88"

# %%
# %%R
# res=results(p.dds, contrast=
#                     c("Plant","HELAN", "BARE"), parallel = TRUE)
# res
# Out:
# Error in "results" %in% mcols(mcols(object))$type :
#   error in evaluating the argument 'table' in selecting a method for function '%in%': Error in mcols(mcols(object)) :
#   error in evaluating the argument 'x' in selecting a method for function 'mcols': Error in mcols(object) :
#   error in evaluating the argument 'x' in selecting a method for function 'mcols': Error: object 'p.dds' not found

# %%
# %%R
# #summary(res) %>% print
# plotMA(res, main="DESeq2", ylim=c(-2,2))
# Out:
# Error in plotMA(res, main = "DESeq2", ylim = c(-2, 2)) :
#   object 'res' not found

# %%
#Can I do paired data to do one full DESeq analysis

# %%
# %%R
#
#
# asNumeric = function(x) { as.numeric(as.character(x)) }
#
# get_Ps = function(physeq.obj) {
#     diagdds = phyloseq_to_deseq2(physeq.obj, ~Plant)
#     diagdds = DESeq(diagdds, quiet = TRUE, parallel = TRUE)
#     theta = 0.5
#     r = results(diagdds)
#     beta = r$log2FoldChange
#     betaSE = r$lfcSE
#     p = pnorm(beta, theta, betaSE, lower.tail = FALSE)
#     r$p = p
#     return(r[, c("log2FoldChange", "p")])
# }
#
# deseq_prune = function(physeq.obj, plant, day) {
#     physeq.md = sample_data(physeq.obj)
#     p = prune_samples((physeq.md$Plant %in% c("BARE", plant))&
#                      (physeq.md$DAP == day), physeq.obj)
#     p.thresh = filter_taxa(p, function(x) sum(x > 0) > (0.25 * length(x)), TRUE)
#     return(p.thresh)
# }

# %%
# %%R -w 1200 -h 600
# Sd = sample_data(physeq)
#
# days = levels(Sd$DAP)
# res.list = vector("list", length(days))
# names(res.list) = as.character(days)
# res.list
#
# df_all = data.frame()
#
# for (day in days) {
#     print(day) ##need to remove
#     Sd.d = Sd[Sd$DAP == day,]
#     Sd.d = Sd.d[Sd.d$Plant != "BARE"]
#     Plants = levels(Sd.d$Plant)
#     Plants %>% print
#
#     res.list.list = NULL
#     res.list.list = vector("list", length(Plants))
#     names(res.list) = Plants
#     df_plant = data.frame()
#
#     for (plant in Plants) {
#         DF = NULL
#         physeq.plant = deseq_prune(physeq, plant, day)
#         #re-order levels
#         sample_data(physeq.plant)$Plant = relevel(sample_data(physeq.plant)$Plant, "BARE")
#         DF = get_Ps(physeq.plant)
#         supp = tax_table(physeq.plant)
#         if (!setequal(row.names(DF), row.names(supp))) {
#             stop("Ordination and supplementary data indices differ on the following:\n.",
#             setdiff(row.names(DF), row.names(supp)))
#         }
#         DF = data.frame(DF, supp)
#         DF$OTU = rownames(DF)
#         DF$Day = day
#         df_plant = rbind(df_plant, DF)
#     }
#     df_plant$Plant = plant
#     df_all = rbind(df_all, df_plant)
# }
# Out:
# [1] "36"
# [1] "FAGES"
# converting counts to integer mode
# [1] "53"
# [1] "AMAPO" "ECHCG"
# converting counts to integer mode
# converting counts to integer mode
# [1] "57"
# [1] "ABUTH" "GLYMA"
# converting counts to integer mode
# converting counts to integer mode
# [1] "61"
# [1] "SETFA"
# converting counts to integer mode
# [1] "72"
# [1] "75-062" "ERATE"  "H99"    "Il14H"  "MS71"
# converting counts to integer mode
# converting counts to integer mode
# converting counts to integer mode
# converting counts to integer mode
# converting counts to integer mode
# [1] "79"
# [1] "B73"   "B97"   "Hp301" "Oh7B"
# converting counts to integer mode
# converting counts to integer mode
# converting counts to integer mode
# converting counts to integer mode
# [1] "84"
# [1] "HELAN"  "SORBI"  "SORSUD"
# converting counts to integer mode
# converting counts to integer mode
# converting counts to integer mode
# [1] "88"
# [1] "ELCOR" "Ki3"   "Mo18"  "Tx303"
# converting counts to integer mode
# converting counts to integer mode
# converting counts to integer mode
# converting counts to integer mode

# %%
# %%R -i workDir
# df_all$p.adj = p.adjust(df_all$p, "BH")
# setwd(workDir)
# write.table(df_all, "bare-plant.csv", row.names = FALSE, sep = ",")

# %% [markdown]
# #Checkpoint, read file of bare-plant.csv to continue

# %%
# %%R -i workDir
# setwd(workDir)
# df_all = read.csv("bare-plant.csv", header = TRUE)
# head(df_all)
# Out:
#   log2FoldChange         p    Rank1         Rank2      Rank3
# 1     -1.2367952 0.9546068 Bacteria Acidobacteria      32-21
# 2     -0.9585578 0.9991682 Bacteria Acidobacteria Holophagae
# 3      1.2749069 0.1830659 Bacteria Acidobacteria Holophagae
# 4     -0.9888109 0.9999998 Bacteria Acidobacteria Holophagae
# 5     -0.6785618 0.9673205 Bacteria Acidobacteria Holophagae
# 6     -3.2346654 0.9988116 Bacteria Acidobacteria     BPC102
#                  Rank4                Rank5 Rank6 Rank7 Rank8      OTU Day
# 1 uncultured_bacterium                 <NA>  <NA>  <NA>  <NA> OTU.5899  36
# 2              Sva0725                 <NA>  <NA>  <NA>  <NA> OTU.8680  36
# 3              Sva0725 uncultured_bacterium  <NA>  <NA>  <NA> OTU.2666  36
# 4              Sva0725                 <NA>  <NA>  <NA>  <NA>  OTU.323  36
# 5              Sva0725                 <NA>  <NA>  <NA>  <NA> OTU.7636  36
# 6 uncultured_bacterium                 <NA>  <NA>  <NA>  <NA> OTU.3772  36
#   Plant     p.adj
# 1 FAGES 1.0000000
# 2 FAGES 1.0000000
# 3 FAGES 0.8627427
# 4 FAGES 1.0000000
# 5 FAGES 1.0000000
# 6 FAGES 1.0000000

# %%
# %%R
# 2
# Out:
# [1] 2

# %%
# %%R -w 900 -h 600
#
# colourCount = length(unique(df_all$Rank2)) + 1
# getPalette = colorRampPalette(brewer.pal(10, "Dark2"))
#
# df.sig = df_all[df_all$p.adj < .05,]
# df.ns = df_all[df_all$p.adj >= .05,]
#
# p = ggplot(df_all)+
#     geom_point(data = df.ns, aes(Rank2, log2FoldChange, color = "Gray", position = "jitter")) +
#     scale_shape_identity() +
#     geom_point(data = df.sig, aes(Rank2, log2FoldChange, color = Rank2, position = "jitter")) +
#
#                #geom_hline(y_intercept = .4) +
#
#     facet_wrap(~Plant)+
#     theme(axis.text.x = element_text(angle = 90)) +
#     labs(y = "log[2] Fold Change")
#
# p = p + scale_color_manual(values = getPalette(colourCount))
# #p = p + geom_point(alpha = 1.00, shape = 21, size = 1.5)
# #p = p + theme_bw()
#
#
#
#
# #p = p + geom_hline(y = l2fc.threshold)
#
#
#
# #p = p + theme(axis.text.x = element_blank())
#
# #p = p + labs(x = "Phylum", color = "Phylum")
#
# #p = p + guides(col = guide_legend(ncol = 2))
#
# #p = p + labs(y = expression(paste("", log[2]," Fold Change",sep="")))
#
# #p = p + guides(colour = guide_legend(override.aes = list(size=4)))
#
# p

# %%
# %%R
# pVal_df.plant = ldply(res.list, function(x) x)
# head(pVal_df.plant)
# Out:
# data frame with 0 columns and 0 rows

# %%
pVal_df.13CXPS$Day = factor(as.numeric(pVal_df.13CXPS$Day))

pVal_df.13CXPS = subset(pVal_df.13CXPS, !is.na(pVal_df.13CXPS$log2FoldChange))

# Phylum order
x = tapply(pVal_df.13CXPS$log2FoldChange, pVal_df.13CXPS$Rank2, function(x) max(x))
x = sort(x, decreasing = TRUE, na.last = TRUE)
pVal_df.13CXPS$Rank2 = factor(as.character(pVal_df.13CXPS$Rank2), levels = names(x))

p = ggplot(pVal_df.13CXPS, aes(x = Rank2, y = log2FoldChange)) 
p = p + geom_hline(y = 1) + geom_point(aes(fill = Rank2), pch = 21, alpha = 0.45, color = "#151515") + 
    theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5, size = 12),
          strip.text.x = element_text(size = 16)) + guides(fill = FALSE) +
    facet_wrap(~Day) + labs(x = "Phylum")
print(p)

# %% [markdown]
# ##Workin on creating publication quality figure

# %%
df_all = com.load_data("df_all")
df_pivot = df_all.pivot_table(index="OTU", columns="Plant", values="log2FoldChange")

OTU_series = df_all.groupby("OTU").first()["Rank2"]
df_pivot = df_pivot.join(OTU_series)

phyla = df_all.sort("log2FoldChange").groupby("Rank2").last()
phyla.sort("log2FoldChange", ascending=False, inplace=True)

xd = dict([(p, x + 1) for x, p in enumerate(phyla.index.tolist())])
xmax = np.max(xd.values()) + 1
X = []
for p in df_pivot.Rank2:
    try:
        X.append(xd[p])
    except KeyError:
        X.append(xmax)
df_pivot["X"] = X

m1 = brewer2mpl.get_map("Paired", "qualitative", 8)
m2 = brewer2mpl.get_map("Dark2", "qualitative", 8)
colors = m1.hex_colors + m2.hex_colors
cd = dict(zip(phyla.index.tolist(), colors))
phylum_color = []
for p in df_pivot.Rank2:
    try:
        phylum_color.append(cd[p])
    except KeyError:
        phylum_color.append("#151515")
df_pivot["phylum_color"] = phylum_color

# %%
df_all.columns
# Out:
# Index([u'log2FoldChange', u'p', u'Rank1', u'Rank2', u'Rank3', u'Rank4', u'Rank5', u'Rank6', u'Rank7', u'Rank8', u'OTU', u'Day', u'Plant', u'p.adj'], dtype='object')

# %%
xd
# Out:
# {'Acidobacteria': 9,
#  'Actinobacteria': 5,
#  'Armatimonadetes': 10,
#  'BHI80-139': 25,
#  'Bacteroidetes': 3,
#  'Candidate_division_BRC1': 18,
#  'Candidate_division_OD1': 11,
#  'Candidate_division_OP11': 30,
#  'Candidate_division_OP3': 22,
#  'Candidate_division_SR1': 29,
#  'Candidate_division_TM7': 17,
#  'Candidate_division_WS3': 31,
#  'Chlamydiae': 32,
#  'Chlorobi': 20,
#  'Chloroflexi': 6,
#  'Cyanobacteria': 8,
#  'Deferribacteres': 34,
#  'Deinococcus-Thermus': 15,
#  'Elusimicrobia': 16,
#  'Fibrobacteres': 7,
#  'Firmicutes': 4,
#  'GOUTA4': 36,
#  'Gemmatimonadetes': 14,
#  'JL-ETNP-Z39': 33,
#  'Lentisphaerae': 24,
#  'NPL-UPA2': 23,
#  'Nitrospirae': 19,
#  'Planctomycetes': 13,
#  'Proteobacteria': 2,
#  'SM2F11': 26,
#  'Spirochaetes': 12,
#  'TA06': 28,
#  'TM6': 27,
#  'Thermotogae': 35,
#  'Verrucomicrobia': 1,
#  'WCHB1-60': 21}

# %%
df = df_pivot
df
# Out:
#               ECHCG     FAGES     GLYMA      MS71      Oh7B     SETFA  \
# OTU
# OTU.10     3.788765  2.225056  4.018410  3.712758  4.377438  5.477555
# OTU.100   -0.261541  1.041747 -0.652985 -0.032698 -0.312994  0.074627
# OTU.1000   0.556641  1.941258  0.280789  1.196512  0.457377  2.059607
# OTU.10000       NaN       NaN       NaN       NaN  1.643816       NaN
# OTU.10004 -0.350724 -0.781626 -0.146961 -0.025814  0.331913 -0.633327
# OTU.10009       NaN       NaN  4.491494  5.764699  4.485300       NaN
# OTU.1001        NaN       NaN       NaN       NaN  6.333756       NaN
# OTU.10012       NaN       NaN       NaN -0.692723 -0.832806 -0.547744
# OTU.10013       NaN  0.793370  0.827262  0.799661 -2.702732       NaN
# OTU.10016 -0.508366  0.563662       NaN  1.011359 -0.411647  0.126966
# OTU.10017       NaN  2.879580       NaN  2.391659       NaN       NaN
# OTU.1002  -0.645730 -1.447221 -0.669814 -0.861634 -0.087197 -1.001532
# OTU.10027 -1.996136 -1.530971  0.366157 -0.222301 -1.104130 -0.350453
# OTU.10028 -2.649606 -0.604775 -0.558311 -0.911740 -1.084086 -3.877798
# OTU.1003  -0.787141  0.832524 -0.687375 -0.216698 -0.654567 -0.793096
# OTU.10030  2.275059  4.357787 -0.501726 -0.095502 -0.348451  0.316475
# OTU.10031       NaN       NaN       NaN       NaN  0.712313       NaN
# OTU.10035 -0.902892  1.102388 -1.613498 -0.337804 -1.709005 -0.970286
# OTU.10036 -0.925217  1.327165 -0.868146  0.564205 -0.230352  0.954452
# OTU.10037       NaN  4.256622       NaN  0.948905 -0.722736       NaN
# OTU.10039  3.031916       NaN       NaN  2.124756  0.951347       NaN
# OTU.1004   0.847970  0.550749 -0.985893 -0.799242  0.043103  0.900667
# OTU.10040 -2.775941       NaN -2.806957 -2.651087 -1.398512 -1.895846
# OTU.10041 -2.549837 -1.590877 -1.328102  0.540190 -1.509693 -1.214300
# OTU.10043       NaN       NaN       NaN       NaN  2.040185       NaN
# OTU.1005  -0.237437  1.347341 -1.162893  0.019021 -0.687156  0.151077
# OTU.10052 -1.889152 -2.152540 -2.050719 -0.868631 -0.934323 -1.311131
# OTU.10056 -2.047894 -0.498676 -2.038891  0.344464 -1.674995 -0.095933
# OTU.10059  5.686506       NaN  5.736969       NaN  6.178496       NaN
# OTU.1006   0.737014  0.380448  0.088617  0.759354  0.929056 -0.850972
# ...             ...       ...       ...       ...       ...       ...
# OTU.9927   1.817232  1.832097 -0.769864  0.260940 -1.052946  1.128754
# OTU.9936  -1.242836 -0.964094       NaN -0.843860 -2.575967 -0.085640
# OTU.9939   1.341985  2.339163 -1.721892 -0.438386 -1.247043  1.646657
# OTU.994   -0.582034 -0.864587 -1.795441  0.116220 -0.421476 -0.063187
# OTU.9941  -1.239116  1.019431 -0.520176  0.154417  0.307851  1.140574
# OTU.9949   1.222400       NaN  1.446018  0.265286  1.198210  2.541989
# OTU.995   -1.023504  0.500415 -0.527318  0.177146 -0.774540 -0.795543
# OTU.9951  -2.016915 -1.009284 -1.464918 -1.925471 -1.550964 -1.578680
# OTU.9953  -0.231998 -0.150134 -0.275366  0.086897 -0.888877  0.146461
# OTU.9957  -0.805105       NaN       NaN  1.137305       NaN       NaN
# OTU.9958  -0.497677 -0.800506 -0.978192 -0.220541  0.216227  0.172113
# OTU.9959        NaN       NaN       NaN -1.283803       NaN       NaN
# OTU.996   -3.692806 -2.098699 -0.470992  0.018391 -0.072083 -1.057247
# OTU.9964  -2.877062  0.043351 -1.500761 -0.956057 -1.893630 -1.674180
# OTU.9965   2.180952 -0.487035  0.699367  2.417143  2.145439  2.513608
# OTU.9966        NaN       NaN       NaN  3.059745 -0.339264       NaN
# OTU.997   -0.479967 -0.344218 -1.281304  0.490927  0.022309 -0.610883
# OTU.9975  -1.213106 -1.268928 -0.917922  0.040023  0.187073 -1.668266
# OTU.998    0.700839  2.622144  0.526820  0.287219  0.720022  1.804596
# OTU.9982        NaN       NaN       NaN -0.217125       NaN       NaN
# OTU.9984   1.905518  0.537451  0.675011  1.120927  1.221912  0.116539
# OTU.9989   0.211327  1.089136  1.244064  1.672377  1.747858  1.528964
# OTU.999    2.755976  2.285115  3.857663  2.719708  1.717844  2.331064
# OTU.9990        NaN       NaN       NaN       NaN  1.911570       NaN
# OTU.9991  -2.222407 -0.428740       NaN  1.494786 -0.435451 -0.647075
# OTU.9992   0.623194  2.325746 -0.474050  0.850402  0.427998  1.001177
# OTU.9993  -0.689901       NaN       NaN       NaN       NaN       NaN
# OTU.9995  -2.148476 -2.331656 -2.017681 -1.853473 -2.132879 -2.381808
# OTU.9997        NaN  1.255359       NaN       NaN -1.832494       NaN
# OTU.9998   1.739402 -0.924688 -0.675327  0.336453  0.900265 -1.093378
#
#              SORSUD     Tx303                   Rank2   X phylum_color
# OTU
# OTU.10     3.673564  4.223827          Proteobacteria   2      #1F78B4
# OTU.100   -0.953164  0.074163           Acidobacteria   9      #1B9E77
# OTU.1000   0.368372  1.668471          Planctomycetes  13      #66A61E
# OTU.10000       NaN       NaN          Planctomycetes  13      #66A61E
# OTU.10004  1.514963  0.284575          Actinobacteria   5      #FB9A99
# OTU.10009  3.912417  6.737019           Bacteroidetes   3      #B2DF8A
# OTU.1001        NaN       NaN              Firmicutes   4      #33A02C
# OTU.10012       NaN       NaN          Planctomycetes  13      #66A61E
# OTU.10013 -0.931874  0.265726         Armatimonadetes  10      #D95F02
# OTU.10016       NaN       NaN          Actinobacteria   5      #FB9A99
# OTU.10017       NaN       NaN          Planctomycetes  13      #66A61E
# OTU.1002   0.421960 -0.083003          Actinobacteria   5      #FB9A99
# OTU.10027 -0.842547 -0.160697          Proteobacteria   2      #1F78B4
# OTU.10028       NaN       NaN         Verrucomicrobia   1      #A6CEE3
# OTU.1003  -1.989727 -0.637199          Planctomycetes  13      #66A61E
# OTU.10030       NaN -0.154677        Gemmatimonadetes  14      #E6AB02
# OTU.10031       NaN       NaN         Verrucomicrobia   1      #A6CEE3
# OTU.10035 -0.857202 -1.901710           Acidobacteria   9      #1B9E77
# OTU.10036 -0.771059 -0.117033           Acidobacteria   9      #1B9E77
# OTU.10037       NaN       NaN           Cyanobacteria   8      #FF7F00
# OTU.10039       NaN       NaN           Bacteroidetes   3      #B2DF8A
# OTU.1004  -0.478350 -0.991538           Bacteroidetes   3      #B2DF8A
# OTU.10040 -0.578946       NaN           Acidobacteria   9      #1B9E77
# OTU.10041       NaN       NaN          Proteobacteria   2      #1F78B4
# OTU.10043       NaN       NaN          Actinobacteria   5      #FB9A99
# OTU.1005  -0.843054  0.238102          Planctomycetes  13      #66A61E
# OTU.10052 -2.624041 -2.061534          Proteobacteria   2      #1F78B4
# OTU.10056       NaN       NaN          Planctomycetes  13      #66A61E
# OTU.10059       NaN       NaN         Verrucomicrobia   1      #A6CEE3
# OTU.1006   0.556736  1.021800             Chloroflexi   6      #E31A1C
# ...             ...       ...                     ...  ..          ...
# OTU.9927        NaN       NaN           Acidobacteria   9      #1B9E77
# OTU.9936        NaN       NaN           Acidobacteria   9      #1B9E77
# OTU.9939  -1.864037  1.056325           Bacteroidetes   3      #B2DF8A
# OTU.994   -0.838426 -0.802358          Planctomycetes  13      #66A61E
# OTU.9941        NaN  1.892277           Acidobacteria   9      #1B9E77
# OTU.9949        NaN       NaN          Proteobacteria   2      #1F78B4
# OTU.995   -3.345199  0.269631          Proteobacteria   2      #1F78B4
# OTU.9951  -3.758124 -2.532663          Proteobacteria   2      #1F78B4
# OTU.9953  -0.839203  3.864803           Acidobacteria   9      #1B9E77
# OTU.9957        NaN       NaN          Planctomycetes  13      #66A61E
# OTU.9958        NaN       NaN             Chloroflexi   6      #E31A1C
# OTU.9959        NaN       NaN          Proteobacteria   2      #1F78B4
# OTU.996   -0.829177 -0.421965             Chloroflexi   6      #E31A1C
# OTU.9964  -1.008008       NaN           Acidobacteria   9      #1B9E77
# OTU.9965   0.767015  3.225798          Proteobacteria   2      #1F78B4
# OTU.9966        NaN       NaN          Proteobacteria   2      #1F78B4
# OTU.997   -0.728445  0.443802          Proteobacteria   2      #1F78B4
# OTU.9975  -0.270524 -0.096575          Actinobacteria   5      #FB9A99
# OTU.998    0.305143  0.685379           Bacteroidetes   3      #B2DF8A
# OTU.9982        NaN       NaN          Planctomycetes  13      #66A61E
# OTU.9984   0.602089  0.407920          Proteobacteria   2      #1F78B4
# OTU.9989   2.589302  2.718089          Actinobacteria   5      #FB9A99
# OTU.999    0.846377       NaN          Proteobacteria   2      #1F78B4
# OTU.9990        NaN       NaN          Actinobacteria   5      #FB9A99
# OTU.9991        NaN -1.117783          Actinobacteria   5      #FB9A99
# OTU.9992        NaN       NaN         Verrucomicrobia   1      #A6CEE3
# OTU.9993        NaN       NaN  Candidate_division_WS3  31      #151515
# OTU.9995  -2.649528 -2.079721             Nitrospirae  19      #151515
# OTU.9997        NaN       NaN          Proteobacteria   2      #1F78B4
# OTU.9998        NaN -0.393077          Proteobacteria   2      #1F78B4
#
# [7049 rows x 11 columns]

# %% [markdown]
# ###Below here is code for figure that needs modification to work with data structure.  Need to define how figurew wil be laid out first

# %%
matplotlib.rcParams["axes.facecolor"] = "white"
matplotlib.rcParams["axes.edgecolor"] = "#151515"
matplotlib.rcParams["grid.color"] = "#F5F5F5"
matplotlib.rcParams["grid.alpha"] = "0.75"

#thresh = .5

fig = plt.figure()
fig.set_size_inches(12,7)

gs = gridspec.GridSpec(nrows = 2, ncols = 7, width_ratios=[1,1,1,1,1,0.5], 
                       left=0.05, right=0.95, bottom=0.05, top=0.95,
                       hspace=0.1, wspace=0.05)

N = len(phyla.index) + 1
treatment = ["13CCPS", "13CXPS"]
days = [1,3,7,14,30]
ncol = 5
nrow = 2
for j, d in zip(range(ncol), days):
    for i, t in zip(range(nrow), treatment):
        try:
            ax = fig.add_subplot(gs[i,j])
            points = ax.scatter(df.X + 0.45 * np.random.random(len(df.X)),
                                df[(t,d)], alpha = 0.75, c = df.phylum_color.tolist(), 
                                s = 20, linewidth=0.25, edgecolor = "#505050")
            ax.axhline(thresh, color = "#151515")
            ax.set_title("%s %s"%(t, d))
        except KeyError:
            ax.set_visible(False)
            continue

axs = fig.get_axes()
xmin = np.array([axi.get_xlim()[0] for axi in axs]).min()
xmax = np.array([axi.get_xlim()[1] for axi in axs]).max()            

for axi in axs:
    axi.set_xlim([xmin,xmax])

axHistX = fig.add_subplot(gs[0, 5])
axHistX.hist(df_all[df_all["Treatment"]=="13CCPS"]["log2FoldChange"], orientation="horizontal", 
             bins=25, fc = "#252525")
axHistX.axhline(thresh)
axHistX.set_yticklabels([])
axHistX.set_ylim([-5,4])

axHistY = fig.add_subplot(gs[1, 5])
axHistY.hist(df_all[df_all["Treatment"]=="13CXPS"]["log2FoldChange"], orientation="horizontal", 
             bins=25, fc = "#252525")
axHistY.axhline(thresh)

axs = fig.get_axes()
xmin = np.array([axi.get_xlim()[0] for axi in axs]).min()
xmax = np.array([axi.get_xlim()[1] for axi in axs]).max()
ymin = np.array([axi.get_ylim()[0] for axi in axs]).min()
ymax = np.array([axi.get_ylim()[1] for axi in axs]).max()

for i, axi in enumerate(axs):
    if i == 10:
        axi.set_xticklabels([])
        axi.set_ylim([ymin,ymax])
        continue
    elif i == 11:
        axi.set_ylim([ymin,ymax])
        axi.set_xlabel("counts")
        continue
    axi.set_ylim([ymin,ymax])
    #axi.set_xticks(range(len(phyla.index.tolist()) + 1))\
    axi.set_xticks(np.arange(N) + 1)
    axi.set_xticklabels([])
    axi.set_xlim([0, N+1])
    
for axi in axs[3:]:
    axi.set_yticklabels([])

axs[-1].set_xticklabels(axs[-1].get_xticks(), rotation = -90, size = 8)
axs[-2].set_xlim(axs[-1].get_xlim())

fig.text(0.005, 0.5, r"Log$_{2}$ Fold Change", rotation="vertical", va ="center", fontsize=16)
fig.text(0.45, 0, "Phylum", fontsize=16)

dummy_lines = []
for p in phyla.index.tolist():
    l, = axs[0].plot([1],[1], "o", color = cd[p], label = p)
    dummy_lines.append(l)

leg = fig.legend(dummy_lines, phyla.index.tolist(), "upper left", ncol=1, numpoints=1, 
           bbox_to_anchor=(0.035, 1.02), frameon = False, prop = {"size":8, "style":"italic"})

leg.set_title("Phylum")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-79-a0c2d172367b> in <module>()
#      23     for i, t in zip(range(nrow), treatment):
#      24         try:
# ---> 25             ax = fig.add_subplot(gs[i,j])
#      26             points = ax.scatter(df.X + 0.45 * np.random.random(len(df.X)),
#      27                                 df[(t,d)], alpha = 0.75, c = df.phylum_color.tolist(),
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#     962                     self._axstack.remove(ax)
#     963
# --> 964             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#     965
#     966         self._axstack.add(key, a)
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      73             raise ValueError('Illegal argument(s) to subplot: %s' % (args,))
#      74
# ---> 75         self.update_params()
#      76
#      77         # _axes_class is set in the subplot_class_factory
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in update_params(self)
#     113         self.figbox, self.rowNum, self.colNum, self.numRows, self.numCols = \
#     114             self.get_subplotspec().get_position(self.figure,
# --> 115                                                 return_all=True)
#     116
#     117     def is_first_col(self):
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/gridspec.pyc in get_position(self, fig, return_all)
#     423
#     424         figBottoms, figTops, figLefts, figRights = \
# --> 425                     gridspec.get_grid_positions(fig)
#     426
#     427
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/gridspec.pyc in get_grid_positions(self, fig)
#     127         figTops = [top - cellHs[2*rowNum] for rowNum in range(nrows)]
#     128         figBottoms = [top - cellHs[2*rowNum+1] for rowNum in range(nrows)]
# --> 129         figLefts = [left + cellWs[2*colNum] for colNum in range(ncols)]
#     130         figRights = [left + cellWs[2*colNum+1] for colNum in range(ncols)]
#     131
#
# IndexError: index 12 is out of bounds for axis 0 with size 12
