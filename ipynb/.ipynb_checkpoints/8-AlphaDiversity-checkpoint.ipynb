# %% [markdown]
# ## Description:
#
#     Diversity estimates

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(phyloseq)
# library(ggplot2)
# library(foreach)
# library(doParallel)
# library(gridExtra)
# library(dplyr)
# library(tidyr)
# library(lme4)
# library(lmerTest)
# Out:
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘lmerTest’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:stats’:
#
#     step
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %% [markdown]
# # Loading phyloseq object

# %%
# %%R
# F = file.path('/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/physeq/Full-Sparsity3in3')
# physeq.Full = readRDS(F)
# sd = sample_data(physeq.Full)
# physeq.Full
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4982 taxa and 238 samples ]
# sample_data() Sample Data:       [ 238 samples by 49 sample variables ]
# tax_table()   Taxonomy Table:    [ 4982 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4982 tips and 4981 internal nodes ]

# %% [markdown]
# ### Rarefy to minimum number of reads

# %%
# %%R
# colnames(sample_data(physeq.Full))
# Out:
#  [1] "X.sample"            "Library"             "Primer_Plate"
#  [4] "Primer_Well_ID"      "primerFR_ID_byPlate" "primerFR_ID_total"
#  [7] "barcode_ID"          "PlotID"              "Plant"
# [10] "Plot"                "Treatment"           "Rep"
# [13] "DAP"                 "Sampling"            "PlantSample"
# [16] "Type"                "Grass_Broad"         "Status"
# [19] "Subfamily"           "fwd_barcode"         "rev_barcode"
# [22] "Planted"             "Biomass_P"           "SLA"
# [25] "Leaf_N"              "Leaf_C"              "LeafC_N"
# [28] "LNa"                 "Plant_N"             "Plant_C"
# [31] "Plant_CN"            "d15N"                "tN_p"
# [34] "BX_activity_g"       "CB_activity_g"       "LAP_activity_g"
# [37] "NAG_activity_g"      "BX_rel"              "CB_rel"
# [40] "LAP_rel"             "NAG_rel"             "NO3_ug_g"
# [43] "NH4_ug_g"            "InorganicN"          "Resid_logB"
# [46] "Resid_logN"          "Resid_logCN"         "Resid_logSLA"
# [49] "Resid_LeafN"

# %% [markdown]
# # Alpha Diversity

# %%
# %%R -w 800 -h 350
# alpha_meas = c("Observed", "Chao1", "Shannon", "Simpson")
# (p <- plot_richness(physeq.Full, "Planted", measures=alpha_meas))

# %%
# %%R -w 800 -h 350
# p = p + geom_boxplot(data=p$data, aes(x=Planted, y=value, color=NULL), alpha=0.1)
# p

# %% [markdown]
# ## Estimate richness

# %%
# %%R
# Shannon = estimate_richness(physeq.Full, measures="Shannon")
#
# sd = sample_data(physeq.Full) %>% tbl_df()
#
# sd = bind_cols(sd, Shannon)
# sd$Rep = as.factor(sd$Rep)
# sd$Plant = as.factor(sd$Plant)
# Out:
# Source: local data frame [6 x 50]
#
#            X.sample Library Primer_Plate Primer_Well_ID primerFR_ID_byPlate
#               (chr)   (int)        (int)         (fctr)               (int)
# 1 sample2-1.06_Npos       1            1             H9                  72
# 2 sample6-4.27_Npos       1            2            F11                  86
# 3 sample4-4.27_Nneg       1            1            B12                  90
# 4 sample4-1.06_Nneg       1            1            E11                  85
# 5 sample2-1.06_Nneg       1            1             G9                  71
# 6 sample6-3.07_Nneg       1            2            C11                  83
# Variables not shown: primerFR_ID_total (int), barcode_ID (int), PlotID (fctr),
#   Plant (fctr), Plot (dbl), Treatment (fctr), Rep (int), DAP (int), Sampling
#   (fctr), PlantSample (fctr), Type (fctr), Grass_Broad (fctr), Status (fctr),
#   Subfamily (fctr), fwd_barcode (fctr), rev_barcode (fctr), Planted (chr),
#   Biomass_P (dbl), SLA (dbl), Leaf_N (dbl), Leaf_C (dbl), LeafC_N (dbl), LNa
#   (dbl), Plant_N (dbl), Plant_C (dbl), Plant_CN (dbl), d15N (dbl), tN_p (dbl),
#   BX_activity_g (dbl), CB_activity_g (dbl), LAP_activity_g (dbl),
#   NAG_activity_g (dbl), BX_rel (dbl), CB_rel (dbl), LAP_rel (dbl), NAG_rel
#   (dbl), NO3_ug_g (dbl), NH4_ug_g (dbl), InorganicN (dbl), Resid_logB (dbl),
#   Resid_logN (dbl), Resid_logCN (dbl), Resid_logSLA (dbl), Resid_LeafN (dbl),
#   Shannon (dbl)

# %%
# %%R
# #test treatment effects on microbial diversity
#
# fit1 = lmer(Shannon~Library + (1|Rep) + (1|Rep:Plant), data = sd)
# summary(fit1)
# Out:
# Linear mixed model fit by REML t-tests use Satterthwaite approximations to
#   degrees of freedom [lmerMod]
# Formula: Shannon ~ Library + (1 | Rep) + (1 | Rep:Plant)
#    Data: sd
#
# REML criterion at convergence: 89.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.3946 -0.4188  0.1076  0.4820  2.9958
#
# Random effects:
#  Groups    Name        Variance Std.Dev.
#  Rep:Plant (Intercept) 0.08384  0.2895
#  Rep       (Intercept) 0.00000  0.0000
#  Residual              0.04402  0.2098
# Number of obs: 238, groups:  Rep:Plant, 91; Rep, 4
#
# Fixed effects:
#              Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)   6.89144    0.07116 218.45000  96.844  < 2e-16 ***
# Library      -0.25086    0.04330 236.00000  -5.793  2.2e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#         (Intr)
# Library -0.879
