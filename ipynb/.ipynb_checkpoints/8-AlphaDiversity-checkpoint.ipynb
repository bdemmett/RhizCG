# %% [markdown]
# ##Description:
#
#     Diversity estimates of merged dataset

# %% [markdown]
# # Setting variables

# %%
workDir = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/ordination/alpha/'
biomFileDir = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/'

biomFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/otu_table_wtax.biom'
metadataFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/metadata_RhizCG_merged.txt'
treeFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/fasttree/otusn.tree'

# %% [markdown]
# # Init

# %%
import os
from pandas import DataFrame
from IPython.display import FileLink

# %%
# %matplotlib inline
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library(phyloseq)
# library(ggplot2)
# library(foreach)
# library(doParallel)
# library(gridExtra)
# library(dplyr)
# library(tidyr)

# %%
if not os.path.isdir(workDir):
    os.mkdir(workDir)

# %% [markdown]
# # Setting files

# %%
# !cd $workDir; ln -f -s $biomFileDir$biomFile
# !cd $workDir; ln -f -s $biomFileDir'../'$metadataFile
# !cd $workDir; ls -thlc
# Out:
# total 8.0K
# lrwxrwxrwx 1 bryan bryan 130 Jul 14 10:43 metadata_RhizCG_merged.txt -> /home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/..//home/bryan/RhizCG/data/MiSeq_amplicon/metadata_RhizCG_merged.txt
# lrwxrwxrwx 1 bryan bryan 143 Jul 14 10:43 otu_table_wtax.biom -> /home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning//home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/otu_table_wtax.biom

# %% [markdown]
# # Loading/editting OTU table

# %%
# %%R -i biomFile -i metadataFile -i workDir -i treeFile
# # loading
# setwd(workDir)
#
# ## biom file
# physeq = import_biom(biomFile, treeFile)
#
# ## loading sample metadata
# sample.data = import_qiime_sample_data(metadataFile)
# physeq = merge_phyloseq(physeq,sample.data)

# %% [markdown]
# #Alpha Diversity

# %%
# %%R
# print(physeq)
# sample_variables(physeq)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 11246 taxa and 249 samples ]
# sample_data() Sample Data:       [ 249 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 11246 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 11246 tips and 11245 internal nodes ]
#  [1] "X.sample"            "Library"             "Primer_Plate"
#  [4] "Primer_Well_ID"      "primerFR_ID_byPlate" "primerFR_ID_total"
#  [7] "barcode_ID"          "PlotID"              "Plant"
# [10] "Plot"                "Treatment"           "Rep"
# [13] "DAP"                 "Sampling"            "PlantSample"
# [16] "Type"                "Grass_Broad"         "Status"
# [19] "Subfamily"           "fwd_barcode"         "rev_barcode"

# %%
# %%R -w 800 -h 350
# plot_richness(physeq, measures = c("Chao1", "Shannon"), x = "Plant")

# %%
# %%R -w 800 -h 350
# plot_richness(physeq, measures = c("Chao1", "Shannon"), x = "Type")
