# %% [markdown]
# ## Description:
#
#     Hypothesis testing

# %% [markdown]
# # Setting variables

# %%
workDir = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/ordination/h_testing/'
biomFileDir = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/'

biomFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/otu_table_wtax.biom'
metadataFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/metadata_RhizCG_merged.txt'
treeFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/fasttree/otusn.tree'

# %% [markdown]
# # Init

# %%
import os
from pandas import DataFrame
from IPython.display import FileLink

# %%
# %matplotlib inline
# %load_ext rpy2.ipython

# %%
# %%R
# library(phyloseq)
# library(ggplot2)
# library(foreach)
# library(doParallel)
# library(gridExtra)
# library(dplyr)
# library(tidyr)
# library(vegan)
# Out:
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: foreach: simple, scalable parallel programming from Revolution Analytics
# Use Revolution R for scalability, fault tolerance and more.
# http://www.revolutionanalytics.com
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: iterators
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: parallel
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘dplyr’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: permute
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: lattice
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: This is vegan 2.3-0
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %%
if not os.path.isdir(workDir):
    os.mkdir(workDir)

# %% [markdown]
# # Setting files

# %%
# !cd $workDir; ln -f -s $biomFileDir$biomFile
# !cd $workDir; ln -f -s $biomFileDir'../'$metadataFile
# !cd $workDir; ls -thlc
# Out:
# total 32K
# lrwxrwxrwx 1 bryan bryan 130 Oct 29 11:03 metadata_RhizCG_merged.txt -> /home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/..//home/bryan/RhizCG/data/MiSeq_amplicon/metadata_RhizCG_merged.txt
# lrwxrwxrwx 1 bryan bryan 143 Oct 29 11:03 otu_table_wtax.biom -> /home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning//home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/otu_table_wtax.biom
# -rw-rw-r-- 1 bryan bryan 22K Sep 30 06:25 heatmap_rank2.pdf

# %% [markdown]
# # Loading/editting OTU table

# %%
# %%R -i biomFile -i metadataFile -i workDir -i treeFile
# # loading
# setwd(workDir)
#
# ## biom file
# physeq = import_biom(biomFile, treeFile)
#
# ## loading sample metadata
# sample.data = import_qiime_sample_data(metadataFile)
# physeq = merge_phyloseq(physeq,sample.data)

# %%
# %%R
# #subset out positive and negative controls
# physeq = subset_samples(physeq, !is.na(DAP))
#
# print(physeq)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 11246 taxa and 240 samples ]
# sample_data() Sample Data:       [ 240 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 11246 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 11246 tips and 11245 internal nodes ]

# %% [markdown]
# ## Normalize samples and filter out taxa that are present in less than 25% of samples

# %%
# %%R
# # filtering/normalizing
# physeq.p = prune_samples(sampleSums(physeq) >= 10, physeq)
# physeq.snorm = transform_sample_counts(physeq.p, function(x) x/sum(x))
#
#
# physeq.thresh = filter_taxa(physeq.snorm, function(x) sum(x > 0) > (0.25 * length(x)), TRUE)
# print(physeq.snorm)
# #physeq.thresh = physeq.snorm
#
# print(physeq.thresh)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 11246 taxa and 240 samples ]
# sample_data() Sample Data:       [ 240 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 11246 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 11246 tips and 11245 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4567 taxa and 240 samples ]
# sample_data() Sample Data:       [ 240 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 4567 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4567 tips and 4566 internal nodes ]

# %% [markdown]
# ## Calculate pairwise weighted Unifrac distances between samples

# %%
# %%R
# registerDoParallel(cores=28)
# wunif.dist = distance(physeq.thresh,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %% [markdown]
# ## NMDS of w-Unifrac

# %%
# %%R -w 800 -h 350
#
# nmds = ordinate(physeq.thresh,
#                 method = "NMDS",
#                 distance = wunif.dist)
#
# p = plot_ordination(physeq.thresh, nmds, justDF = TRUE)
#
# ## generating plots
# p1 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(fill=Plant), pch = 21)
#         #scale_size(range=c(2,8))
#
# #p2 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         #geom_point(aes(fill=Plant, size = BD), pch=21) +
#         #scale_size(range=c(2,8))
#
# grid.arrange(p1, ncol=1)
# Out:
# Run 0 stress 0.140415
# Run 1 stress 0.1404106
# ... New best solution
# ... procrustes: rmse 0.001494914  max resid 0.02198213
# Run 2 stress 0.143657
# Run 3 stress 0.1484653
# Run 4 stress 0.1415763
# Run 5 stress 0.1444436
# Run 6 stress 0.1649838
# Run 7 stress 0.1554403
# Run 8 stress 0.1405445
# ... procrustes: rmse 0.00665887  max resid 0.09850524
# Run 9 stress 0.1550194
# Run 10 stress 0.1701604
# Run 11 stress 0.1430515
# Run 12 stress 0.1882716
# Run 13 stress 0.168058
# Run 14 stress 0.1548572
# Run 15 stress 0.1800603
# Run 16 stress 0.1723949
# Run 17 stress 0.1580073
# Run 18 stress 0.1735109
# Run 19 stress 0.1538208
# Run 20 stress 0.1842314

# %% [markdown]
# ## Import and join enzyme table
# * Caution: current enzyme table is not QC'd, need to replace

# %%
# %%R -w 750 -h 800
#
#
# ## generating plots
# p1 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(fill=Plant), size = 6, pch=21) +
#         facet_wrap(~ DAP) +
#         scale_size(range=c(2,8))
#
# p1

# %% [markdown]
# ## Subset just bare soils to analyze change with time

# %%
# %%R
#
# bare = subset_samples(physeq.thresh, Plant == "BARE")
# sample_data(bare)$DAP = factor(sample_data(bare)$DAP)

# %%
# %%R
# registerDoParallel(cores=28)
# wunif.dist = distance(bare,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R -w 800 -h 350
#
#
# nmds = ordinate(bare,
#                 method = "NMDS",
#                distance = wunif.dist)
#
# p = plot_ordination(bare, nmds, justDF = TRUE)
# Out:
# Run 0 stress 0.1544259
# Run 1 stress 0.1544265
# ... procrustes: rmse 0.0001578274  max resid 0.0007792517
# *** Solution reached

# %%
# %%R -w 750 -h 800
#
#
# ## generating plots
# p1 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(fill=DAP), size = 6, pch=21)
#
# p1

# %%
# %%R
# df = as(sample_data(bare), "data.frame")
# d = wunif.dist
# bareadonis = adonis(d ~ DAP, df)
# bareadonis
# Out:
# Call:
# adonis(formula = d ~ DAP, data = df)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs   MeanSqs F.Model      R2 Pr(>F)
# DAP        7   0.09194 0.0131347  3.1979 0.28558  0.001 ***
# Residuals 56   0.23001 0.0041073         0.71442
# Total     63   0.32195                   1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Subset just plants to evaluate variation without bare soil

# %%
# %%R
#
# plant = subset_samples(physeq.thresh, Plant != "BARE")
# sample_data(plant)$DAP = factor(sample_data(plant)$DAP)
# plant
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4567 taxa and 176 samples ]
# sample_data() Sample Data:       [ 176 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 4567 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4567 tips and 4566 internal nodes ]

# %% [markdown]
# ### subset just plants from Nneg and Npos

# %%
# %%R
# colnames(sample_data(plant))
# Out:
#  [1] "X.sample"            "Library"             "Primer_Plate"
#  [4] "Primer_Well_ID"      "primerFR_ID_byPlate" "primerFR_ID_total"
#  [7] "barcode_ID"          "PlotID"              "Plant"
# [10] "Plot"                "Treatment"           "Rep"
# [13] "DAP"                 "Sampling"            "PlantSample"
# [16] "Type"                "Grass_Broad"         "Status"
# [19] "Subfamily"           "fwd_barcode"         "rev_barcode"

# %%
# %%R
#
# plantNneg = subset_samples(plant, Treatment == "Nneg")
# sample_data(plantNneg)$DAP = factor(sample_data(plantNneg)$DAP)
# plantNneg
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4567 taxa and 88 samples ]
# sample_data() Sample Data:       [ 88 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 4567 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4567 tips and 4566 internal nodes ]

# %%
# %%R
#
# plantNpos = subset_samples(plant, Treatment == "Npos")
# sample_data(plantNpos)$DAP = factor(sample_data(plantNpos)$DAP)
# plantNpos
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4567 taxa and 88 samples ]
# sample_data() Sample Data:       [ 88 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 4567 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4567 tips and 4566 internal nodes ]

# %% [markdown]
# ## subset for particular day to test significance of plant while controlling for date

# %%
# %%R
# plant88 = subset_samples(plantNneg, DAP == 88)
# plant88
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4567 taxa and 16 samples ]
# sample_data() Sample Data:       [ 16 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 4567 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4567 tips and 4566 internal nodes ]

# %% [markdown]
# ### Create distance matrix of weighted unifrac for each plant subset

# %%
# %%R
# registerDoParallel(cores=28)
# plant.wunif.dist = distance(plant,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# registerDoParallel(cores=28)
# plantNneg.wunif.dist = distance(plantNneg,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# registerDoParallel(cores=28)
# plantNpos.wunif.dist = distance(plantNpos,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R
# registerDoParallel(cores=28)
# plant88.wunif.dist = distance(plant88,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R -w 750 -h 800
# #Day 84
#
# plantnmds = ordinate(plant88,
#                 method = "NMDS",
#                distance = plant88.wunif.dist)
#
# p = plot_ordination(plant88, plantnmds, justDF = TRUE)
#
# ## generating plots
# p1 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(fill=Plant), size = 6, pch=21)
#
# p1
# Out:
# Run 0 stress 0.09863175
# Run 1 stress 0.09863176
# ... procrustes: rmse 2.271891e-05  max resid 5.569873e-05
# *** Solution reached

# %% [markdown]
# ### Ordinate each subset

# %%
# %%R -w 750 -h 800
# #Whole plant set
#
# plantnmds = ordinate(plant,
#                 method = "NMDS",
#                distance = plant.wunif.dist)
#
# p = plot_ordination(plant, plantnmds, justDF = TRUE)
#
# ## generating plots
# p1 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(fill=Plant), size = 6, pch=21)
#
# p1
# Out:
# Run 0 stress 0.1710848
# Run 1 stress 0.1746419
# Run 2 stress 0.1710837
# ... New best solution
# ... procrustes: rmse 0.0002298753  max resid 0.002569713
# *** Solution reached

# %%
# %%R
# p
# Out:
#                          NMDS1         NMDS2          X.sample Library
# sample5-1.22_Nneg -0.061407351 -4.632063e-02 sample5-1.22_Nneg       1
# sample6-4.12_Npos -0.025928480 -2.225386e-02 sample6-4.12_Npos       1
# sample4-1.03_Npos -0.072246675 -4.463589e-02 sample4-1.03_Npos       1
# sample5-2.06_Npos -0.002869192 -2.161476e-02 sample5-2.06_Npos       1
# sample5-4.08_Npos -0.014073017 -1.037087e-02 sample5-4.08_Npos       1
# sample5-4.28_Npos -0.035823772 -4.982878e-02 sample5-4.28_Npos       1
# sample5-1.29_Npos -0.104045212  6.866954e-02 sample5-1.29_Npos       1
# sample4-2.02_Nneg -0.076096352 -1.523887e-02 sample4-2.02_Nneg       1
# sample4-4.21_Nneg -0.048765630 -2.563128e-02 sample4-4.21_Nneg       1
# sample6-2.13_Npos  0.023024724  1.211731e-02 sample6-2.13_Npos       1
# sample5-2.29_Nneg -0.006580359 -1.854201e-02 sample5-2.29_Nneg       1
# sample5-2.06_Nneg -0.005707011 -6.520550e-03 sample5-2.06_Nneg       1
# sample1-2.23_Nneg -0.051860593 -8.702364e-02 sample1-2.23_Nneg       1
# sample6-2.26_Nneg  0.029140422  5.746832e-03 sample6-2.26_Nneg       1
# sample6-3.18_Nneg  0.019368856 -4.617312e-03 sample6-3.18_Nneg       1
# sample5-3.13_Nneg  0.013207434 -1.716612e-02 sample5-3.13_Nneg       1
# sample2-2.08_Nneg -0.055833332  4.601103e-02 sample2-2.08_Nneg       1
# sample5-1.17_Nneg -0.005236643 -1.103095e-01 sample5-1.17_Nneg       1
# sample6-3.01_Npos -0.013958954 -8.880927e-03 sample6-3.01_Npos       1
# sample3-2.03_Nneg -0.173005616  1.003455e-01 sample3-2.03_Nneg       1
# sample5-4.08_Nneg  0.030141060 -1.039329e-02 sample5-4.08_Nneg       1
# sample5-4.05_Npos  0.103176618  8.051052e-03 sample5-4.05_Npos       1
# sample6-2.16_Npos  0.022774428  5.905547e-03 sample6-2.16_Npos       1
# sample1-4.24_Nneg -0.066813716 -1.135309e-01 sample1-4.24_Nneg       1
# sample5-4.28_Nneg -0.084549153 -4.471212e-02 sample5-4.28_Nneg       1
# sample6-2.13_Nneg  0.048772747 -4.780184e-03 sample6-2.13_Nneg       1
# sample1-3.08_Npos -0.073555600 -9.140333e-02 sample1-3.08_Npos       1
# sample6-3.04_Npos -0.046466500  7.242628e-03 sample6-3.04_Npos       1
# sample4-1.03_Nneg -0.050604671 -3.016202e-02 sample4-1.03_Nneg       1
# sample8-3.03_Nneg  0.017845043 -7.757786e-02 sample8-3.03_Nneg       2
#                   Primer_Plate Primer_Well_ID primerFR_ID_byPlate
# sample5-1.22_Nneg            1             A4                  25
# sample6-4.12_Npos            2             H3                  24
# sample4-1.03_Npos            1             B3                  18
# sample5-2.06_Npos            2             D1                   4
# sample5-4.08_Npos            2             H1                   8
# sample5-4.28_Npos            1             H4                  32
# sample5-1.29_Npos            1             B5                  34
# sample4-2.02_Nneg            1             C3                  19
# sample4-4.21_Nneg            1             G3                  23
# sample6-2.13_Npos            2             D3                  20
# sample5-2.29_Nneg            1             C4                  27
# sample5-2.06_Nneg            2             C1                   3
# sample1-2.23_Nneg            1             C1                   3
# sample6-2.26_Nneg            2             C7                  51
# sample6-3.18_Nneg            2             E7                  53
# sample5-3.13_Nneg            2             E1                   5
# sample2-2.08_Nneg            1             C7                  51
# sample5-1.17_Nneg            2             A1                   1
# sample6-3.01_Npos            2             F5                  38
# sample3-2.03_Nneg            1             C8                  59
# sample5-4.08_Nneg            2             G1                   7
# sample5-4.05_Npos            1             H6                  48
# sample6-2.16_Npos            2             D5                  36
# sample1-4.24_Nneg            1             G1                   7
# sample5-4.28_Nneg            1             G4                  31
# sample6-2.13_Nneg            2             C3                  19
# sample1-3.08_Npos            1             F1                   6
# sample6-3.04_Npos            2             F3                  22
# sample4-1.03_Nneg            1             A3                  17
# sample5-1.22_Npos            1             B4                  26
# sample6-1.15_Nneg            2             A5                  33
# sample5-2.11_Nneg            1             C6                  43
# sample4-4.21_Npos            1             H3                  24
# sample6-4.12_Nneg            2             G3                  23
# sample5-1.25_Nneg            1             A2                   9
# sample6-4.17_Npos            2             H5                  40
# sample6-3.04_Nneg            2             E3                  21
# sample5-3.27_Nneg            1             E4                  29
# sample6-1.15_Npos            2             B5                  34
# sample5-3.11_Nneg            1             E5                  37
# sample5-2.11_Npos            1             D6                  44
# sample5-3.17_Npos            1             F2                  14
# sample5-1.17_Npos            2             B1                   2
# sample3-3.06_Nneg            1             E8                  61
# sample2-3.05_Nneg            1             E7                  53
# sample6-1.07_Npos            2             B3                  18
# sample5-3.13_Npos            2             F1                   6
# sample5-4.09_Npos            1             H2                  16
# sample6-4.30_Npos            2             H7                  56
# sample6-1.12_Npos            2             B7                  50
# sample6-3.18_Npos            2             F7                  54
# sample1-4.24_Npos            1             H1                   8
# sample3-3.06_Npos            1             F8                  62
# sample5-4.06_Nneg            1             G5                  39
# sample6-4.17_Nneg            2             G5                  39
# sample5-3.11_Npos            1             F5                  38
# sample5-3.16_Npos            1             F6                  46
# sample1-1.27_Npos            1             B1                   2
# sample5-4.05_Nneg            1             G6                  47
# sample5-1.25_Npos            1             B2                  10
# sample6-1.07_Nneg            2             A3                  17
# sample5-2.18_Nneg            1             C5                  35
# sample6-2.26_Npos            2             D7                  52
# sample5-3.16_Nneg            1             E6                  45
# sample5-4.06_Npos            1             H5                  40
# sample3-1.09_Npos            1             B8                  58
# sample3-4.15_Nneg            1             G8                  63
# sample5-2.15_Npos            1             D2                  12
# sample6-4.30_Nneg            2             G7                  55
# sample5-3.27_Npos            1             F4                  30
# sample6-1.12_Nneg            2             A7                  49
# sample4-3.10_Npos            1             F3                  22
# sample6-2.16_Nneg            2             C5                  35
# sample5-3.17_Nneg            1             E2                  13
# sample5-1.16_Npos            1             B6                  42
# sample3-2.03_Npos            1             D8                  60
# sample1-2.23_Npos            1             D1                   4
# sample5-4.09_Nneg            1             G2                  15
# sample2-2.08_Npos            1             D7                  52
# sample2-3.05_Npos            1             F7                  54
# sample2-1.08_Nneg            1             A7                  49
# sample3-4.15_Npos            1             H8                  64
# sample6-3.01_Nneg            2             E5                  37
# sample5-1.16_Nneg            1             A6                  41
# sample2-1.08_Npos            1             B7                  50
# sample1-1.27_Nneg            1             A1                   1
# sample4-3.10_Nneg            1             E3                  21
# sample5-1.29_Nneg            1             A5                  33
# sample4-2.02_Npos            1             D3                  20
# sample5-2.15_Nneg            1             C2                  11
# sample1-3.08_Nneg            1             E1                   5
# sample3-1.09_Nneg            1             A8                  57
# sample2-4.25_Nneg            1             G7                  55
# sample5-2.18_Npos            1             D5                  36
# sample5-2.29_Npos            1             D4                  28
# sample2-4.25_Npos            1             H7                  56
# sample7-1.13_Npos            1             F4                  30
# sample7-4.02_Npos            1             H3                  24
# sample8-2.07_Nneg            1             C8                  59
# sample7-4.02_Nneg            1             G3                  23
# sample3-1.20_Npos            1            B12                  90
# sample7-1.04_Npos            1             C3                  19
# sample8-4.23_Nneg            1            G10                  79
# sample7-3.19_Nneg            1             H4                  32
# sample7-4.03_Npos            1             B4                  26
# sample8-1.14_Npos            2             B2                  10
# sample7-2.12_Npos            1             E2                  13
# sample3-4.18_Nneg            1             A3                  17
# sample8-3.28_Npos            2             F2                  14
# sample6-1.18_Nneg            1             B9                  66
# sample7-2.12_Nneg            1             C2                  11
# sample7-2.28_Nneg            1             D5                  36
# sample2-2.10_Nneg            1             A2                   9
# sample8-2.17_Npos            1            D11                  84
# sample3-2.19_Npos            1            C12                  91
# sample8-2.25_Nneg            1            C10                  75
# sample6-3.09_Nneg            1             E9                  69
# sample2-3.20_Npos            2             F1                   6
# sample2-3.20_Nneg            2             E1                   5
# sample3-3.30_Npos            1            E12                  93
# sample8-4.23_Npos            1            H10                  80
# sample8-3.03_Npos            1             F8                  62
# sample6-4.13_Npos            1             H9                  72
# sample8-4.07_Nneg            2             G2                  15
# sample6-1.18_Npos            1             A9                  65
# sample7-3.25_Npos            1             F3                  22
# sample8-3.23_Nneg            1            E11                  85
# sample7-2.30_Npos            1             G4                  31
# sample7-1.13_Nneg            1             E4                  29
# sample8-2.22_Npos            2             D2                  12
# sample7-2.30_Nneg            1             C4                  27
# sample2-1.24_Npos            2             B1                   2
# sample6-2.14_Npos            1             D9                  68
# sample8-1.14_Nneg            2             A2                   9
# sample3-1.20_Nneg            1            A12                  89
# sample2-4.16_Npos            2             H1                   8
# sample8-1.19_Npos            1             B8                  58
# sample7-2.28_Npos            1             D3                  20
# sample7-3.19_Npos            1             A5                  33
# sample7-1.04_Nneg            1             B3                  18
# sample8-1.19_Nneg            1             A8                  57
# sample7-3.12_Nneg            1             F5                  38
# sample7-4.03_Nneg            1             E5                  37
# sample7-1.28_Npos            1             G2                  15
# sample8-1.10_Npos            1            B11                  82
# sample7-1.28_Nneg            1             F2                  14
# sample7-3.25_Nneg            1             E3                  21
# sample2-1.24_Nneg            2             A1                   1
# sample8-1.10_Nneg            1            A11                  81
# sample8-4.01_Npos            1             H8                  64
# sample7-4.14_Npos            1             C5                  35
# sample8-4.01_Nneg            1             G8                  63
# sample8-2.17_Nneg            1            C11                  83
# sample6-3.09_Npos            1             F9                  70
# sample8-2.22_Nneg            2             C2                  11
# sample8-3.29_Nneg            1            E10                  77
# sample8-4.07_Npos            2             H2                  16
# sample8-1.23_Npos            1            B10                  74
# sample8-3.28_Nneg            2             E2                  13
# sample2-2.10_Npos            2             D1                   4
# sample6-4.13_Nneg            1             G9                  71
# sample3-2.19_Nneg            1             H2                  16
# sample2-4.16_Nneg            2             G1                   7
# sample7-3.12_Npos            1             D2                  12
# sample8-3.23_Npos            1            F11                  86
# sample8-3.29_Npos            1            F10                  78
# sample8-1.23_Nneg            1            A10                  73
# sample6-2.14_Nneg            1             C9                  67
# sample8-4.04_Nneg            1            G11                  87
# sample3-3.30_Nneg            1            D12                  92
# sample7-4.14_Nneg            1             B5                  34
# sample8-2.07_Npos            1             D8                  60
# sample3-4.18_Npos            1             D4                  28
# sample8-4.04_Npos            1            H11                  88
# sample8-2.25_Npos            1            D10                  76
# sample8-3.03_Nneg            1             E8                  61
#                   primerFR_ID_total barcode_ID    PlotID  Plant Plot Treatment
# sample5-1.22_Nneg                25         25 1.22_Nneg 75-062 1.22      Nneg
# sample6-4.12_Npos               120        120 4.12_Npos   Oh7B 4.12      Npos
# sample4-1.03_Npos                18         18 1.03_Npos  SETFA 1.03      Npos
# sample5-2.06_Npos               100        100 2.06_Npos   MS71 2.06      Npos
# sample5-4.08_Npos               104        104 4.08_Npos   MS71 4.08      Npos
# sample5-4.28_Npos                32         32 4.28_Npos 75-062 4.28      Npos
# sample5-1.29_Npos                34         34 1.29_Npos  ERATE 1.29      Npos
# sample4-2.02_Nneg                19         19 2.02_Nneg  SETFA 2.02      Nneg
# sample4-4.21_Nneg                23         23 4.21_Nneg  SETFA 4.21      Nneg
# sample6-2.13_Npos               116        116 2.13_Npos   Oh7B 2.13      Npos
# sample5-2.29_Nneg                27         27 2.29_Nneg 75-062 2.29      Nneg
# sample5-2.06_Nneg                99         99 2.06_Nneg   MS71 2.06      Nneg
# sample1-2.23_Nneg                 3          3 2.23_Nneg  FAGES 2.23      Nneg
# sample6-2.26_Nneg               147        147 2.26_Nneg    B73 2.26      Nneg
# sample6-3.18_Nneg               149        149 3.18_Nneg    B73 3.18      Nneg
# sample5-3.13_Nneg               101        101 3.13_Nneg   MS71 3.13      Nneg
# sample2-2.08_Nneg                51         51 2.08_Nneg  AMAPO 2.08      Nneg
# sample5-1.17_Nneg                97         97 1.17_Nneg   MS71 1.17      Nneg
# sample6-3.01_Npos               134        134 3.01_Npos    B97 3.01      Npos
# sample3-2.03_Nneg                59         59 2.03_Nneg  GLYMA 2.03      Nneg
# sample5-4.08_Nneg               103        103 4.08_Nneg   MS71 4.08      Nneg
# sample5-4.05_Npos                48         48 4.05_Npos    H99 4.05      Npos
# sample6-2.16_Npos               132        132 2.16_Npos    B97 2.16      Npos
# sample1-4.24_Nneg                 7          7 4.24_Nneg  FAGES 4.24      Nneg
# sample5-4.28_Nneg                31         31 4.28_Nneg 75-062 4.28      Nneg
# sample6-2.13_Nneg               115        115 2.13_Nneg   Oh7B 2.13      Nneg
# sample1-3.08_Npos                 6          6 3.08_Npos  FAGES 3.08      Npos
# sample6-3.04_Npos               118        118 3.04_Npos   Oh7B 3.04      Npos
# sample4-1.03_Nneg                17         17 1.03_Nneg  SETFA 1.03      Nneg
# sample5-1.22_Npos                26         26 1.22_Npos 75-062 1.22      Npos
# sample6-1.15_Nneg               129        129 1.15_Nneg    B97 1.15      Nneg
# sample5-2.11_Nneg                43         43 2.11_Nneg    H99 2.11      Nneg
# sample4-4.21_Npos                24         24 4.21_Npos  SETFA 4.21      Npos
# sample6-4.12_Nneg               119        119 4.12_Nneg   Oh7B 4.12      Nneg
# sample5-1.25_Nneg                 9          9 1.25_Nneg  Il14H 1.25      Nneg
# sample6-4.17_Npos               136        136 4.17_Npos    B97 4.17      Npos
# sample6-3.04_Nneg               117        117 3.04_Nneg   Oh7B 3.04      Nneg
# sample5-3.27_Nneg                29         29 3.27_Nneg 75-062 3.27      Nneg
# sample6-1.15_Npos               130        130 1.15_Npos    B97 1.15      Npos
# sample5-3.11_Nneg                37         37 3.11_Nneg  ERATE 3.11      Nneg
# sample5-2.11_Npos                44         44 2.11_Npos    H99 2.11      Npos
# sample5-3.17_Npos                14         14 3.17_Npos  Il14H 3.17      Npos
# sample5-1.17_Npos                98         98 1.17_Npos   MS71 1.17      Npos
# sample3-3.06_Nneg                61         61 3.06_Nneg  GLYMA 3.06      Nneg
# sample2-3.05_Nneg                53         53 3.05_Nneg  AMAPO 3.05      Nneg
# sample6-1.07_Npos               114        114 1.07_Npos   Oh7B 1.07      Npos
# sample5-3.13_Npos               102        102 3.13_Npos   MS71 3.13      Npos
# sample5-4.09_Npos                16         16 4.09_Npos  Il14H 4.09      Npos
# sample6-4.30_Npos               152        152 4.30_Npos    B73 4.30      Npos
# sample6-1.12_Npos               146        146 1.12_Npos    B73 1.12      Npos
# sample6-3.18_Npos               150        150 3.18_Npos    B73 3.18      Npos
# sample1-4.24_Npos                 8          8 4.24_Npos  FAGES 4.24      Npos
# sample3-3.06_Npos                62         62 3.06_Npos  GLYMA 3.06      Npos
# sample5-4.06_Nneg                39         39 4.06_Nneg  ERATE 4.06      Nneg
# sample6-4.17_Nneg               135        135 4.17_Nneg    B97 4.17      Nneg
# sample5-3.11_Npos                38         38 3.11_Npos  ERATE 3.11      Npos
# sample5-3.16_Npos                46         46 3.16_Npos    H99 3.16      Npos
# sample1-1.27_Npos                 2          2 1.27_Npos  FAGES 1.27      Npos
# sample5-4.05_Nneg                47         47 4.05_Nneg    H99 4.05      Nneg
# sample5-1.25_Npos                10         10 1.25_Npos  Il14H 1.25      Npos
# sample6-1.07_Nneg               113        113 1.07_Nneg   Oh7B 1.07      Nneg
# sample5-2.18_Nneg                35         35 2.18_Nneg  ERATE 2.18      Nneg
# sample6-2.26_Npos               148        148 2.26_Npos    B73 2.26      Npos
# sample5-3.16_Nneg                45         45 3.16_Nneg    H99 3.16      Nneg
# sample5-4.06_Npos                40         40 4.06_Npos  ERATE 4.06      Npos
# sample3-1.09_Npos                58         58 1.09_Npos  GLYMA 1.09      Npos
# sample3-4.15_Nneg                63         63 4.15_Nneg  GLYMA 4.15      Nneg
# sample5-2.15_Npos                12         12 2.15_Npos  Il14H 2.15      Npos
# sample6-4.30_Nneg               151        151 4.30_Nneg    B73 4.30      Nneg
# sample5-3.27_Npos                30         30 3.27_Npos 75-062 3.27      Npos
# sample6-1.12_Nneg               145        145 1.12_Nneg    B73 1.12      Nneg
# sample4-3.10_Npos                22         22 3.10_Npos  SETFA 3.10      Npos
# sample6-2.16_Nneg               131        131 2.16_Nneg    B97 2.16      Nneg
# sample5-3.17_Nneg                13         13 3.17_Nneg  Il14H 3.17      Nneg
# sample5-1.16_Npos                42         42 1.16_Npos    H99 1.16      Npos
# sample3-2.03_Npos                60         60 2.03_Npos  GLYMA 2.03      Npos
# sample1-2.23_Npos                 4          4 2.23_Npos  FAGES 2.23      Npos
# sample5-4.09_Nneg                15         15 4.09_Nneg  Il14H 4.09      Nneg
# sample2-2.08_Npos                52         52 2.08_Npos  AMAPO 2.08      Npos
# sample2-3.05_Npos                54         54 3.05_Npos  AMAPO 3.05      Npos
# sample2-1.08_Nneg                49         49 1.08_Nneg  AMAPO 1.08      Nneg
# sample3-4.15_Npos                64         64 4.15_Npos  GLYMA 4.15      Npos
# sample6-3.01_Nneg               133        133 3.01_Nneg    B97 3.01      Nneg
# sample5-1.16_Nneg                41         41 1.16_Nneg    H99 1.16      Nneg
# sample2-1.08_Npos                50         50 1.08_Npos  AMAPO 1.08      Npos
# sample1-1.27_Nneg                 1          1 1.27_Nneg  FAGES 1.27      Nneg
# sample4-3.10_Nneg                21         21 3.10_Nneg  SETFA 3.10      Nneg
# sample5-1.29_Nneg                33         33 1.29_Nneg  ERATE 1.29      Nneg
# sample4-2.02_Npos                20         20 2.02_Npos  SETFA 2.02      Npos
# sample5-2.15_Nneg                11         11 2.15_Nneg  Il14H 2.15      Nneg
# sample1-3.08_Nneg                 5          5 3.08_Nneg  FAGES 3.08      Nneg
# sample3-1.09_Nneg                57         57 1.09_Nneg  GLYMA 1.09      Nneg
# sample2-4.25_Nneg                55         55 4.25_Nneg  AMAPO 4.25      Nneg
# sample5-2.18_Npos                36         36 2.18_Npos  ERATE 2.18      Npos
# sample5-2.29_Npos                28         28 2.29_Npos 75-062 2.29      Npos
# sample2-4.25_Npos                56         56 4.25_Npos  AMAPO 4.25      Npos
# sample7-1.13_Npos                30         30 1.13_Npos  SORBI 1.13      Npos
# sample7-4.02_Npos                24         24 4.02_Npos SORSUD 4.02      Npos
# sample8-2.07_Nneg                59         59 2.07_Nneg  ELCOR 2.07      Nneg
# sample7-4.02_Nneg                23         23 4.02_Nneg SORSUD 4.02      Nneg
# sample3-1.20_Npos                90         90 1.20_Npos  ABUTH 1.20      Npos
# sample7-1.04_Npos                19         19 1.04_Npos SORSUD 1.04      Npos
# sample8-4.23_Nneg                79         79 4.23_Nneg    Ki3 4.23      Nneg
# sample7-3.19_Nneg                32         32 3.19_Nneg  SORBI 3.19      Nneg
# sample7-4.03_Npos                26         26 4.03_Npos  HELAN 4.03      Npos
# sample8-1.14_Npos               106        106 1.14_Npos  Tx303 1.14      Npos
# sample7-2.12_Npos                13         13 2.12_Npos  HELAN 2.12      Npos
# sample3-4.18_Nneg                17         17 4.18_Nneg  ABUTH 4.18      Nneg
# sample8-3.28_Npos               110        110 3.28_Npos  Tx303 3.28      Npos
# sample6-1.18_Nneg                66         66 1.18_Nneg  Hp301 1.18      Nneg
# sample7-2.12_Nneg                11         11 2.12_Nneg  HELAN 2.12      Nneg
# sample7-2.28_Nneg                36         36 2.28_Nneg SORSUD 2.28      Nneg
# sample2-2.10_Nneg                 9          9 2.10_Nneg  ECHCG 2.10      Nneg
# sample8-2.17_Npos                84         84 2.17_Npos   Mo18 2.17      Npos
# sample3-2.19_Npos                91         91 2.19_Npos  ABUTH 2.19      Npos
# sample8-2.25_Nneg                75         75 2.25_Nneg    Ki3 2.25      Nneg
# sample6-3.09_Nneg                69         69 3.09_Nneg  Hp301 3.09      Nneg
# sample2-3.20_Npos               102        102 3.20_Npos  ECHCG 3.20      Npos
# sample2-3.20_Nneg               101        101 3.20_Nneg  ECHCG 3.20      Nneg
# sample3-3.30_Npos                93         93 3.30_Npos  ABUTH 3.30      Npos
# sample8-4.23_Npos                80         80 4.23_Npos    Ki3 4.23      Npos
# sample8-3.03_Npos                62         62 3.03_Npos  ELCOR 3.03      Npos
# sample6-4.13_Npos                72         72 4.13_Npos  Hp301 4.13      Npos
# sample8-4.07_Nneg               111        111 4.07_Nneg  Tx303 4.07      Nneg
# sample6-1.18_Npos                65         65 1.18_Npos  Hp301 1.18      Npos
# sample7-3.25_Npos                22         22 3.25_Npos SORSUD 3.25      Npos
# sample8-3.23_Nneg                85         85 3.23_Nneg   Mo18 3.23      Nneg
# sample7-2.30_Npos                31         31 2.30_Npos  SORBI 2.30      Npos
# sample7-1.13_Nneg                29         29 1.13_Nneg  SORBI 1.13      Nneg
# sample8-2.22_Npos               108        108 2.22_Npos  Tx303 2.22      Npos
# sample7-2.30_Nneg                27         27 2.30_Nneg  SORBI 2.30      Nneg
# sample2-1.24_Npos                98         98 1.24_Npos  ECHCG 1.24      Npos
# sample6-2.14_Npos                68         68 2.14_Npos  Hp301 2.14      Npos
# sample8-1.14_Nneg               105        105 1.14_Nneg  Tx303 1.14      Nneg
# sample3-1.20_Nneg                89         89 1.20_Nneg  ABUTH 1.20      Nneg
# sample2-4.16_Npos               104        104 4.16_Npos  ECHCG 4.16      Npos
# sample8-1.19_Npos                58         58 1.19_Npos  ELCOR 1.19      Npos
# sample7-2.28_Npos                20         20 2.28_Npos SORSUD 2.28      Npos
# sample7-3.19_Npos                33         33 3.19_Npos  SORBI 3.19      Npos
# sample7-1.04_Nneg                18         18 1.04_Nneg SORSUD 1.04      Nneg
# sample8-1.19_Nneg                57         57 1.19_Nneg  ELCOR 1.19      Nneg
# sample7-3.12_Nneg                38         38 3.12_Nneg  HELAN 3.12      Nneg
# sample7-4.03_Nneg                37         37 4.03_Nneg  HELAN 4.03      Nneg
# sample7-1.28_Npos                15         15 1.28_Npos  HELAN 1.28      Npos
# sample8-1.10_Npos                82         82 1.10_Npos   Mo18 1.10      Npos
# sample7-1.28_Nneg                14         14 1.28_Nneg  HELAN 1.28      Nneg
# sample7-3.25_Nneg                21         21 3.25_Nneg SORSUD 3.25      Nneg
# sample2-1.24_Nneg                97         97 1.24_Nneg  ECHCG 1.24      Nneg
# sample8-1.10_Nneg                81         81 1.10_Nneg   Mo18 1.10      Nneg
# sample8-4.01_Npos                64         64 4.01_Npos  ELCOR 4.01      Npos
# sample7-4.14_Npos                35         35 4.14_Npos  SORBI 4.14      Npos
# sample8-4.01_Nneg                63         63 4.01_Nneg  ELCOR 4.01      Nneg
# sample8-2.17_Nneg                83         83 2.17_Nneg   Mo18 2.17      Nneg
# sample6-3.09_Npos                70         70 3.09_Npos  Hp301 3.09      Npos
# sample8-2.22_Nneg               107        107 2.22_Nneg  Tx303 2.22      Nneg
# sample8-3.29_Nneg                77         77 3.29_Nneg    Ki3 3.29      Nneg
# sample8-4.07_Npos               112        112 4.07_Npos  Tx303 4.07      Npos
# sample8-1.23_Npos                74         74 1.23_Npos    Ki3 1.23      Npos
# sample8-3.28_Nneg               109        109 3.28_Nneg  Tx303 3.28      Nneg
# sample2-2.10_Npos               100        100 2.10_Npos  ECHCG 2.10      Npos
# sample6-4.13_Nneg                71         71 4.13_Nneg  Hp301 4.13      Nneg
# sample3-2.19_Nneg                16         16 2.19_Nneg  ABUTH 2.19      Nneg
# sample2-4.16_Nneg               103        103 4.16_Nneg  ECHCG 4.16      Nneg
# sample7-3.12_Npos                12         12 3.12_Npos  HELAN 3.12      Npos
# sample8-3.23_Npos                86         86 3.23_Npos   Mo18 3.23      Npos
# sample8-3.29_Npos                78         78 3.29_Npos    Ki3 3.29      Npos
# sample8-1.23_Nneg                73         73 1.23_Nneg    Ki3 1.23      Nneg
# sample6-2.14_Nneg                67         67 2.14_Nneg  Hp301 2.14      Nneg
# sample8-4.04_Nneg                87         87 4.04_Nneg   Mo18 4.04      Nneg
# sample3-3.30_Nneg                92         92 3.30_Nneg  ABUTH 3.30      Nneg
# sample7-4.14_Nneg                34         34 4.14_Nneg  SORBI 4.14      Nneg
# sample8-2.07_Npos                60         60 2.07_Npos  ELCOR 2.07      Npos
# sample3-4.18_Npos                28         28 4.18_Npos  ABUTH 4.18      Npos
# sample8-4.04_Npos                88         88 4.04_Npos   Mo18 4.04      Npos
# sample8-2.25_Npos                76         76 2.25_Npos    Ki3 2.25      Npos
# sample8-3.03_Nneg                61         61 3.03_Nneg  ELCOR 3.03      Nneg
#                   Rep DAP Sampling    PlantSample      Type Grass_Broad Status
# sample5-1.22_Nneg   1  72  sample5 75-062_sample5     Maize     Monocot   Crop
# sample6-4.12_Npos   4  79  sample6   Oh7B_sample6     Maize     Monocot   Crop
# sample4-1.03_Npos   1  61  sample4  SETFA_sample4  C4_Grass     Monocot   Weed
# sample5-2.06_Npos   2  72  sample5   MS71_sample5     Maize     Monocot   Crop
# sample5-4.08_Npos   4  72  sample5   MS71_sample5     Maize     Monocot   Crop
# sample5-4.28_Npos   4  72  sample5 75-062_sample5     Maize     Monocot   Crop
# sample5-1.29_Npos   1  72  sample5  ERATE_sample5  C4_Grass     Monocot   Crop
# sample4-2.02_Nneg   2  61  sample4  SETFA_sample4  C4_Grass     Monocot   Weed
# sample4-4.21_Nneg   4  61  sample4  SETFA_sample4  C4_Grass     Monocot   Weed
# sample6-2.13_Npos   2  79  sample6   Oh7B_sample6     Maize     Monocot   Crop
# sample5-2.29_Nneg   2  72  sample5 75-062_sample5     Maize     Monocot   Crop
# sample5-2.06_Nneg   2  72  sample5   MS71_sample5     Maize     Monocot   Crop
# sample1-2.23_Nneg   2  36  sample1  FAGES_sample1  Dicot-NM       Dicot   Crop
# sample6-2.26_Nneg   2  79  sample6    B73_sample6     Maize     Monocot   Crop
# sample6-3.18_Nneg   3  79  sample6    B73_sample6     Maize     Monocot   Crop
# sample5-3.13_Nneg   3  72  sample5   MS71_sample5     Maize     Monocot   Crop
# sample2-2.08_Nneg   2  53  sample2  AMAPO_sample2  Dicot-NM       Dicot   Weed
# sample5-1.17_Nneg   1  72  sample5   MS71_sample5     Maize     Monocot   Crop
# sample6-3.01_Npos   3  79  sample6    B97_sample6     Maize     Monocot   Crop
# sample3-2.03_Nneg   2  57  sample3  GLYMA_sample3    Legume       Dicot   Crop
# sample5-4.08_Nneg   4  72  sample5   MS71_sample5     Maize     Monocot   Crop
# sample5-4.05_Npos   4  72  sample5    H99_sample5     Maize     Monocot   Crop
# sample6-2.16_Npos   2  79  sample6    B97_sample6     Maize     Monocot   Crop
# sample1-4.24_Nneg   4  36  sample1  FAGES_sample1  Dicot-NM       Dicot   Crop
# sample5-4.28_Nneg   4  72  sample5 75-062_sample5     Maize     Monocot   Crop
# sample6-2.13_Nneg   2  79  sample6   Oh7B_sample6     Maize     Monocot   Crop
# sample1-3.08_Npos   3  36  sample1  FAGES_sample1  Dicot-NM       Dicot   Crop
# sample6-3.04_Npos   3  79  sample6   Oh7B_sample6     Maize     Monocot   Crop
# sample4-1.03_Nneg   1  61  sample4  SETFA_sample4  C4_Grass     Monocot   Weed
# sample5-1.22_Npos   1  72  sample5 75-062_sample5     Maize     Monocot   Crop
# sample6-1.15_Nneg   1  79  sample6    B97_sample6     Maize     Monocot   Crop
# sample5-2.11_Nneg   2  72  sample5    H99_sample5     Maize     Monocot   Crop
# sample4-4.21_Npos   4  61  sample4  SETFA_sample4  C4_Grass     Monocot   Weed
# sample6-4.12_Nneg   4  79  sample6   Oh7B_sample6     Maize     Monocot   Crop
# sample5-1.25_Nneg   1  72  sample5  Il14H_sample5     Maize     Monocot   Crop
# sample6-4.17_Npos   4  79  sample6    B97_sample6     Maize     Monocot   Crop
# sample6-3.04_Nneg   3  79  sample6   Oh7B_sample6     Maize     Monocot   Crop
# sample5-3.27_Nneg   3  72  sample5 75-062_sample5     Maize     Monocot   Crop
# sample6-1.15_Npos   1  79  sample6    B97_sample6     Maize     Monocot   Crop
# sample5-3.11_Nneg   3  72  sample5  ERATE_sample5  C4_Grass     Monocot   Crop
# sample5-2.11_Npos   2  72  sample5    H99_sample5     Maize     Monocot   Crop
# sample5-3.17_Npos   3  72  sample5  Il14H_sample5     Maize     Monocot   Crop
# sample5-1.17_Npos   1  72  sample5   MS71_sample5     Maize     Monocot   Crop
# sample3-3.06_Nneg   3  57  sample3  GLYMA_sample3    Legume       Dicot   Crop
# sample2-3.05_Nneg   3  53  sample2  AMAPO_sample2  Dicot-NM       Dicot   Weed
# sample6-1.07_Npos   1  79  sample6   Oh7B_sample6     Maize     Monocot   Crop
# sample5-3.13_Npos   3  72  sample5   MS71_sample5     Maize     Monocot   Crop
# sample5-4.09_Npos   4  72  sample5  Il14H_sample5     Maize     Monocot   Crop
# sample6-4.30_Npos   4  79  sample6    B73_sample6     Maize     Monocot   Crop
# sample6-1.12_Npos   1  79  sample6    B73_sample6     Maize     Monocot   Crop
# sample6-3.18_Npos   3  79  sample6    B73_sample6     Maize     Monocot   Crop
# sample1-4.24_Npos   4  36  sample1  FAGES_sample1  Dicot-NM       Dicot   Crop
# sample3-3.06_Npos   3  57  sample3  GLYMA_sample3    Legume       Dicot   Crop
# sample5-4.06_Nneg   4  72  sample5  ERATE_sample5  C4_Grass     Monocot   Crop
# sample6-4.17_Nneg   4  79  sample6    B97_sample6     Maize     Monocot   Crop
# sample5-3.11_Npos   3  72  sample5  ERATE_sample5  C4_Grass     Monocot   Crop
# sample5-3.16_Npos   3  72  sample5    H99_sample5     Maize     Monocot   Crop
# sample1-1.27_Npos   1  36  sample1  FAGES_sample1  Dicot-NM       Dicot   Crop
# sample5-4.05_Nneg   4  72  sample5    H99_sample5     Maize     Monocot   Crop
# sample5-1.25_Npos   1  72  sample5  Il14H_sample5     Maize     Monocot   Crop
# sample6-1.07_Nneg   1  79  sample6   Oh7B_sample6     Maize     Monocot   Crop
# sample5-2.18_Nneg   2  72  sample5  ERATE_sample5  C4_Grass     Monocot   Crop
# sample6-2.26_Npos   2  79  sample6    B73_sample6     Maize     Monocot   Crop
# sample5-3.16_Nneg   3  72  sample5    H99_sample5     Maize     Monocot   Crop
# sample5-4.06_Npos   4  72  sample5  ERATE_sample5  C4_Grass     Monocot   Crop
# sample3-1.09_Npos   1  57  sample3  GLYMA_sample3    Legume       Dicot   Crop
# sample3-4.15_Nneg   4  57  sample3  GLYMA_sample3    Legume       Dicot   Crop
# sample5-2.15_Npos   2  72  sample5  Il14H_sample5     Maize     Monocot   Crop
# sample6-4.30_Nneg   4  79  sample6    B73_sample6     Maize     Monocot   Crop
# sample5-3.27_Npos   3  72  sample5 75-062_sample5     Maize     Monocot   Crop
# sample6-1.12_Nneg   1  79  sample6    B73_sample6     Maize     Monocot   Crop
# sample4-3.10_Npos   3  61  sample4  SETFA_sample4  C4_Grass     Monocot   Weed
# sample6-2.16_Nneg   2  79  sample6    B97_sample6     Maize     Monocot   Crop
# sample5-3.17_Nneg   3  72  sample5  Il14H_sample5     Maize     Monocot   Crop
# sample5-1.16_Npos   1  72  sample5    H99_sample5     Maize     Monocot   Crop
# sample3-2.03_Npos   2  57  sample3  GLYMA_sample3    Legume       Dicot   Crop
# sample1-2.23_Npos   2  36  sample1  FAGES_sample1  Dicot-NM       Dicot   Crop
# sample5-4.09_Nneg   4  72  sample5  Il14H_sample5     Maize     Monocot   Crop
# sample2-2.08_Npos   2  53  sample2  AMAPO_sample2  Dicot-NM       Dicot   Weed
# sample2-3.05_Npos   3  53  sample2  AMAPO_sample2  Dicot-NM       Dicot   Weed
# sample2-1.08_Nneg   1  53  sample2  AMAPO_sample2  Dicot-NM       Dicot   Weed
# sample3-4.15_Npos   4  57  sample3  GLYMA_sample3    Legume       Dicot   Crop
# sample6-3.01_Nneg   3  79  sample6    B97_sample6     Maize     Monocot   Crop
# sample5-1.16_Nneg   1  72  sample5    H99_sample5     Maize     Monocot   Crop
# sample2-1.08_Npos   1  53  sample2  AMAPO_sample2  Dicot-NM       Dicot   Weed
# sample1-1.27_Nneg   1  36  sample1  FAGES_sample1  Dicot-NM       Dicot   Crop
# sample4-3.10_Nneg   3  61  sample4  SETFA_sample4  C4_Grass     Monocot   Weed
# sample5-1.29_Nneg   1  72  sample5  ERATE_sample5  C4_Grass     Monocot   Crop
# sample4-2.02_Npos   2  61  sample4  SETFA_sample4  C4_Grass     Monocot   Weed
# sample5-2.15_Nneg   2  72  sample5  Il14H_sample5     Maize     Monocot   Crop
# sample1-3.08_Nneg   3  36  sample1  FAGES_sample1  Dicot-NM       Dicot   Crop
# sample3-1.09_Nneg   1  57  sample3  GLYMA_sample3    Legume       Dicot   Crop
# sample2-4.25_Nneg   4  53  sample2  AMAPO_sample2  Dicot-NM       Dicot   Weed
# sample5-2.18_Npos   2  72  sample5  ERATE_sample5  C4_Grass     Monocot   Crop
# sample5-2.29_Npos   2  72  sample5 75-062_sample5     Maize     Monocot   Crop
# sample2-4.25_Npos   4  53  sample2  AMAPO_sample2  Dicot-NM       Dicot   Weed
# sample7-1.13_Npos   1  84  sample7  SORBI_sample7  C4_Grass     Monocot   Crop
# sample7-4.02_Npos   4  84  sample7 SORSUD_sample7  C4_Grass     Monocot   Crop
# sample8-2.07_Nneg   2  88  sample8  ELCOR_sample8  C4_Grass     Monocot   Crop
# sample7-4.02_Nneg   4  84  sample7 SORSUD_sample7  C4_Grass     Monocot   Crop
# sample3-1.20_Npos   1  57  sample3  ABUTH_sample3 Dicot-Myc       Dicot   Weed
# sample7-1.04_Npos   1  84  sample7 SORSUD_sample7  C4_Grass     Monocot   Crop
# sample8-4.23_Nneg   4  88  sample8    Ki3_sample8     Maize     Monocot   Crop
# sample7-3.19_Nneg   3  84  sample7  SORBI_sample7  C4_Grass     Monocot   Crop
# sample7-4.03_Npos   4  84  sample7  HELAN_sample7 Dicot-Myc       Dicot   Crop
# sample8-1.14_Npos   1  88  sample8  Tx303_sample8     Maize     Monocot   Crop
# sample7-2.12_Npos   2  84  sample7  HELAN_sample7 Dicot-Myc       Dicot   Crop
# sample3-4.18_Nneg   4  57  sample3  ABUTH_sample3 Dicot-Myc       Dicot   Weed
# sample8-3.28_Npos   3  88  sample8  Tx303_sample8     Maize     Monocot   Crop
# sample6-1.18_Nneg   1  79  sample6  Hp301_sample6     Maize     Monocot   Crop
# sample7-2.12_Nneg   2  84  sample7  HELAN_sample7 Dicot-Myc       Dicot   Crop
# sample7-2.28_Nneg   2  84  sample7 SORSUD_sample7  C4_Grass     Monocot   Crop
# sample2-2.10_Nneg   2  53  sample2  ECHCG_sample2  C4_Grass     Monocot   Weed
# sample8-2.17_Npos   2  88  sample8   Mo18_sample8     Maize     Monocot   Crop
# sample3-2.19_Npos   2  57  sample3  ABUTH_sample3 Dicot-Myc       Dicot   Weed
# sample8-2.25_Nneg   2  88  sample8    Ki3_sample8     Maize     Monocot   Crop
# sample6-3.09_Nneg   3  79  sample6  Hp301_sample6     Maize     Monocot   Crop
# sample2-3.20_Npos   3  53  sample2  ECHCG_sample2  C4_Grass     Monocot   Weed
# sample2-3.20_Nneg   3  53  sample2  ECHCG_sample2  C4_Grass     Monocot   Weed
# sample3-3.30_Npos   3  57  sample3  ABUTH_sample3 Dicot-Myc       Dicot   Weed
# sample8-4.23_Npos   4  88  sample8    Ki3_sample8     Maize     Monocot   Crop
# sample8-3.03_Npos   3  88  sample8  ELCOR_sample8  C4_Grass     Monocot   Crop
# sample6-4.13_Npos   4  79  sample6  Hp301_sample6     Maize     Monocot   Crop
# sample8-4.07_Nneg   4  88  sample8  Tx303_sample8     Maize     Monocot   Crop
# sample6-1.18_Npos   1  79  sample6  Hp301_sample6     Maize     Monocot   Crop
# sample7-3.25_Npos   3  84  sample7 SORSUD_sample7  C4_Grass     Monocot   Crop
# sample8-3.23_Nneg   3  88  sample8   Mo18_sample8     Maize     Monocot   Crop
# sample7-2.30_Npos   2  84  sample7  SORBI_sample7  C4_Grass     Monocot   Crop
# sample7-1.13_Nneg   1  84  sample7  SORBI_sample7  C4_Grass     Monocot   Crop
# sample8-2.22_Npos   2  88  sample8  Tx303_sample8     Maize     Monocot   Crop
# sample7-2.30_Nneg   2  84  sample7  SORBI_sample7  C4_Grass     Monocot   Crop
# sample2-1.24_Npos   1  53  sample2  ECHCG_sample2  C4_Grass     Monocot   Weed
# sample6-2.14_Npos   2  79  sample6  Hp301_sample6     Maize     Monocot   Crop
# sample8-1.14_Nneg   1  88  sample8  Tx303_sample8     Maize     Monocot   Crop
# sample3-1.20_Nneg   1  57  sample3  ABUTH_sample3 Dicot-Myc       Dicot   Weed
# sample2-4.16_Npos   4  53  sample2  ECHCG_sample2  C4_Grass     Monocot   Weed
# sample8-1.19_Npos   1  88  sample8  ELCOR_sample8  C4_Grass     Monocot   Crop
# sample7-2.28_Npos   2  84  sample7 SORSUD_sample7  C4_Grass     Monocot   Crop
# sample7-3.19_Npos   3  84  sample7  SORBI_sample7  C4_Grass     Monocot   Crop
# sample7-1.04_Nneg   1  84  sample7 SORSUD_sample7  C4_Grass     Monocot   Crop
# sample8-1.19_Nneg   1  88  sample8  ELCOR_sample8  C4_Grass     Monocot   Crop
# sample7-3.12_Nneg   3  84  sample7  HELAN_sample7 Dicot-Myc       Dicot   Crop
# sample7-4.03_Nneg   4  84  sample7  HELAN_sample7 Dicot-Myc       Dicot   Crop
# sample7-1.28_Npos   1  84  sample7  HELAN_sample7 Dicot-Myc       Dicot   Crop
# sample8-1.10_Npos   1  88  sample8   Mo18_sample8     Maize     Monocot   Crop
# sample7-1.28_Nneg   1  84  sample7  HELAN_sample7 Dicot-Myc       Dicot   Crop
# sample7-3.25_Nneg   3  84  sample7 SORSUD_sample7  C4_Grass     Monocot   Crop
# sample2-1.24_Nneg   1  53  sample2  ECHCG_sample2  C4_Grass     Monocot   Weed
# sample8-1.10_Nneg   1  88  sample8   Mo18_sample8     Maize     Monocot   Crop
# sample8-4.01_Npos   4  88  sample8  ELCOR_sample8  C4_Grass     Monocot   Crop
# sample7-4.14_Npos   4  84  sample7  SORBI_sample7  C4_Grass     Monocot   Crop
# sample8-4.01_Nneg   4  88  sample8  ELCOR_sample8  C4_Grass     Monocot   Crop
# sample8-2.17_Nneg   2  88  sample8   Mo18_sample8     Maize     Monocot   Crop
# sample6-3.09_Npos   3  79  sample6  Hp301_sample6     Maize     Monocot   Crop
# sample8-2.22_Nneg   2  88  sample8  Tx303_sample8     Maize     Monocot   Crop
# sample8-3.29_Nneg   3  88  sample8    Ki3_sample8     Maize     Monocot   Crop
# sample8-4.07_Npos   4  88  sample8  Tx303_sample8     Maize     Monocot   Crop
# sample8-1.23_Npos   1  88  sample8    Ki3_sample8     Maize     Monocot   Crop
# sample8-3.28_Nneg   3  88  sample8  Tx303_sample8     Maize     Monocot   Crop
# sample2-2.10_Npos   2  53  sample2  ECHCG_sample2  C4_Grass     Monocot   Weed
# sample6-4.13_Nneg   4  79  sample6  Hp301_sample6     Maize     Monocot   Crop
# sample3-2.19_Nneg   2  57  sample3  ABUTH_sample3 Dicot-Myc       Dicot   Weed
# sample2-4.16_Nneg   4  53  sample2  ECHCG_sample2  C4_Grass     Monocot   Weed
# sample7-3.12_Npos   3  84  sample7  HELAN_sample7 Dicot-Myc       Dicot   Crop
# sample8-3.23_Npos   3  88  sample8   Mo18_sample8     Maize     Monocot   Crop
# sample8-3.29_Npos   3  88  sample8    Ki3_sample8     Maize     Monocot   Crop
# sample8-1.23_Nneg   1  88  sample8    Ki3_sample8     Maize     Monocot   Crop
# sample6-2.14_Nneg   2  79  sample6  Hp301_sample6     Maize     Monocot   Crop
# sample8-4.04_Nneg   4  88  sample8   Mo18_sample8     Maize     Monocot   Crop
# sample3-3.30_Nneg   3  57  sample3  ABUTH_sample3 Dicot-Myc       Dicot   Weed
# sample7-4.14_Nneg   4  84  sample7  SORBI_sample7  C4_Grass     Monocot   Crop
# sample8-2.07_Npos   2  88  sample8  ELCOR_sample8  C4_Grass     Monocot   Crop
# sample3-4.18_Npos   4  57  sample3  ABUTH_sample3 Dicot-Myc       Dicot   Weed
# sample8-4.04_Npos   4  88  sample8   Mo18_sample8     Maize     Monocot   Crop
# sample8-2.25_Npos   2  88  sample8    Ki3_sample8     Maize     Monocot   Crop
# sample8-3.03_Nneg   3  88  sample8  ELCOR_sample8  C4_Grass     Monocot   Crop
#                       Subfamily fwd_barcode rev_barcode
# sample5-1.22_Nneg      Paniceae    ATCGTACG    CAGTGAGT
# sample6-4.12_Npos      Paniceae    GTCAGATA    AGTAGCGT
# sample4-1.03_Npos      Paniceae    ACTATCTG    AGTAGCGT
# sample5-2.06_Npos      Paniceae    TACGAGAC    AACTCTCG
# sample5-4.08_Npos      Paniceae    GTCAGATA    AACTCTCG
# sample5-4.28_Npos      Paniceae    GACACCGT    CAGTGAGT
# sample5-1.29_Npos Andropogoneae    ACTATCTG    CGTACTCA
# sample4-2.02_Nneg      Paniceae    TAGCGAGT    AGTAGCGT
# sample4-4.21_Nneg      Paniceae    GGATATCT    AGTAGCGT
# sample6-2.13_Npos      Paniceae    TACGAGAC    AGTAGCGT
# sample5-2.29_Nneg      Paniceae    TAGCGAGT    CAGTGAGT
# sample5-2.06_Nneg      Paniceae    AGAGTCAC    AACTCTCG
# sample1-2.23_Nneg          <NA>    TAGCGAGT    AACTCTCG
# sample6-2.26_Nneg      Paniceae    AGAGTCAC    GGAGACTA
# sample6-3.18_Nneg      Paniceae    ACGTCTCG    GGAGACTA
# sample5-3.13_Nneg      Paniceae    ACGTCTCG    AACTCTCG
# sample2-2.08_Nneg          <NA>    TAGCGAGT    GGAGACTA
# sample5-1.17_Nneg      Paniceae    CTACTATA    AACTCTCG
# sample6-3.01_Npos      Paniceae    TCGACGAG    CGTACTCA
# sample3-2.03_Nneg          <NA>    TAGCGAGT    GTCGCTCG
# sample5-4.08_Nneg      Paniceae    GATCGTGT    AACTCTCG
# sample5-4.05_Npos      Paniceae    GACACCGT    CTACGCAG
# sample6-2.16_Npos      Paniceae    TACGAGAC    CGTACTCA
# sample1-4.24_Nneg          <NA>    GGATATCT    AACTCTCG
# sample5-4.28_Nneg      Paniceae    GGATATCT    CAGTGAGT
# sample6-2.13_Nneg      Paniceae    AGAGTCAC    AGTAGCGT
# sample1-3.08_Npos          <NA>    CGTGAGTG    AACTCTCG
# sample6-3.04_Npos      Paniceae    TCGACGAG    AGTAGCGT
# sample4-1.03_Nneg      Paniceae    ATCGTACG    AGTAGCGT
# sample5-1.22_Npos      Paniceae    ACTATCTG    CAGTGAGT
# sample6-1.15_Nneg      Paniceae    CTACTATA    CGTACTCA
# sample5-2.11_Nneg      Paniceae    TAGCGAGT    CTACGCAG
# sample4-4.21_Npos      Paniceae    GACACCGT    AGTAGCGT
# sample6-4.12_Nneg      Paniceae    GATCGTGT    AGTAGCGT
# sample5-1.25_Nneg      Paniceae    ATCGTACG    ACTATGTC
# sample6-4.17_Npos      Paniceae    GTCAGATA    CGTACTCA
# sample6-3.04_Nneg      Paniceae    ACGTCTCG    AGTAGCGT
# sample5-3.27_Nneg      Paniceae    TCATCGAG    CAGTGAGT
# sample6-1.15_Npos      Paniceae    CGTTACTA    CGTACTCA
# sample5-3.11_Nneg Andropogoneae    TCATCGAG    CGTACTCA
# sample5-2.11_Npos      Paniceae    CTGCGTGT    CTACGCAG
# sample5-3.17_Npos      Paniceae    CGTGAGTG    ACTATGTC
# sample5-1.17_Npos      Paniceae    CGTTACTA    AACTCTCG
# sample3-3.06_Nneg          <NA>    TCATCGAG    GTCGCTCG
# sample2-3.05_Nneg          <NA>    TCATCGAG    GGAGACTA
# sample6-1.07_Npos      Paniceae    CGTTACTA    AGTAGCGT
# sample5-3.13_Npos      Paniceae    TCGACGAG    AACTCTCG
# sample5-4.09_Npos      Paniceae    GACACCGT    ACTATGTC
# sample6-4.30_Npos      Paniceae    GTCAGATA    GGAGACTA
# sample6-1.12_Npos      Paniceae    CGTTACTA    GGAGACTA
# sample6-3.18_Npos      Paniceae    TCGACGAG    GGAGACTA
# sample1-4.24_Npos          <NA>    GACACCGT    AACTCTCG
# sample3-3.06_Npos          <NA>    CGTGAGTG    GTCGCTCG
# sample5-4.06_Nneg Andropogoneae    GGATATCT    CGTACTCA
# sample6-4.17_Nneg      Paniceae    GATCGTGT    CGTACTCA
# sample5-3.11_Npos Andropogoneae    CGTGAGTG    CGTACTCA
# sample5-3.16_Npos      Paniceae    CGTGAGTG    CTACGCAG
# sample1-1.27_Npos          <NA>    ACTATCTG    AACTCTCG
# sample5-4.05_Nneg      Paniceae    GGATATCT    CTACGCAG
# sample5-1.25_Npos      Paniceae    ACTATCTG    ACTATGTC
# sample6-1.07_Nneg      Paniceae    CTACTATA    AGTAGCGT
# sample5-2.18_Nneg Andropogoneae    TAGCGAGT    CGTACTCA
# sample6-2.26_Npos      Paniceae    TACGAGAC    GGAGACTA
# sample5-3.16_Nneg      Paniceae    TCATCGAG    CTACGCAG
# sample5-4.06_Npos Andropogoneae    GACACCGT    CGTACTCA
# sample3-1.09_Npos          <NA>    ACTATCTG    GTCGCTCG
# sample3-4.15_Nneg          <NA>    GGATATCT    GTCGCTCG
# sample5-2.15_Npos      Paniceae    CTGCGTGT    ACTATGTC
# sample6-4.30_Nneg      Paniceae    GATCGTGT    GGAGACTA
# sample5-3.27_Npos      Paniceae    CGTGAGTG    CAGTGAGT
# sample6-1.12_Nneg      Paniceae    CTACTATA    GGAGACTA
# sample4-3.10_Npos      Paniceae    CGTGAGTG    AGTAGCGT
# sample6-2.16_Nneg      Paniceae    AGAGTCAC    CGTACTCA
# sample5-3.17_Nneg      Paniceae    TCATCGAG    ACTATGTC
# sample5-1.16_Npos      Paniceae    ACTATCTG    CTACGCAG
# sample3-2.03_Npos          <NA>    CTGCGTGT    GTCGCTCG
# sample1-2.23_Npos          <NA>    CTGCGTGT    AACTCTCG
# sample5-4.09_Nneg      Paniceae    GGATATCT    ACTATGTC
# sample2-2.08_Npos          <NA>    CTGCGTGT    GGAGACTA
# sample2-3.05_Npos          <NA>    CGTGAGTG    GGAGACTA
# sample2-1.08_Nneg          <NA>    ATCGTACG    GGAGACTA
# sample3-4.15_Npos          <NA>    GACACCGT    GTCGCTCG
# sample6-3.01_Nneg      Paniceae    ACGTCTCG    CGTACTCA
# sample5-1.16_Nneg      Paniceae    ATCGTACG    CTACGCAG
# sample2-1.08_Npos          <NA>    ACTATCTG    GGAGACTA
# sample1-1.27_Nneg          <NA>    ATCGTACG    AACTCTCG
# sample4-3.10_Nneg      Paniceae    TCATCGAG    AGTAGCGT
# sample5-1.29_Nneg Andropogoneae    ATCGTACG    CGTACTCA
# sample4-2.02_Npos      Paniceae    CTGCGTGT    AGTAGCGT
# sample5-2.15_Nneg      Paniceae    TAGCGAGT    ACTATGTC
# sample1-3.08_Nneg          <NA>    TCATCGAG    AACTCTCG
# sample3-1.09_Nneg          <NA>    ATCGTACG    GTCGCTCG
# sample2-4.25_Nneg          <NA>    GGATATCT    GGAGACTA
# sample5-2.18_Npos Andropogoneae    CTGCGTGT    CGTACTCA
# sample5-2.29_Npos      Paniceae    CTGCGTGT    CAGTGAGT
# sample2-4.25_Npos          <NA>    GACACCGT    GGAGACTA
# sample7-1.13_Npos Andropogoneae    CGTGAGTG    CAGTGAGT
# sample7-4.02_Npos Andropogoneae    GACACCGT    AGTAGCGT
# sample8-2.07_Nneg Andropogoneae    TAGCGAGT    GTCGCTCG
# sample7-4.02_Nneg Andropogoneae    GGATATCT    AGTAGCGT
# sample3-1.20_Npos          <NA>    ACTATCTG    TCGCTATA
# sample7-1.04_Npos Andropogoneae    TAGCGAGT    AGTAGCGT
# sample8-4.23_Nneg      Paniceae    GGATATCT    TAGCAGAC
# sample7-3.19_Nneg Andropogoneae    GACACCGT    CAGTGAGT
# sample7-4.03_Npos          <NA>    ACTATCTG    CAGTGAGT
# sample8-1.14_Npos      Paniceae    CGTTACTA    ACTATGTC
# sample7-2.12_Npos          <NA>    TCATCGAG    ACTATGTC
# sample3-4.18_Nneg          <NA>    ATCGTACG    AGTAGCGT
# sample8-3.28_Npos      Paniceae    TCGACGAG    ACTATGTC
# sample6-1.18_Nneg      Paniceae    ACTATCTG    GTCGTAGT
# sample7-2.12_Nneg          <NA>    TAGCGAGT    ACTATGTC
# sample7-2.28_Nneg Andropogoneae    CTGCGTGT    CGTACTCA
# sample2-2.10_Nneg      Paniceae    ATCGTACG    ACTATGTC
# sample8-2.17_Npos      Paniceae    CTGCGTGT    TCATAGAC
# sample3-2.19_Npos          <NA>    TAGCGAGT    TCGCTATA
# sample8-2.25_Nneg      Paniceae    TAGCGAGT    TAGCAGAC
# sample6-3.09_Nneg      Paniceae    TCATCGAG    GTCGTAGT
# sample2-3.20_Npos      Paniceae    TCGACGAG    AACTCTCG
# sample2-3.20_Nneg      Paniceae    ACGTCTCG    AACTCTCG
# sample3-3.30_Npos          <NA>    TCATCGAG    TCGCTATA
# sample8-4.23_Npos      Paniceae    GACACCGT    TAGCAGAC
# sample8-3.03_Npos Andropogoneae    CGTGAGTG    GTCGCTCG
# sample6-4.13_Npos      Paniceae    GACACCGT    GTCGTAGT
# sample8-4.07_Nneg      Paniceae    GATCGTGT    ACTATGTC
# sample6-1.18_Npos      Paniceae    ATCGTACG    GTCGTAGT
# sample7-3.25_Npos Andropogoneae    CGTGAGTG    AGTAGCGT
# sample8-3.23_Nneg      Paniceae    TCATCGAG    TCATAGAC
# sample7-2.30_Npos Andropogoneae    GGATATCT    CAGTGAGT
# sample7-1.13_Nneg Andropogoneae    TCATCGAG    CAGTGAGT
# sample8-2.22_Npos      Paniceae    TACGAGAC    ACTATGTC
# sample7-2.30_Nneg Andropogoneae    TAGCGAGT    CAGTGAGT
# sample2-1.24_Npos      Paniceae    CGTTACTA    AACTCTCG
# sample6-2.14_Npos      Paniceae    CTGCGTGT    GTCGTAGT
# sample8-1.14_Nneg      Paniceae    CTACTATA    ACTATGTC
# sample3-1.20_Nneg          <NA>    ATCGTACG    TCGCTATA
# sample2-4.16_Npos      Paniceae    GTCAGATA    AACTCTCG
# sample8-1.19_Npos Andropogoneae    ACTATCTG    GTCGCTCG
# sample7-2.28_Npos Andropogoneae    CTGCGTGT    AGTAGCGT
# sample7-3.19_Npos Andropogoneae    ATCGTACG    CGTACTCA
# sample7-1.04_Nneg Andropogoneae    ACTATCTG    AGTAGCGT
# sample8-1.19_Nneg Andropogoneae    ATCGTACG    GTCGCTCG
# sample7-3.12_Nneg          <NA>    CGTGAGTG    CGTACTCA
# sample7-4.03_Nneg          <NA>    TCATCGAG    CGTACTCA
# sample7-1.28_Npos          <NA>    GGATATCT    ACTATGTC
# sample8-1.10_Npos      Paniceae    ACTATCTG    TCATAGAC
# sample7-1.28_Nneg          <NA>    CGTGAGTG    ACTATGTC
# sample7-3.25_Nneg Andropogoneae    TCATCGAG    AGTAGCGT
# sample2-1.24_Nneg      Paniceae    CTACTATA    AACTCTCG
# sample8-1.10_Nneg      Paniceae    ATCGTACG    TCATAGAC
# sample8-4.01_Npos Andropogoneae    GACACCGT    GTCGCTCG
# sample7-4.14_Npos Andropogoneae    TAGCGAGT    CGTACTCA
# sample8-4.01_Nneg Andropogoneae    GGATATCT    GTCGCTCG
# sample8-2.17_Nneg      Paniceae    TAGCGAGT    TCATAGAC
# sample6-3.09_Npos      Paniceae    CGTGAGTG    GTCGTAGT
# sample8-2.22_Nneg      Paniceae    AGAGTCAC    ACTATGTC
# sample8-3.29_Nneg      Paniceae    TCATCGAG    TAGCAGAC
# sample8-4.07_Npos      Paniceae    GTCAGATA    ACTATGTC
# sample8-1.23_Npos      Paniceae    ACTATCTG    TAGCAGAC
# sample8-3.28_Nneg      Paniceae    ACGTCTCG    ACTATGTC
# sample2-2.10_Npos      Paniceae    TACGAGAC    AACTCTCG
# sample6-4.13_Nneg      Paniceae    GGATATCT    GTCGTAGT
# sample3-2.19_Nneg          <NA>    GACACCGT    ACTATGTC
# sample2-4.16_Nneg      Paniceae    GATCGTGT    AACTCTCG
# sample7-3.12_Npos          <NA>    CTGCGTGT    ACTATGTC
# sample8-3.23_Npos      Paniceae    CGTGAGTG    TCATAGAC
# sample8-3.29_Npos      Paniceae    CGTGAGTG    TAGCAGAC
# sample8-1.23_Nneg      Paniceae    ATCGTACG    TAGCAGAC
# sample6-2.14_Nneg      Paniceae    TAGCGAGT    GTCGTAGT
# sample8-4.04_Nneg      Paniceae    GGATATCT    TCATAGAC
# sample3-3.30_Nneg          <NA>    CTGCGTGT    TCGCTATA
# sample7-4.14_Nneg Andropogoneae    ACTATCTG    CGTACTCA
# sample8-2.07_Npos Andropogoneae    CTGCGTGT    GTCGCTCG
# sample3-4.18_Npos          <NA>    CTGCGTGT    CAGTGAGT
# sample8-4.04_Npos      Paniceae    GACACCGT    TCATAGAC
# sample8-2.25_Npos      Paniceae    CTGCGTGT    TAGCAGAC
# sample8-3.03_Nneg Andropogoneae    TCATCGAG    GTCGCTCG

# %%
# %%R -w 750 -h 800
# #Whole plant set
#
# plantNnegnmds = ordinate(plantNneg,
#                 method = "NMDS",
#                distance = plantNneg.wunif.dist)
#
# p = plot_ordination(plantNneg, plantNnegnmds, justDF = TRUE)
#
# ## generating plots
# p1 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(fill=Plant), size = 6, pch=21)
#
# p1
# Out:
# Run 0 stress 0.164082
# Run 1 stress 0.1894401
# Run 2 stress 0.2173661
# Run 3 stress 0.1949009
# Run 4 stress 0.1577954
# ... New best solution
# ... procrustes: rmse 0.03591861  max resid 0.256015
# Run 5 stress 0.1683086
# Run 6 stress 0.1577953
# ... New best solution
# ... procrustes: rmse 3.209961e-05  max resid 0.0002477847
# *** Solution reached

# %%
# %%R -w 750 -h 800
# #Whole plant set
#
# plantNposnmds = ordinate(plantNpos,
#                 method = "NMDS",
#                distance = plantNpos.wunif.dist)
#
# p = plot_ordination(plantNpos, plantNposnmds, justDF = TRUE)
#
# ## generating plots
# p1 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(fill=Plant), size = 6, pch=21)
#
# p1
# Out:
# Run 0 stress 0.1728807
# Run 1 stress 0.1728826
# ... procrustes: rmse 0.0005883523  max resid 0.004968926
# *** Solution reached

# %% [markdown]
# ## Hypothesis Testing on Plant subset
# *Note that the proper model design should be DAP + Plant + (1|plant:fertilizer) (check notes), since plant + and - fertilizer are not independent.  Thus plant may have a greater explanatory power becuase false replicates are spatially autocorrelated.

# %%
# %%R
# df = as(sample_data(plant), "data.frame")
# d = plant.wunif.dist
# plantadonis = adonis(d ~ Plant + Treatment, df)
# plantadonis
# Out:
# Call:
# adonis(formula = d ~ Plant + Treatment, data = df)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#            Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Plant      21    2.1604 0.102874  7.7479 0.50896  0.001 ***
# Treatment   1    0.0528 0.052838  3.9795 0.01245  0.001 ***
# Residuals 153    2.0315 0.013278         0.47859
# Total     175    4.2447                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# df = as(sample_data(plantNneg), "data.frame")
# d = plantNneg.wunif.dist
# plantNnegadonis = adonis(d ~ Plant, df)
# plantNnegadonis
# Out:
# Call:
# adonis(formula = d ~ Plant, data = df)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model     R2 Pr(>F)
# Plant     21   1.17164 0.055792  4.5716 0.5926  0.001 ***
# Residuals 66   0.80547 0.012204         0.4074
# Total     87   1.97711                  1.0000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# df = as(sample_data(plantNpos), "data.frame")
# d = plantNpos.wunif.dist
# plantadonis = adonis(d ~ Plant, df)
# plantadonis
# Out:
# Call:
# adonis(formula = d ~ Plant, data = df)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Plant     21    1.2093 0.057586  3.7802 0.54603  0.001 ***
# Residuals 66    1.0054 0.015234         0.45397
# Total     87    2.2147                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# df = as(sample_data(plant88), "data.frame")
# d = plant88.wunif.dist
# plantadonis = adonis(d ~ Plant, df)
# plantadonis
# Out:
# Call:
# adonis(formula = d ~ Plant, data = df)
#
# Permutation: free
# Number of permutations: 999
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Plant      3  0.095109 0.031703  3.3675 0.45708  0.001 ***
# Residuals 12  0.112971 0.009414         0.54292
# Total     15  0.208079                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### NMDS of unweighted-unifrac distances

# %%
# %%R
# registerDoParallel(cores=28)
#
# uwunif.dist = distance(physeq.thresh,
#                       method = "unifrac",
#                       weighted = FALSE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %%
# %%R -w 800 -h 350
#
#
# nmds = ordinate(physeq.thresh,
#                 method = "NMDS",
#                 distance = uwunif.dist)
#
# p = plot_ordination(physeq.thresh, nmds, justDF = TRUE)
#
#
# ## generating plots
# p1 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(fill=Plant), pch = 21)
#         #scale_size(range=c(2,8))
#
# #p2 = ggplot(p, aes(x = NMDS1, y = NMDS2)) +
#         #geom_point(aes(fill=Plant, size = BD), pch=21) +
#         #scale_size(range=c(2,8))
#
# grid.arrange(p1, ncol=1)
# Out:
# Run 0 stress 0.151542
# Run 1 stress 0.151551
# ... procrustes: rmse 0.004933649  max resid 0.05450923
# Run 2 stress 0.1798721
# Run 3 stress 0.1566438
# Run 4 stress 0.1548091
# Run 5 stress 0.1572005
# Run 6 stress 0.1563552
# Run 7 stress 0.1516446
# ... procrustes: rmse 0.004650461  max resid 0.06352403
# Run 8 stress 0.1547486
# Run 9 stress 0.1759134
# Run 10 stress 0.1566606
# Run 11 stress 0.1550539
# Run 12 stress 0.1596702
# Run 13 stress 0.1549299
# Run 14 stress 0.172921
# Run 15 stress 0.1520395
# ... procrustes: rmse 0.006702048  max resid 0.07926728
# Run 16 stress 0.1514983
# ... New best solution
# ... procrustes: rmse 0.004211767  max resid 0.05455723
# Run 17 stress 0.1638477
# Run 18 stress 0.1547571
# Run 19 stress 0.1631966
# Run 20 stress 0.1565619

# %% [markdown]
# #Heatmaps of taxon abundances

# %%
# %%R
# physeq.thresh %>% tax_table %>% head
# Out:
# Taxonomy Table:     [6 taxa by 8 taxonomic ranks]:
#          Rank1      Rank2              Rank3
# OTU.5899 "Bacteria" "__Acidobacteria"  "__32-21"
# OTU.8680 "Bacteria" "__Acidobacteria"  "__Holophagae"
# OTU.2666 "Bacteria" "__Acidobacteria"  "__Holophagae"
# OTU.323  "Bacteria" "__Acidobacteria"  "__Holophagae"
# OTU.7636 "Bacteria" "__Acidobacteria"  "__Holophagae"
# OTU.1030 "Bacteria" "__Proteobacteria" "__Deltaproteobacteria"
#          Rank4                    Rank5                    Rank6          Rank7
# OTU.5899 "__uncultured_bacterium" NA                       NA             NA
# OTU.8680 "__Sva0725"              NA                       NA             NA
# OTU.2666 "__Sva0725"              "__uncultured_bacterium" NA             NA
# OTU.323  "__Sva0725"              NA                       NA             NA
# OTU.7636 "__Sva0725"              NA                       NA             NA
# OTU.1030 "__Desulfobacterales"    "__Nitrospinaceae"       "__uncultured" NA
#          Rank8
# OTU.5899 NA
# OTU.8680 NA
# OTU.2666 NA
# OTU.323  NA
# OTU.7636 NA
# OTU.1030 NA

# %%
# %%R -w 800
# physeq.thresh.t50 <- prune_taxa(names(sort(taxa_sums(physeq.thresh),TRUE)[1:10]), physeq.thresh)
#
# plot_heatmap(physeq.thresh.t50, sample.label='Plant', taxa.label='Rank2')
#
# ggsave("heatmap_rank2.pdf")
# Out:
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Saving 11.1 x 6.67 in image
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %%
# %%R -w 800
# physeq.thresh.t50 <- prune_taxa(names(sort(taxa_sums(physeq.thresh),TRUE)[1:10]), physeq.thresh)
#
# plot_heatmap(physeq.thresh.t50, sample.label='Plant', taxa.label='Rank7')

# %% [markdown]
# ##Analysis of changes in bare soil community over time

# %%
# %%R
# sample_names(physeq)
# Out:
#   [1] "sample2-1.06_Npos" "sample6-4.27_Npos" "sample4-4.27_Nneg"
#   [4] "sample4-1.06_Nneg" "sample2-1.06_Nneg" "sample6-3.07_Nneg"
#   [7] "sample5-3.07_Nneg" "sample6-3.07_Npos" "sample3-3.07_Npos"
#  [10] "sample5-1.22_Nneg" "sample6-4.12_Npos" "sample1-4.27_Npos"
#  [13] "sample4-1.03_Npos" "sample5-2.06_Npos" "sample5-4.08_Npos"
#  [16] "sample4-3.07_Nneg" "sample5-4.28_Npos" "sample6-1.06_Npos"
#  [19] "sample4-2.05_Nneg" "sample2-4.27_Nneg" "sample1-2.05_Nneg"
#  [22] "sample5-1.29_Npos" "sample5-4.27_Npos" "sample5-4.27_Nneg"
#  [25] "sample1-3.07_Nneg" "sample4-2.02_Nneg" "sample4-4.21_Nneg"
#  [28] "sample2-2.05_Nneg" "sample6-2.13_Npos" "sample5-2.29_Nneg"
#  [31] "sample5-2.06_Nneg" "sample1-2.23_Nneg" "sample6-2.26_Nneg"
#  [34] "sample6-3.18_Nneg" "sample5-3.13_Nneg" "sample2-2.08_Nneg"
