# %% [markdown]
# # Goal
#
# * Map incorporators on the phylogeny

# %% [markdown]
# # Setting variables

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# # Note that Nick has separate phyloseq objects for sip and the bulk soil saved
# physeqDir = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/physeq/'
#
# physeqFull = 'Full-Sparsity3in3_r'
# #physeqBulk = 'bulk-core'
#
#
# nprocs = 20
#
# workDir = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/DeSeq2/'
# figDir = '/home/bryan/RhizCG/figures/rhizosphere_enriched/RelAbund'
#
# RhizEnrichedFile = file.path(workDir, 'bare-plant.csv')
#
# biomFileDir = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/'
# biomFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/otu_table_wtax.biom'
# metadataFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/metadata_RhizCG_merged.txt'
# treeFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/fasttree/otusn.tree'

# %% [markdown]
# # Init

# %%
# %%R
# library(phyloseq)
# library(reshape)
# library(dplyr)
# library(tidyr)
# library(ggplot2)
# library(grid)
# library(gridExtra)
# library(foreach)
# library(doParallel)
# Out:
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘dplyr’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:reshape’:
#
#     rename
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘tidyr’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:reshape’:
#
#     expand, smiths
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘gridExtra’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: foreach: simple, scalable parallel programming from Revolution Analytics
# Use Revolution R for scalability, fault tolerance and more.
# http://www.revolutionanalytics.com
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: iterators
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: parallel
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %% [markdown]
# # Loading files

# %%
# %%R
# F = file.path('/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/physeq/Full-Sparsity3in3')
# physeq.Full = readRDS(F)
# physeq.Full.m = physeq.Full %>% sample_data
# physeq.Full
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4982 taxa and 238 samples ]
# sample_data() Sample Data:       [ 238 samples by 55 sample variables ]
# tax_table()   Taxonomy Table:    [ 4982 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4982 tips and 4981 internal nodes ]

# %%
# %%R
#
# physeq.bare = subset_samples(physeq.Full, Plant == "BARE")
# physeq.bare.m = physeq.bare %>% sample_data
# physeq.bare
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4982 taxa and 64 samples ]
# sample_data() Sample Data:       [ 64 samples by 55 sample variables ]
# tax_table()   Taxonomy Table:    [ 4982 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4982 tips and 4981 internal nodes ]

# %%
# %%R
# physeq.plant = subset_samples(physeq.Full, Plant != "BARE")
# physeq.plant.m = physeq.plant %>% sample_data
# physeq.plant
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4982 taxa and 174 samples ]
# sample_data() Sample Data:       [ 174 samples by 55 sample variables ]
# tax_table()   Taxonomy Table:    [ 4982 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4982 tips and 4981 internal nodes ]

# %% [markdown]
# ## Join average OTU counts (rarified) per plant with log2fold change data

# %%
# %%R
# #aggregate by plant
# merge.phy = merge_samples(physeq.plant, "Plant")
#
# #Transform sample counts to correct for two missing samples from ECHCG
# merge.phy = transform_sample_counts(merge.phy, function(x) x/sum(x))
#
# #Melt to bring into long data format
# temp = merge.phy %>% otu_table %>% as.data.frame
# temp$Plant = rownames(temp)
# OTUrel = melt(temp, id = "Plant")
# colnames(OTUrel)[2:3] = c("OTU", "RelAbund")
#
#
# # log2 fold change analysis results file
# df.l2fc = read.delim(RhizEnrichedFile, sep=',')
# df.l2fc %>% head(n=3)
#
# # Join l2f and relabund data
# df.l2fc = left_join(df.l2fc, OTUrel)
# head(df.l2fc)
#
# #Clean up
# temp = NULL
# OTUrel = NULL
# Out:
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Joining, by = c("OTU", "Plant")
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %%
# %%R
# # merge.phy %>% otu_table %>% range(na.remove = TRUE)
# # merge.phy %>% filter_taxa(function(x) (x = 1) > 0)
# # #merge.phy %>% otu_table %>%
# #     head
# Out:
# NULL

# %%
# %%R
# merge.phy
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4982 taxa and 22 samples ]
# sample_data() Sample Data:       [ 22 samples by 55 sample variables ]
# tax_table()   Taxonomy Table:    [ 4982 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4982 tips and 4981 internal nodes ]

# %%
# %%R
# head(df.l2fc)
# Out:
#   log2FoldChange         p    Rank1          Rank2               Rank3
# 1     -1.2362293 0.9508456 Bacteria  Acidobacteria               32-21
# 2     -0.9586041 0.9990821 Bacteria  Acidobacteria          Holophagae
# 3      1.2753701 0.1881231 Bacteria  Acidobacteria          Holophagae
# 4     -0.9890428 0.9999999 Bacteria  Acidobacteria          Holophagae
# 5     -0.6773383 0.9649874 Bacteria  Acidobacteria          Holophagae
# 6     -1.7041008 0.9999051 Bacteria Proteobacteria Deltaproteobacteria
#                  Rank4                Rank5      Rank6 Rank7 Rank8      OTU Day
# 1 uncultured_bacterium                 <NA>       <NA>  <NA>  <NA> OTU.5899  36
# 2              Sva0725                 <NA>       <NA>  <NA>  <NA> OTU.8680  36
# 3              Sva0725 uncultured_bacterium       <NA>  <NA>  <NA> OTU.2666  36
# 4              Sva0725                 <NA>       <NA>  <NA>  <NA>  OTU.323  36
# 5              Sva0725                 <NA>       <NA>  <NA>  <NA> OTU.7636  36
# 6    Desulfobacterales       Nitrospinaceae uncultured  <NA>  <NA> OTU.1030  36
#   Plant     p.adj     RelAbund
# 1 FAGES 1.0000000 1.188091e-05
# 2 FAGES 1.0000000 8.316634e-05
# 3 FAGES 0.8652547 4.356332e-05
# 4 FAGES 1.0000000 3.999905e-04
# 5 FAGES 1.0000000 4.356332e-05
# 6 FAGES 1.0000000 6.336483e-05

# %% [markdown]
# ## Making tree plot & metadata plots separately, then combining with grid.arrange

# %%
# %%R -h 1000
#
# plot_tree = function(physeq, color.rank="Rank2", legend.title='Phylum',
#                      plot.margin=NULL, y.expand=c(0.01,0.01),
#                      legend.position='none', legend.size=4){
#     # general tree plotting with ggplot
#     as.Num = function(x){ x %>% as.character %>% as.numeric }
#
#     # plot margin
#     if(is.null(plot.margin)){
#         plot.margin = unit(c(0,0,0,0), "cm")  # top, right, bottom, left
#     }
#
#     # get tree coords
#     treeSegs = phyloseq:::tree_layout(phy_tree(physeq), ladderize='right')
#
#     # edge parsing
#     edge_inner = treeSegs$edgeDT[is.na(treeSegs$edgeDT$OTU)]
#     edge_otu = treeSegs$edgeDT[! is.na(treeSegs$edgeDT$OTU)]
#
#     # adding taxonomy to left edges
#     physeq.tax = physeq %>% tax_table %>% as.matrix %>% as.data.frame %>%
#         mutate(OTU = rownames(.))
#     edge_otu.df = edge_otu %>% as.matrix %>% as.data.frame %>%
#         mutate(xleft = xleft %>% as.Num,
#                xright = xright %>% as.Num,
#                y = y %>% as.Num)
#     edge_otu.df = inner_join(edge_otu.df, physeq.tax, c('OTU' = 'OTU')) %>%
#         mutate(Rank2 = gsub('^__', '', Rank2),
#                Rank3 = gsub('^__', '', Rank3),
#                Rank4 = gsub('^__', '', Rank4),
#                Rank5 = gsub('^__', '', Rank5),
#                Rank6 = gsub('^__', '', Rank6),
#                Rank7 = gsub('^__', '', Rank7),
#                Rank8 = gsub('^__', '', Rank8))
#
#     # adding node-metadata connector lines
#     edge_otu.con = edge_otu.df %>%
#                      mutate(max.xright = max(xright, na.rm=T),
#                             xleft = xright,
#                             xright = max.xright)
#
#     # dummy facet
#     edge_inner$FACET = 1
#
#     # making tree plot
#     p.tree = ggplot(data=edge_inner) +
#         geom_segment(aes(x=xleft, xend=xright, y=y, yend=y)) +
#         geom_segment(data=edge_otu.df,
#                      aes(x=xleft, xend=xright, y=y, yend=y)) +
#         geom_segment(data=edge_otu.con,
#                      aes_string(x="xleft", xend="xright", y="y",
#                                 yend="y", color=color.rank)) +
#         geom_segment(data=treeSegs$vertDT,
#                      aes(x=x, xend=x, y=vmin, yend=vmax)) +
#         scale_y_continuous(expand=y.expand) +
#         scale_color_discrete(legend.title) +
#         facet_grid(. ~ FACET) +
#         theme_bw() +
#         guides(colour = guide_legend(override.aes = list(size=legend.size))) +
#         theme(
#             panel.grid.major = element_blank(),
#             panel.grid.minor = element_blank(),
#             panel.border = element_blank(),
#             panel.background = element_blank(),
#             axis.title = element_blank(),
#             axis.text = element_blank(),
#             axis.ticks = element_blank(),
#             legend.position = legend.position,
#             legend.background = element_blank(),
#             legend.key = element_blank(),
#             strip.background = element_blank(),
#             strip.text = element_blank(),
#             plot.margin = plot.margin
#             )
#     return(p.tree)
#     }
#
# #-- test --#
# p.tree = plot_tree(merge.phy,
#           legend.title='Phylum',
#           legend.position='none',
#           plot.margin=unit(c(0,-0.1,0,2),'cm'))
# p.tree

# %%
# %%R
#
# g_legend = function(a.gplot, text.size = 20, legend.position=c(0.5, 0.5)){
#     # function for plotting just legend
#     a.gplot = a.gplot + theme(legend.position=legend.position,
#                               text = element_text(size=text.size))
#     tmp = ggplot_gtable(ggplot_build(a.gplot))
#     leg = which(sapply(tmp$grobs, function(x) x$name) == "guide-box")
#     legend = tmp$grobs[[leg]]
#     return(legend)
#     }
#
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
#
# as.Num = function(x){ x %>% as.character %>% as.numeric }
#
# order_metadata_to_tree = function(physeq, metadata){
#     # function for parsing & giving y (y.tree) value to metadata
#
#     # get tree coords
#     treeSegs = phyloseq:::tree_layout(phy_tree(physeq), ladderize='right')
#
#     # edge parsing
#     edge_otu.df = treeSegs$edgeDT[! is.na(treeSegs$edgeDT$OTU)] %>%
#                 as.matrix %>%
#                 as.data.frame %>%
#                 mutate(y.tree = y %>% as.Num) %>%
#                 select(OTU, y.tree)
#
#     # joining leaf edge and metadata
#     inner_join(edge_otu.df, metadata, c('OTU' = 'OTU'))
#     }
#
# #-- test --#
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
#
# df.l2fc.ord = order_metadata_to_tree(merge.phy, df.l2fc.s)
# df.l2fc.ord %>% head(n=4)
# Out:
#        OTU y.tree log2FoldChange         p Day Plant     p.adj     RelAbund
# 1 OTU.4087   4981    1.763280694 0.1742325  36 FAGES 0.8275676 1.584121e-05
# 2 OTU.4087   4981    0.006397593 0.5982452  53 AMAPO 1.0000000 0.000000e+00
# 3 OTU.4087   4981    0.536219786 0.4924229  53 ECHCG 1.0000000 0.000000e+00
# 4 OTU.4087   4981    2.929335792 0.0664975  61 SETFA 0.4371311 2.832002e-05

# %% [markdown]
# ### Ordering plants by phylogenetic distance

# %%
# %%R
#
# # calc wUnifrac distance
# calc.wunif.dist = function(physeq, cores=8){
#     registerDoParallel(cores=cores)
#     wunif.dist = distance(physeq,
#                           method = "unifrac",
#                           weighted = TRUE,
#                           fast = TRUE,
#                           parallel = TRUE,
#                           normalized = FALSE)
#     return(wunif.dist)
#     }
#
#
# # ordering substrates by w-unifrac distances between plants
# order_plants_by_responders = function(metadata, physeq, p.adj.cutoff=0.05, ...){
#
#     # filtering physeq to just incorporators
#     responders = metadata %>%
#         filter(p.adj < p.adj.cutoff)
#     taxa.names = taxa_names(physeq)
#     taxa.to.rm = taxa.names[taxa.names %in% responders$OTU]
#     physeq.cut = prune_taxa(taxa.to.rm, physeq)
#
#     # merging samples by Plant
#     physeq.cut.merge = merge_samples(physeq.cut, "Plant")
#
#     # removing 12C-con
#     physeq.md = physeq.cut.merge %>% sample_data
#     physeq.md$Plant = rownames(physeq.md)
#     sample_data(physeq.cut.merge) = physeq.md
#     physeq.cut.merge = prune_samples(physeq.md$Plant != 'BARE', physeq.cut.merge)
#
#     # w-unifrac
#     wunif.dist = calc.wunif.dist(physeq.cut.merge, ...)
#
#     # hclust of w-unifrac values
#     wunif.clust = hclust(wunif.dist, method='average')
#
#     # ordering metadata by hclust ordering
#     Plants = metadata$Plant %>% as.vector %>% unique
#     Plants = Plants[wunif.clust$order]
#     metadata$Plant = factor(metadata$Plant, levels=Plants)
#
#     return(metadata)
# }
#
# #-- test --#
# #calc.wunif.dist(physeq.thresh, cores=20)
# df.l2fc.ord2 = order_plants_by_responders(df.l2fc.ord, physeq.Full, cores=nprocs)
# df.l2fc.ord2 %>% head(n=4)
# Out:
#        OTU y.tree log2FoldChange         p Day Plant     p.adj     RelAbund
# 1 OTU.4087   4981    1.763280694 0.1742325  36 FAGES 0.8275676 1.584121e-05
# 2 OTU.4087   4981    0.006397593 0.5982452  53 AMAPO 1.0000000 0.000000e+00
# 3 OTU.4087   4981    0.536219786 0.4924229  53 ECHCG 1.0000000 0.000000e+00
# 4 OTU.4087   4981    2.929335792 0.0664975  61 SETFA 0.4371311 2.832002e-05

# %% [markdown]
# ## Alternate function to order plants by Day of Sampling or Type of Plant

# %%
# %%R
# sample_data(physeq.Full)$Type %>% levels
# Out:
# [1] "BARE"      "C4_Grass"  "Dicot-Myc" "Dicot-NM"  "Legume"    "Maize"

# %%
# %%R
#
# # read phylogenetic distance, expanded with 0.0002 between maize
# phy_expand = read.csv(file = "/home/bryan/RhizCG/PhyDist/phyDist_expanded.csv", header = TRUE)
# colnames(phy_expand)[12] = "75-062"
#
# pd.m = melt(as.matrix(phy_expand))
#
# #set column names and create comparison column
# colnames(pd.m) = c("PlantA", "PlantB", "phy_Dist")
# pd.m$PlantComp = paste(pd.m$PlantA, pd.m$PlantB, sep = "-")
# pd.m %>% head
# Out:
#   PlantA PlantB phy_Dist   PlantComp
# 1  FAGES  FAGES  0.00000 FAGES-FAGES
# 2  AMAPO  FAGES  0.23210 AMAPO-FAGES
# 3  HELAN  FAGES  0.25302 HELAN-FAGES
# 4  ABUTH  FAGES  0.27096 ABUTH-FAGES
# 5  GLYMA  FAGES  0.35879 GLYMA-FAGES
# 6  SORBI  FAGES  0.43476 SORBI-FAGES

# %%
# %%R
# treeFile = '/home/bryan/RhizCG/PhyDist/20160209_phylogeny.tre'
# NAMFile = '/home/bryan/RhizCG/PhyDist/NAM_founders_distanceMatrix_v2.txt'
# NAMdist = read.table(NAMFile, header = TRUE)
# #reorder so that NAMdist is in same order as log2fold change matrix
# NAMdist = NAMdist[c(1:6, 8, 7, 9, 10), c(1:6, 8, 7, 9, 10)]
#
# nd.m = melt(as.matrix(NAMdist))
#
# #set column names and create comparison column
# colnames(nd.m) = c("PlantA", "PlantB", "gene_Dist")
# nd.m$PlantComp = paste(nd.m$PlantA, nd.m$PlantB, sep = "-")
# nd.m %>% head
# Out:
#   PlantA PlantB gene_Dist PlantComp
# 1    B73    B73 0.0000000   B73-B73
# 2    B97    B73 0.1285456   B97-B73
# 3    H99    B73 0.1306701   H99-B73
# 4  Hp301    B73 0.1357241 Hp301-B73
# 5  Il14H    B73 0.1412994 Il14H-B73
# 6    Ki3    B73 0.1413460   Ki3-B73

# %%
# %%R
# #Join distance tables
# Dist = left_join(pd.m, nd.m[,c(3,4)], by = "PlantComp")
# #scale phydist by namDist using ifelse statement to remove NAs
# Dist$TreeDist = ifelse(is.na(Dist$gene_Dist), Dist$phy_Dist, Dist$phy_Dist*Dist$gene_Dist)
# head(Dist)
# Out:
#   PlantA PlantB phy_Dist   PlantComp gene_Dist TreeDist
# 1  FAGES  FAGES  0.00000 FAGES-FAGES        NA  0.00000
# 2  AMAPO  FAGES  0.23210 AMAPO-FAGES        NA  0.23210
# 3  HELAN  FAGES  0.25302 HELAN-FAGES        NA  0.25302
# 4  ABUTH  FAGES  0.27096 ABUTH-FAGES        NA  0.27096
# 5  GLYMA  FAGES  0.35879 GLYMA-FAGES        NA  0.35879
# 6  SORBI  FAGES  0.43476 SORBI-FAGES        NA  0.43476

# %%
# %%R
# Dist.c = cast(Dist[,c(1,2,6)], PlantA~PlantB, mean) %>% as.dist
# Out:
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Using TreeDist as value column.  Use the value argument to cast to override this choice
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %%
# %%R
# Dist_hc = hclust(as.dist(Dist.c), "average")
# plot(Dist_hc)
# Dist_hc
# Out:
# Call:
# hclust(d = as.dist(Dist.c), method = "average")
#
# Cluster method   : average
# Number of objects: 22

# %%
# %%R
# #Function is taking an input deseq object that has been mapped to tree ($y.tree), then ordering the
# #groups by another variable.  Above this is done with the clustering of incorporators.  Here this is done
# # with phylogenetic tree
#
# # Needed inputs
# ## 1) Metadata ordered to tree, in this case df.l2fc.ord
# ## 2) Phyloseq object, in this pase Physeq.Full is trimmed within the function to just responders
#
# ##Goal, order to DAP
#
#
# # ordering substrates by w-unifrac distances between plants
# order_metadata_by_phylogeny = function(metadata, ...){
#
#
# #ordering metadata by hclust ordering
#     #Plants = metadata$Plant %>% as.vector %>% unique
#     #Plants = Plants[hc_object$order]
#     Plants = c("75-062", "Hp301", "Il14H", "H99", "B97", "MS71", "B73", "Oh7B", "Ki3", "Mo18", "Tx303", "SORBI",
#   "SORSUD", "ECHCG", "SETFA", "ELCOR", "ERATE", "GLYMA", "FAGES", "AMAPO", "ABUTH", "HELAN")
#
#     metadata$Plant = factor(metadata$Plant, levels=Plants)
#
#     return(metadata)
#  }
#
# # #-- test --#
#
# df.l2fc.ord2 = order_plants_by_phylogeny(df.l2fc.ord, Dist_hc)
# df.l2fc.ord2 %>% head(n=4)
# Out:
# Error in withVisible({ :
#   could not find function "order_plants_by_phylogeny"

# %%
# %%R
# Responders$RelAbund %>% log2 %>% hist
# Out:
# Error in eval(expr, envir, enclos) : object 'Responders' not found

# %%
# %%R
# range(df.l2fc.ord$RelAbund, na.rm = TRUE) %>% print
# range(Responders$RelAbund, na.rm = TRUE) %>% print
# Out:
# [1] 0.00000000 0.05550029
# Error in eval(expr, envir, enclos) : object 'Responders' not found

# %%
# %%R -w 600
#
# # function for making incorporator plot
# responders_plot = function(metadata, plot.margin=NULL){
#     if(is.null(plot.margin)){
#         plot.margin = unit(c(0.1,0,0,-0.7), "cm")  # top, right, bottom, left
#     }
#
#
# metadata.ord = metadata %>%
#         mutate(responder = p.adj < 0.05,
#                responder.num = responder %>% as.numeric,
#                Day = Day %>% as.character)
#
#     metadata.ord$Day = reorder(metadata.ord$Day, metadata.ord$Day %>% as.numeric)
#
#     min.y = metadata.ord$y.tree %>% min(na.rm=T)
#     max.y = metadata.ord$y.tree %>% max(na.rm=T)
#
# Responders = filter(metadata.ord, p.adj <0.05 & log2FoldChange > 0)
#     NonResp = filter(metadata.ord, p.adj >0.05 )
#     Filtered = filter(metadata.ord, is.na(p.adj))
#
# p.responder = ggplot() +
#     geom_tile(data = NonResp, aes(Day, y.tree, alpha=responder.num), fill = "black") +
#     scale_y_continuous(expand=c(0,0)) +
#
#     geom_tile(data = Responders, aes(Day, y.tree, fill = RelAbund)) +
#     scale_fill_gradient( low = "Yellow", high = "Orange", limit = c(.00001733848, .0555003)) +
#     scale_y_continuous(expand=c(0,0)) +
#
#         facet_grid(. ~ Plant, scales='free_x') +
#         theme_bw() +
#         theme(
#             panel.grid.major = element_blank(),
#             panel.grid.minor = element_blank(),
#             axis.text.x = element_text(angle=90, vjust=0.5, hjust=1),
#             axis.title.y = element_blank(),
#             axis.text.y = element_blank(),
#             axis.ticks.y = element_blank(),
#             legend.position = 'none',
#             plot.margin = plot.margin
#             )
#     return(p.responder)
#     }
#
# #-- test --#
# p.responders = responders_plot(df.l2fc.ord2)
# p.responders
# Out:
# Error in eval(expr, envir, enclos) : object 'df.l2fc.ord2' not found
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Error in eval(expr, envir, enclos) : object 'df.l2fc.ord2' not found
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %%
# %%R -w 800 -h 1000
#
# resize_ggplots = function(ggplot.list,
#                           resize.index = length(ggplot.list),
#                           widths=rep(1, length(ggplot.list))){
#     # other.plots = list of plots
#     stopifnot(class(ggplot.list)[1] == 'list')
#
#     ## making gtables
#     make_gt = function(x) ggplot_gtable(ggplot_build(x))
#     gt = lapply(ggplot.list, make_gt)
#
#     # resizing
#     gt.len = length(gt)
#     for(i in 1:gt.len){
#         if(i == resize.index){
#             next
#         } else {
#             gt[[i]]$heights = gt[[resize.index]]$heights
#         }
#     }
#
#     # grid.arrange params
#     params.l = list('ncol' = gt.len, 'widths' = widths)
#
#     # return list of gtables + params
#     return(c(gt, params.l))
#     }
#
# x = resize_ggplots(list(p.tree, p.responders, p.rel.abund, p.rel.total.abund),
#                    widths=c(.6,1.8,0.18,0.15))
# do.call(grid.arrange, x)

# %%
# %%R -w 800 -h 1000
# # tree plot
# p.tree = plot_tree(merge.phy,
#                    legend.title=' Phylum',
#                    y.expand=c(0.001,0.001),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(merge.phy, df.l2fc.s)
#
# ## Order plants by phylogeny
# df.l2fc.ord = order_metadata_by_phylogeny(df.l2fc.ord)
# ## plants by date
# #df.l2fc.ord = order_plants_by_Library(df.l2fc.ord, physeq.Full, cores=nprocs)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord)
#
# # # bulk abundance plots
# # df.bulk = bulk_abund_plot_df(physeq.bare, df.l2fc.ord)
# # p.rel.abund = bulk_rel_abund_plot(df.bulk, plot.margin=unit(c(0,0,0,-0.4), 'cm'))
# # p.rel.total.abund = bulk_rel_total_abund_plot(df.bulk, bar.width=2,
# #                                               plot.margin=unit(c(2,0.2,2,-0.38), 'cm'))
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders, p.rel.abund, p.rel.total.abund),
#                     widths=c(.6,1.8,0.18,0.15))
# do.call(grid.arrange, gt)

# %%
# %%R
# df.l2fc.ord$OTU %>% unique %>% length
# Out:
# [1] 4982

# %%
# %%R
# # tree legend
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
# # saving figure
# outFile = 'allPhyla_sparCut3in3_relabund.jpeg'
# outFile = paste(c(figDir, outFile), collapse='/')
# jpeg(outFile, width= 9, height= 8, units = "in", res = 150)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'allPhyla_sparCut3in3_relabund_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## full tree; just incorporators with greather than 0.001 rel abund

# %%
# %%R
# # adding incorporator status to tax_table
# p.adj.cutoff = 0.05
#
# physeq.Full.resp = physeq.Full
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8) %>%
#     group_by(OTU) %>%
#     summarize(Responder = any(p.adj < p.adj.cutoff & RelAbund > 0.001) %>% as.numeric) %>%
#     ungroup()
#
# tax = physeq.Full.resp %>% tax_table %>% as.data.frame
# tax$OTU = rownames(tax)
# tax.j = left_join(tax, df.l2fc.s, c('OTU' = 'OTU')) %>%
#     mutate(Responder = ifelse(is.na(Responder), 0, Responder)) %>%
#     as.data.frame()
# rownames(tax.j) = tax.j$OTU %>% as.character
# tax.j$OTU = NULL
#
# # making new phyloseq object with incorporator info
# physeq.Full.resp = phyloseq(physeq.Full.resp %>% otu_table,
#                              tax.j %>% as.matrix %>% tax_table,
#                              physeq.Full.resp %>% sample_data,
#                              physeq.Full.resp %>% phy_tree)
# physeq.Full.resp = subset_taxa(physeq.Full.resp, Responder==1)
# physeq.Full.resp
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 327 taxa and 238 samples ]
# sample_data() Sample Data:       [ 238 samples by 55 sample variables ]
# tax_table()   Taxonomy Table:    [ 327 taxa by 9 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 327 tips and 326 internal nodes ]

# %%
# %%R -w 800 -h 800
#
# p.tree = plot_tree(physeq.Full.resp,
#                    legend.title=' Phylum',
#                    y.expand=c(0.003,0.003),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq.Full.resp, df.l2fc.s)
# ## substrates by similarity of responders
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord)
#
# # # bulk abundance plots
# # df.bulk = bulk_abund_plot_df(physeq.bare, df.l2fc.ord)
# # p.rel.abund = bulk_rel_abund_plot(df.bulk, plot.margin=unit(c(0,0,0,-0.4), 'cm'))
# # p.rel.total.abund = bulk_rel_total_abund_plot(df.bulk, bar.width=1.25,
# #                                               plot.margin=unit(c(2,0.2,2,-0.38), 'cm'))
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(0.7,1.5))
# do.call(grid.arrange, gt)

# %% [markdown]
# ### Simple plot: not bulk abundance data

# %%
# %%R -w 800 -h 800
#
# p.tree = plot_tree(physeq.Full.resp,
#                    legend.title=' Phylum',
#                    y.expand=c(0.003,0.003),
#                    plot.margin=unit(c(0,-0.2,0,0), 'cm'))
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq.Full.resp, df.l2fc.s)
# ## substrates by similarity of incorporators
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full.resp, cores=nprocs)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord)
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(0.7,1.8))
# do.call(grid.arrange, gt)

# %%
# %%R
# # saving figure
# outFile = 'allPhyla-resp_thresh_sparCut3in3_relabund.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=800 / 65, height=800 / 65)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'allPhyla-resp_thresh_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# grid.draw(my.legend)

# %% [markdown]
# ### simple plot not bulk abundance data organized by DAP

# %%
# %%R -w 800 -h 800
#
# p.tree = plot_tree(physeq.Full.resp,
#                    legend.title=' Phylum',
#                    y.expand=c(0.003,0.003),
#                    plot.margin=unit(c(0,-0.2,0,0), 'cm'))
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq.Full.resp, df.l2fc.s)
# ## substrates by similarity of incorporators
# df.l2fc.ord = order_plants_by_day(df.l2fc.ord, physeq.Full.resp, cores=nprocs)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord)
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(0.7,1.3))
# do.call(grid.arrange, gt)
# Out:
# Error in withVisible({ : could not find function "order_plants_by_day"
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Error in withVisible({ : could not find function "order_plants_by_day"
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %%
# %%R
# # saving figure
# outFile = 'allPhyla-resp_byDay_sparCut3in3.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=800 / 65, height=800 / 65)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'allPhyla-resp_byDay_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# # Figures for each phylum

# %%
# %%R
# # ordering plants by full tree order (all incorporators)
# full.tree.ord = df.l2fc.ord$Plant %>% levels
# full.tree.ord
# Out:
#  [1] "FAGES"  "AMAPO"  "ECHCG"  "ABUTH"  "GLYMA"  "SETFA"  "75-062" "ERATE"
#  [9] "H99"    "Il14H"  "MS71"   "B73"    "B97"    "Hp301"  "Oh7B"   "HELAN"
# [17] "SORBI"  "SORSUD" "ELCOR"  "Ki3"    "Mo18"   "Tx303"

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Proteobacteria"
# physeq_1phy = subset_taxa(physeq.Full.resp, Rank2==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank3',
#                    legend.title='Class',
#                    y.expand=c(0.002,0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord)
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(0.7,1.5))
# do.call(grid.arrange, gt)

# %% [markdown]
# # Figures for each phylum

# %%
# %%R
# # ordering substrates by full tree order (all incorporators)
# full.tree.ord = df.l2fc.ord$Plant %>% levels
# full.tree.ord
# Out:
#  [1] "75-062" "Hp301"  "Il14H"  "H99"    "B97"    "MS71"   "B73"    "Oh7B"
#  [9] "Ki3"    "Mo18"   "Tx303"  "SORBI"  "SORSUD" "ECHCG"  "SETFA"  "ELCOR"
# [17] "ERATE"  "GLYMA"  "FAGES"  "AMAPO"  "ABUTH"  "HELAN"

# %%
# %%R
# # total OTU counts for each day (for normalizing)
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq.Full, df.l2fc.s)
#
# # bulk abundance plots
# df.bulk = bulk_abund_plot_df(physeq.Full, df.l2fc.ord)
#
# # total OTU counts for bulk soils
# total.counts = df.bulk %>%
#     group_by(Day) %>%
#     summarize(total_count = sum(count)) %>%
#     as.data.frame
#
# total.counts
# Out:
#   Day total_count
# 1  36      345731
# 2  53      538309
# 3  57      395462
# 4  61      490806
# 5  72      460647
# 6  79      529997
# 7  84       97075
# 8  88       86071

# %% [markdown]
# # Table summary of responders at phylum level

# %% [markdown]
# ### Number of responders per phylum of abundant taxa (> 0.001 relative abundance)

# %%
# %%R
# physeq.tax = physeq.Full.resp  %>% tax_table %>% as.matrix %>% as.data.frame
# physeq.tax$Rank2 %>% table %>% sort(decreasing=T)
# Out:
# .
#   Proteobacteria   Actinobacteria      Chloroflexi    Bacteroidetes
#              139               66               33               30
#    Acidobacteria       Firmicutes  Verrucomicrobia    Cyanobacteria
#               17               12               11                6
#   Planctomycetes    Fibrobacteres Gemmatimonadetes     Spirochaetes
#                6                2                2                2
#  Armatimonadetes
#                1

# %%
# %%R
# R %>% head
# Out:
#   log2FoldChange            p    Rank1         Rank2
# 1       1.797665 4.162088e-04 Bacteria Acidobacteria
# 2       2.336543 3.965295e-03 Bacteria Acidobacteria
# 3       1.562344 2.156499e-04 Bacteria Acidobacteria
# 4       1.968877 5.971283e-04 Bacteria Acidobacteria
# 5       2.204226 2.165542e-07 Bacteria Acidobacteria
# 6       2.233963 1.110414e-04 Bacteria Acidobacteria
#                            Rank3                Rank4                Rank5
# 1                          DA023 uncultured_bacterium                 <NA>
# 2                     Holophagae            43F-1404R                 <NA>
# 3                     Holophagae            43F-1404R uncultured_bacterium
# 4                     Holophagae            43F-1404R uncultured_bacterium
# 5 Candidatus_Chloracidobacterium uncultured_bacterium                 <NA>
# 6 Candidatus_Chloracidobacterium                 <NA>                 <NA>
#   Rank6 Rank7 Rank8      OTU Day Plant        p.adj     RelAbund
# 1  <NA>  <NA>  <NA> OTU.7789  36 FAGES 7.536174e-03 0.0003722684
# 2  <NA>  <NA>  <NA> OTU.1763  36 FAGES 4.950377e-02 0.0002257372
# 3  <NA>  <NA>  <NA> OTU.5587  36 FAGES 4.320464e-03 0.0009267107
# 4  <NA>  <NA>  <NA> OTU.7307  36 FAGES 1.023888e-02 0.0005584026
# 5  <NA>  <NA>  <NA>  OTU.504  36 FAGES 9.600572e-06 0.0006296880
# 6  <NA>  <NA>  <NA>  OTU.745  36 FAGES 2.433704e-03 0.0004554347

# %%
# %%R
# #list of OTUs to trim physeq object
# R = df.l2fc %>% filter(p.adj < 0.05)
# mytaxa = as.character(R$OTU)
#
# #Trim phyloseq object
# merge.R = merge.phy %>% subset_samples(Plant != "BARE")
# merge.R = prune_taxa(mytaxa, merge.R)
# merge.R
#
# #Export to dataframe and join with log2F table
# PlantRel = merge.R %>% otu_table %>%  t() %>% as.data.frame
#
# PlantRel$OTU = rownames(PlantRel)
#
# #Export taxonomy
# Taxonomy = merge.R %>% tax_table %>% as.data.frame
# Taxonomy$OTU = rownames(Taxonomy)
#
# PlantRel = inner_join(Taxonomy, PlantRel, by = "OTU")
# PlantRel %>% head
# Out:
#      Rank1         Rank2                Rank3                Rank4 Rank5 Rank6
# 1 Bacteria           TM6 uncultured_bacterium                 <NA>  <NA>  <NA>
# 2 Bacteria           TM6 uncultured_bacterium                 <NA>  <NA>  <NA>
# 3 Bacteria Elusimicrobia          Lineage_IIb uncultured_bacterium  <NA>  <NA>
# 4 Bacteria Elusimicrobia          Lineage_IIb uncultured_bacterium  <NA>  <NA>
# 5 Bacteria Elusimicrobia               MVP-88 uncultured_bacterium  <NA>  <NA>
# 6 Bacteria   Chloroflexi          Gitt-GS-136                 <NA>  <NA>  <NA>
#   Rank7 Rank8      OTU       75-062        ABUTH        AMAPO          B73
# 1  <NA>  <NA> OTU.4087 0.000000e+00 0.000000e+00 0.000000e+00 8.669242e-06
# 2  <NA>  <NA> OTU.2009 3.511441e-05 0.000000e+00 3.386253e-05 8.958217e-05
# 3  <NA>  <NA> OTU.1285 9.754004e-05 9.967219e-05 1.749564e-04 4.912571e-05
# 4  <NA>  <NA> OTU.3513 1.950801e-05 1.107469e-05 2.821877e-05 1.733848e-05
# 5  <NA>  <NA> OTU.6694 1.950801e-05 2.214938e-05 1.693126e-05 3.467697e-05
# 6  <NA>  <NA>  OTU.212 1.217300e-03 1.395411e-03 1.687483e-03 8.669242e-04
#            B97        ECHCG        ELCOR        ERATE        FAGES        GLYMA
# 1 4.174581e-05 0.000000e+00 0.000000e+00 0.000000e+00 1.584121e-05 0.000000e+00
# 2 1.013827e-04 0.000000e+00 4.312637e-05 2.284973e-05 7.920604e-06 1.333422e-05
# 3 3.876397e-05 1.381635e-05 1.437546e-04 1.051087e-04 3.643478e-04 1.333422e-05
# 4 1.789106e-05 2.763271e-05 5.750183e-05 2.284973e-05 9.108694e-05 0.000000e+00
# 5 5.963687e-05 1.381635e-05 1.006282e-04 1.508082e-04 1.584121e-05 1.333422e-05
# 6 1.413394e-03 1.229655e-03 1.049408e-03 7.631809e-04 1.790056e-03 1.386759e-03
#            H99        HELAN        Hp301        Il14H          Ki3         Mo18
# 1 0.000000e+00 0.000000e+00 2.302794e-05 2.405436e-06 7.407316e-05 0.000000e+00
# 2 1.391453e-05 0.000000e+00 1.151397e-05 4.089242e-05 9.876421e-05 4.592528e-05
# 3 1.159544e-04 1.263073e-05 1.381677e-04 6.494678e-05 2.098740e-04 9.185056e-05
# 4 6.029629e-05 0.000000e+00 4.605589e-05 2.645980e-05 7.407316e-05 1.148132e-05
# 5 5.565811e-05 0.000000e+00 6.908383e-05 3.127067e-05 1.234553e-05 3.444396e-05
# 6 2.026883e-03 3.132421e-03 1.243509e-03 7.384689e-04 1.049370e-03 1.584422e-03
#           MS71         Oh7B        SETFA        SORBI       SORSUD        Tx303
# 1 2.409946e-06 4.921151e-06 2.832002e-05 0.000000e+00 0.000000e+00 0.000000e+00
# 2 4.337903e-05 2.460575e-05 1.618287e-05 2.282792e-05 1.157943e-05 2.412953e-05
# 3 9.398791e-05 8.612014e-05 4.450288e-05 6.848377e-05 3.473830e-05 1.608635e-04
# 4 4.337903e-05 2.952691e-05 3.236573e-05 2.282792e-05 0.000000e+00 4.825905e-05
# 5 8.434812e-05 1.156470e-04 6.068575e-05 3.424188e-05 3.473830e-05 8.043176e-06
# 6 1.486937e-03 1.414831e-03 1.120663e-03 2.807835e-03 2.547476e-03 1.544290e-03

# %% [markdown]
# # Phylum stats

# %%
# %%R
# dim(PlantRel)
# Out:
# [1] 1506   31

# %%
# %%R
# colnames(PlantRel)
# Out:
#  [1] "Rank1"  "Rank2"  "Rank3"  "Rank4"  "Rank5"  "Rank6"  "Rank7"  "Rank8"
#  [9] "OTU"    "75-062" "ABUTH"  "AMAPO"  "B73"    "B97"    "ECHCG"  "ELCOR"
# [17] "ERATE"  "FAGES"  "GLYMA"  "H99"    "HELAN"  "Hp301"  "Il14H"  "Ki3"
# [25] "Mo18"   "MS71"   "Oh7B"   "SETFA"  "SORBI"  "SORSUD" "Tx303"

# %%
# %%R
# #calculating OTU stats
# PlantRel$min = apply(PlantRel[,10:31], 1, FUN = min)
# PlantRel$max = apply(PlantRel[,10:31], 1, FUN = max)
# PlantRel$median = apply(PlantRel[,10:31], 1, FUN = min)
# PlantRel %>% head
# Out:
#      Rank1         Rank2                Rank3                Rank4 Rank5 Rank6
# 1 Bacteria           TM6 uncultured_bacterium                 <NA>  <NA>  <NA>
# 2 Bacteria           TM6 uncultured_bacterium                 <NA>  <NA>  <NA>
# 3 Bacteria Elusimicrobia          Lineage_IIb uncultured_bacterium  <NA>  <NA>
# 4 Bacteria Elusimicrobia          Lineage_IIb uncultured_bacterium  <NA>  <NA>
# 5 Bacteria Elusimicrobia               MVP-88 uncultured_bacterium  <NA>  <NA>
# 6 Bacteria   Chloroflexi          Gitt-GS-136                 <NA>  <NA>  <NA>
#   Rank7 Rank8      OTU       75-062        ABUTH        AMAPO          B73
# 1  <NA>  <NA> OTU.4087 0.000000e+00 0.000000e+00 0.000000e+00 8.669242e-06
# 2  <NA>  <NA> OTU.2009 3.511441e-05 0.000000e+00 3.386253e-05 8.958217e-05
# 3  <NA>  <NA> OTU.1285 9.754004e-05 9.967219e-05 1.749564e-04 4.912571e-05
# 4  <NA>  <NA> OTU.3513 1.950801e-05 1.107469e-05 2.821877e-05 1.733848e-05
# 5  <NA>  <NA> OTU.6694 1.950801e-05 2.214938e-05 1.693126e-05 3.467697e-05
# 6  <NA>  <NA>  OTU.212 1.217300e-03 1.395411e-03 1.687483e-03 8.669242e-04
#            B97        ECHCG        ELCOR        ERATE        FAGES        GLYMA
# 1 4.174581e-05 0.000000e+00 0.000000e+00 0.000000e+00 1.584121e-05 0.000000e+00
# 2 1.013827e-04 0.000000e+00 4.312637e-05 2.284973e-05 7.920604e-06 1.333422e-05
# 3 3.876397e-05 1.381635e-05 1.437546e-04 1.051087e-04 3.643478e-04 1.333422e-05
# 4 1.789106e-05 2.763271e-05 5.750183e-05 2.284973e-05 9.108694e-05 0.000000e+00
# 5 5.963687e-05 1.381635e-05 1.006282e-04 1.508082e-04 1.584121e-05 1.333422e-05
# 6 1.413394e-03 1.229655e-03 1.049408e-03 7.631809e-04 1.790056e-03 1.386759e-03
#            H99        HELAN        Hp301        Il14H          Ki3         Mo18
# 1 0.000000e+00 0.000000e+00 2.302794e-05 2.405436e-06 7.407316e-05 0.000000e+00
# 2 1.391453e-05 0.000000e+00 1.151397e-05 4.089242e-05 9.876421e-05 4.592528e-05
# 3 1.159544e-04 1.263073e-05 1.381677e-04 6.494678e-05 2.098740e-04 9.185056e-05
# 4 6.029629e-05 0.000000e+00 4.605589e-05 2.645980e-05 7.407316e-05 1.148132e-05
# 5 5.565811e-05 0.000000e+00 6.908383e-05 3.127067e-05 1.234553e-05 3.444396e-05
# 6 2.026883e-03 3.132421e-03 1.243509e-03 7.384689e-04 1.049370e-03 1.584422e-03
#           MS71         Oh7B        SETFA        SORBI       SORSUD        Tx303
# 1 2.409946e-06 4.921151e-06 2.832002e-05 0.000000e+00 0.000000e+00 0.000000e+00
# 2 4.337903e-05 2.460575e-05 1.618287e-05 2.282792e-05 1.157943e-05 2.412953e-05
# 3 9.398791e-05 8.612014e-05 4.450288e-05 6.848377e-05 3.473830e-05 1.608635e-04
# 4 4.337903e-05 2.952691e-05 3.236573e-05 2.282792e-05 0.000000e+00 4.825905e-05
# 5 8.434812e-05 1.156470e-04 6.068575e-05 3.424188e-05 3.473830e-05 8.043176e-06
# 6 1.486937e-03 1.414831e-03 1.120663e-03 2.807835e-03 2.547476e-03 1.544290e-03
#            min          max       median
# 1 0.000000e+00 7.407316e-05 0.000000e+00
# 2 0.000000e+00 1.013827e-04 0.000000e+00
# 3 1.263073e-05 3.643478e-04 1.263073e-05
# 4 0.000000e+00 9.108694e-05 0.000000e+00
# 5 0.000000e+00 1.508082e-04 0.000000e+00
# 6 7.384689e-04 3.132421e-03 7.384689e-04

# %%
# %%R
# #calculate OTU stats for each phyla
# OTU_level = PlantRel %>% group_by(Rank2) %>%
#     summarize(Median = median(median),
#              Max = mean(max),
#              Min = min(min),
#             count = length(Rank2)) %>%
#      arrange(desc(count))
# colnames(OTU_level) = c("Rank2", "OTU_Median", "OTU_Max", "OTU_Min", "OTU_count")
# OTU_level
# Out:
# Source: local data frame [20 x 5]
#
#                      Rank2   OTU_Median      OTU_Max OTU_Min OTU_count
#                     (fctr)        (dbl)        (dbl)   (dbl)     (int)
# 1           Proteobacteria 7.920604e-06 1.551604e-03       0       507
# 2            Bacteroidetes 0.000000e+00 8.045637e-04       0       206
# 3           Actinobacteria 5.534924e-05 2.954526e-03       0       174
# 4              Chloroflexi 1.827978e-05 7.833390e-04       0       158
# 5           Planctomycetes 0.000000e+00 2.918767e-04       0       144
# 6          Verrucomicrobia 8.945531e-06 9.689389e-04       0        93
# 7               Firmicutes 0.000000e+00 2.794551e-03       0        58
# 8            Acidobacteria 3.894743e-05 9.631878e-04       0        56
# 9         Gemmatimonadetes 1.173017e-05 4.003143e-04       0        38
# 10           Cyanobacteria 0.000000e+00 6.771842e-04       0        24
# 11         Armatimonadetes 0.000000e+00 2.717567e-04       0        21
# 12           Fibrobacteres 0.000000e+00 4.760396e-04       0         8
# 13            Spirochaetes 0.000000e+00 1.113312e-03       0         5
# 14 Candidate_division_BRC1 0.000000e+00 2.982720e-04       0         3
# 15           Elusimicrobia 0.000000e+00 2.020810e-04       0         3
# 16                Chlorobi 5.789717e-06 2.225768e-04       0         2
# 17             Nitrospirae 0.000000e+00 4.633553e-04       0         2
# 18                     TM6 0.000000e+00 8.772792e-05       0         2
# 19  Candidate_division_OD1 0.000000e+00 1.227694e-04       0         1
# 20     Deinococcus-Thermus 0.000000e+00 3.592252e-04       0         1

# %%
# %%R
# colnames(PlantRel)
# Out:
#  [1] "Rank1"  "Rank2"  "Rank3"  "Rank4"  "Rank5"  "Rank6"  "Rank7"  "Rank8"
#  [9] "OTU"    "75-062" "ABUTH"  "AMAPO"  "B73"    "B97"    "ECHCG"  "ELCOR"
# [17] "ERATE"  "FAGES"  "GLYMA"  "H99"    "HELAN"  "Hp301"  "Il14H"  "Ki3"
# [25] "Mo18"   "MS71"   "Oh7B"   "SETFA"  "SORBI"  "SORSUD" "Tx303"  "min"
# [33] "max"    "median"

# %%
# %%R
# colnames(PL)
# Out:
#  [1] "Rank2"           "75-062"          "ABUTH"           "AMAPO"
#  [5] "B73"             "B97"             "ECHCG"           "ELCOR"
#  [9] "ERATE"           "FAGES"           "GLYMA"           "H99"
# [13] "HELAN"           "Hp301"           "Il14H"           "Ki3"
# [17] "Mo18"            "MS71"            "Oh7B"            "SETFA"
# [21] "SORBI"           "SORSUD"          "Tx303"           "Max_relabund"
# [25] "Min_relabund"    "Median_relabund"

# %%
# %%R
# #calculate OTU stats for each phyla
# PL = PlantRel[,c(2,10:31)] %>% group_by(Rank2) %>%
#     summarize_each(funs(sum))
# PL$Max_relabund = apply(PL[,2:23], 1, FUN = max)
# PL$Min_relabund = apply(PL[,2:23], 1, FUN = min)
# PL$Median_relabund = apply(PL[,2:23], 1, FUN = median)
# Phylum_level = (PL[,c("Rank2", "Min_relabund", "Max_relabund", "Median_relabund" )])
# Phylum_level
# Out:
# Source: local data frame [20 x 4]
#
#                      Rank2 Min_relabund Max_relabund Median_relabund
#                     (fctr)        (dbl)        (dbl)           (dbl)
# 1            Acidobacteria 9.346739e-03 0.0513215528    1.952954e-02
# 2           Actinobacteria 1.002075e-01 0.3194437427    1.595892e-01
# 3          Armatimonadetes 1.270860e-03 0.0036801173    2.101607e-03
# 4            Bacteroidetes 1.624289e-02 0.0740449363    4.066342e-02
# 5  Candidate_division_BRC1 2.315887e-05 0.0008633458    8.565661e-05
# 6   Candidate_division_OD1 0.000000e+00 0.0001227694    3.790324e-05
# 7                 Chlorobi 2.526146e-05 0.0003168242    1.044845e-04
# 8              Chloroflexi 1.751203e-02 0.0911404051    4.467883e-02
# 9            Cyanobacteria 7.577671e-04 0.0124907923    2.480864e-03
# 10     Deinococcus-Thermus 0.000000e+00 0.0003592252    4.313640e-05
# 11           Elusimicrobia 1.263073e-05 0.0004712759    1.376651e-04
# 12           Fibrobacteres 2.214938e-05 0.0035219873    5.453321e-04
# 13              Firmicutes 2.371951e-03 0.0986625770    1.301014e-02
# 14        Gemmatimonadetes 1.528318e-03 0.0116591289    4.814106e-03
# 15             Nitrospirae 0.000000e+00 0.0009267107    1.268632e-04
# 16          Planctomycetes 5.077553e-03 0.0362486436    1.167119e-02
# 17          Proteobacteria 1.402733e-01 0.4133542236    2.356425e-01
# 18            Spirochaetes 1.894609e-04 0.0055201760    5.235221e-04
# 19                     TM6 0.000000e+00 0.0001728374    3.169472e-05
# 20         Verrucomicrobia 1.066033e-02 0.0425488015    3.027248e-02

# %%
# %%R
# Tbl = full_join(OTU_level, Phylum_level, by = "Rank2") %>% arrange(desc(OTU_count))
# Tbl
# write.csv(Tbl, file = '/home/bryan/RhizCG/figures/PhylumStats.csv', sep = ",")

# %% [markdown]
# ## Family level

# %%
# %%R
# #calculate OTU stats for each phyla
# OTU_level = PlantRel %>% group_by(Rank2, Rank3, Rank4, Rank5) %>%
#     summarize(
#                 Median = median(median),
#              Max = mean(max),
#              Min = min(min),
#             count = length(Rank5)) %>%
#      arrange(desc(count))
# colnames(OTU_level) = c("Rank2", "Rank3", "Rank4", "Rank5", "OTU_Median", "OTU_Max", "OTU_Min", "OTU_count")
# OTU_level
# Out:
# Source: local data frame [251 x 8]
# Groups: Rank2, Rank3, Rank4 [136]
#
#            Rank2                          Rank3
#           (fctr)                         (fctr)
# 1  Acidobacteria                          11-24
# 2  Acidobacteria Candidatus_Chloracidobacterium
# 3  Acidobacteria Candidatus_Chloracidobacterium
# 4  Acidobacteria Candidatus_Chloracidobacterium
# 5  Acidobacteria          Candidatus_Solibacter
# 6  Acidobacteria                          DA023
# 7  Acidobacteria                          DA023
# 8  Acidobacteria                          DA023
# 9  Acidobacteria                         DS-100
# 10 Acidobacteria                     Holophagae
# ..           ...                            ...
# Variables not shown: Rank4 (fctr), Rank5 (fctr), OTU_Median (dbl), OTU_Max
#   (dbl), OTU_Min (dbl), OTU_count (int)

# %%
# %%R
# colnames(PlantRel)
# Out:
#  [1] "Rank1"  "Rank2"  "Rank3"  "Rank4"  "Rank5"  "Rank6"  "Rank7"  "Rank8"
#  [9] "OTU"    "75-062" "ABUTH"  "AMAPO"  "B73"    "B97"    "ECHCG"  "ELCOR"
# [17] "ERATE"  "FAGES"  "GLYMA"  "H99"    "HELAN"  "Hp301"  "Il14H"  "Ki3"
# [25] "Mo18"   "MS71"   "Oh7B"   "SETFA"  "SORBI"  "SORSUD" "Tx303"  "min"
# [33] "max"    "median"

# %%
# %%R
# #calculate OTU stats for each phyla
# FL = PlantRel[,c(2,3,4,5,10:31)] %>% group_by(Rank2, Rank3, Rank4, Rank5) %>%
#     summarize_each(funs(sum))
# colnames(FL)
# FL$Max_relabund = apply(FL[,5:26], 1, FUN = max)
# FL$Min_relabund = apply(FL[,5:26], 1, FUN = min)
# FL$Median_relabund = apply(FL[,5:26], 1, FUN = median)
# Family_level = (FL[,c("Rank2", "Rank3", "Rank4","Rank5", "Min_relabund", "Max_relabund", "Median_relabund" )])
# Family_level
# Out:
# Source: local data frame [251 x 7]
# Groups: Rank2, Rank3, Rank4 [136]
#
#            Rank2                          Rank3
#           (fctr)                         (fctr)
# 1  Acidobacteria                          11-24
# 2  Acidobacteria Candidatus_Chloracidobacterium
# 3  Acidobacteria Candidatus_Chloracidobacterium
# 4  Acidobacteria Candidatus_Chloracidobacterium
# 5  Acidobacteria          Candidatus_Solibacter
# 6  Acidobacteria                          DA023
# 7  Acidobacteria                          DA023
# 8  Acidobacteria                          DA023
# 9  Acidobacteria                         DS-100
# 10 Acidobacteria                     Holophagae
# ..           ...                            ...
# Variables not shown: Rank4 (fctr), Rank5 (fctr), Min_relabund (dbl),
#   Max_relabund (dbl), Median_relabund (dbl)

# %%
# %%R
# Tbl = full_join(OTU_level, Family_level) %>% arrange(desc(OTU_count))
# Tbl
# write.csv(Tbl, file = '/home/bryan/RhizCG/figures/FamilyStats.csv', sep = ",")

# %%
# %%R
# ggplot(PlantRel, aes(x = log(median), y = log(max), colour = Rank2)) +
#     geom_point()

# %%
# %%R
# df.l2fc %>% filter(p.adj < 0.05) %>%
#     group_by(OTU) %>%
#     summarize(Rel = mean(RelAbund),
#              l2f = mean(log2FoldChange),
#              Phylum = first(Rank2)) %>%
#     group_by(Phylum) %>%
#      summarize(count = length(Phylum),
#                   RelAbund = mean(Rel),
#                     L2F = mean(l2f)) %>%
#      arrange(desc(count))
# Out:
# Source: local data frame [20 x 4]
#
#                     Phylum count     RelAbund      L2F
#                     (fctr) (int)        (dbl)    (dbl)
# 1           Proteobacteria   507 6.658721e-04 4.027051
# 2            Bacteroidetes   206 2.969870e-04 4.315679
# 3           Actinobacteria   174 1.363705e-03 3.202288
# 4              Chloroflexi   158 4.083371e-04 3.364895
# 5           Planctomycetes   144 2.434705e-04 2.666013
# 6          Verrucomicrobia    93 4.385508e-04 3.860752
# 7               Firmicutes    58 7.028826e-04 4.808561
# 8            Acidobacteria    56 8.354507e-04 2.350185
# 9         Gemmatimonadetes    38 3.380225e-04 2.730885
# 10           Cyanobacteria    24 3.652760e-04 3.887706
# 11         Armatimonadetes    21 1.520715e-04 3.979465
# 12           Fibrobacteres     8 1.837690e-04 4.372810
# 13            Spirochaetes     5 2.862844e-04 4.174627
# 14 Candidate_division_BRC1     3 2.025618e-04 3.087652
# 15           Elusimicrobia     3 2.020810e-04 3.410570
# 16                Chlorobi     2 1.630705e-04 2.801292
# 17             Nitrospirae     2 4.622507e-04 2.808100
# 18                     TM6     2 6.566399e-05 3.828986
# 19  Candidate_division_OD1     1 5.668802e-05 5.135198
# 20     Deinococcus-Thermus     1 1.358074e-04 4.461477

# %% [markdown]
# ## Proteobacteria

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Proteobacteria"
# physeq_1phy = subset_taxa(physeq.Full.resp, Rank2==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy, color.rank='Rank3', legend.title='Class',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(0.7,1.5))
# do.call(grid.arrange, gt)

# %%
# %%R -i figDir
#
# #outFile = 'Proteo_sparsityCut.pdf'
# #outFile = paste(c(figDir, outFile))#, collapse='/')
# outFile = 'Proteo_sparsityCut.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# #outFile = file.path(figDir, 'Proteo_sparsityCut.pdf')
# pdf(outFile, width=800 / 65, height=1300 / 65)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Gammaproteobacteria"
# physeq_1phy = subset_taxa(physeq.Full, Rank3==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank4',
#                    legend.title='Order',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(.6,1.8))
# do.call(grid.arrange, gt)

# %%
# %%R
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
#
#
# outFile = 'Gamma-Proteo_sparsityCut.jpeg'
# outFile = paste(c(figDir, outFile), collapse='/')
# #outFile = file.path(figDir, 'Proteo_sparsityCut.pdf')
# jpeg(outFile, width=9, height=9, units = "in")
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'Gamma-Proteo_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Alphaproteobacteria"
# physeq_1phy = subset_taxa(physeq.Full.resp, Rank3==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank4',
#                    legend.title='Order',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(.6,1.8))
# do.call(grid.arrange, gt)

# %%
# %%R
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
#
# outFile = 'Alpha_sparCut3in3.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
#
# jpeg(outFile, width=9, height=9, units = "in", res = 150)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'Alpha-Proteo_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## Actinobacteria

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Actinobacteria"
# physeq_1phy = subset_taxa(physeq.Full.resp, Rank2==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank4',
#                    legend.title='Order',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(.6,1.8))
# do.call(grid.arrange, gt)

# %%
# %%R
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
#
# outFile = 'Actino_sparCut3in3.jpeg'
# outFile = paste(c(figDir, outFile), collapse='/')
#
# jpeg(outFile, width=9, height=9, units = "in", res = 150)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'Actino_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## Planctomycetes

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Planctomycetes"
# physeq_1phy = subset_taxa(physeq.Full.resp, Rank2==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank3',
#                    legend.title='Class',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(.6,1.8))
# do.call(grid.arrange, gt)

# %%
# %%R
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
#
# outFile = 'Plancto_sparCut3in3.jpeg'
# outFile = paste(c(figDir, outFile), collapse='/')
#
# jpeg(outFile, width=9, height=9, units = "in", res = 150)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'Plancto_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## Acidobacteria

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Acidobacteria"
# physeq_1phy = subset_taxa(physeq.Full.resp, Rank2==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank3',
#                    legend.title='Class',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(.6,1.8))
# do.call(grid.arrange, gt)

# %%
# %%R
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
#
# outFile = 'Acido_sparCut3in3.jpeg'
# outFile = paste(c(figDir, outFile), collapse='/')
#
# jpeg(outFile, width=9, height=9, units = "in", res = 150)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'Acido_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## Chloroflexi

# %%
# %%R
# physeq.Full.resp %>% subset_taxa(Rank2 == "Chloroflexi") %>% otu_table %>% melt %>% hist

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Chloroflexi"
# physeq_1phy = subset_taxa(physeq.Full.resp, Rank2==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank3',
#                    legend.title='Class',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(.6,1.8))
# do.call(grid.arrange, gt)

# %%
# %%R
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
#
# outFile = 'Chloro_sparCut3in3.jpeg'
# outFile = paste(c(figDir, outFile), collapse='/')
#
# jpeg(outFile, width=9, height=9, units = "in", res = 150)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'Chloro_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## Bacteroidetes

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Bacteroidetes"
# physeq_1phy = subset_taxa(physeq.Full.resp, Rank2==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank3',
#                    legend.title='Class',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(.6,1.8))
# do.call(grid.arrange, gt)

# %%
# %%R
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
#
# outFile = 'Bacteroidetes_sparCut3in3.jpeg'
# outFile = paste(c(figDir, outFile), collapse='/')
#
# jpeg(outFile, width=9, height=9, units = "in", res = 150)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'Bacteroidetes_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## Verrucomicrobia

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Verrucomicrobia"
# physeq_1phy = subset_taxa(physeq.Full.resp, Rank2==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank3',
#                    legend.title='Class',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(.6,1.8))
# do.call(grid.arrange, gt)

# %%
# %%R
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
#
# outFile = 'Verruco_sparCut3in3.jpeg'
# outFile = paste(c(figDir, outFile), collapse='/')
#
# jpeg(outFile, width=9, height=9, units = "in", res = 150)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'Verruco_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## Firmicutes

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Firmicutes"
# physeq_1phy = subset_taxa(physeq.Full.resp, Rank2==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank6',
#                    legend.title='Genus',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(.6,1.8))
# do.call(grid.arrange, gt)

# %%
# %%R
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
#
# outFile = 'Firmicutes_sparCut3in3.jpeg'
# outFile = paste(c(figDir, outFile), collapse='/')
#
# jpeg(outFile, width=9, height=9, units = "in", res = 150)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'Firmicutes_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# TT = physeq.Full %>% tax_table %>% data.frame
# colnames(TT)
# TT[row.names(TT) == "OTU.1001",]
# Out:
#             Rank1      Rank2           Rank3              Rank4
# OTU.1001 Bacteria Firmicutes Erysipelotrichi Erysipelotrichales
#                        Rank5          Rank6                Rank7 Rank8
# OTU.1001 Erysipelotrichaceae Asteroleplasma uncultured_bacterium  <NA>

# %%
# %%R
# tax
# df.family = df.l2fc[!is.na(df.l2fc$Rank5),]
#
# Pb_sel = df.family$Rank5 == "Paenibacillaceae"
#
# Pb = df.family[Pb_sel,] %>% arrange(p.adj)
# Pb[,c("Rank5", "Rank6", "p.adj")]
# Out:
#                Rank5         Rank6        p.adj
# 1   Paenibacillaceae Paenibacillus 2.867822e-09
# 2   Paenibacillaceae Paenibacillus 2.871479e-09
# 3   Paenibacillaceae Paenibacillus 7.365414e-06
# 4   Paenibacillaceae Paenibacillus 1.094995e-05
# 5   Paenibacillaceae Paenibacillus 5.483978e-05
# 6   Paenibacillaceae Paenibacillus 7.720390e-05
# 7   Paenibacillaceae Paenibacillus 9.986144e-05
# 8   Paenibacillaceae Paenibacillus 2.706554e-04
# 9   Paenibacillaceae Paenibacillus 2.850030e-04
# 10  Paenibacillaceae Paenibacillus 2.941849e-04
# 11  Paenibacillaceae Paenibacillus 4.246286e-04
# 12  Paenibacillaceae Paenibacillus 4.753803e-04
# 13  Paenibacillaceae Paenibacillus 7.053511e-04
# 14  Paenibacillaceae Paenibacillus 1.385811e-03
# 15  Paenibacillaceae Paenibacillus 1.767881e-03
# 16  Paenibacillaceae Paenibacillus 2.385436e-03
# 17  Paenibacillaceae Paenibacillus 2.890407e-03
# 18  Paenibacillaceae Paenibacillus 3.030312e-03
# 19  Paenibacillaceae Paenibacillus 5.057714e-03
# 20  Paenibacillaceae Paenibacillus 5.278960e-03
# 21  Paenibacillaceae Paenibacillus 6.311030e-03
# 22  Paenibacillaceae Paenibacillus 7.001041e-03
# 23  Paenibacillaceae Paenibacillus 8.895238e-03
# 24  Paenibacillaceae Paenibacillus 8.907538e-03
# 25  Paenibacillaceae Paenibacillus 1.066001e-02
# 26  Paenibacillaceae Paenibacillus 1.592160e-02
# 27  Paenibacillaceae Paenibacillus 1.727374e-02
# 28  Paenibacillaceae Paenibacillus 2.169711e-02
# 29  Paenibacillaceae Paenibacillus 2.435744e-02
# 30  Paenibacillaceae Paenibacillus 2.555442e-02
# 31  Paenibacillaceae Paenibacillus 2.678285e-02
# 32  Paenibacillaceae Paenibacillus 2.681821e-02
# 33  Paenibacillaceae Paenibacillus 3.022875e-02
# 34  Paenibacillaceae Paenibacillus 3.827090e-02
# 35  Paenibacillaceae Paenibacillus 3.853808e-02
# 36  Paenibacillaceae Paenibacillus 4.879501e-02
# 37  Paenibacillaceae      Cohnella 5.029446e-02
# 38  Paenibacillaceae Paenibacillus 5.079925e-02
# 39  Paenibacillaceae Paenibacillus 5.261517e-02
# 40  Paenibacillaceae Paenibacillus 5.940600e-02
# 41  Paenibacillaceae Paenibacillus 6.381628e-02
# 42  Paenibacillaceae Paenibacillus 6.447770e-02
# 43  Paenibacillaceae Paenibacillus 6.760116e-02
# 44  Paenibacillaceae Paenibacillus 7.844175e-02
# 45  Paenibacillaceae Paenibacillus 8.246042e-02
# 46  Paenibacillaceae Paenibacillus 9.366512e-02
# 47  Paenibacillaceae Paenibacillus 1.170309e-01
# 48  Paenibacillaceae Paenibacillus 1.231689e-01
# 49  Paenibacillaceae Paenibacillus 1.236167e-01
# 50  Paenibacillaceae Paenibacillus 1.437607e-01
# 51  Paenibacillaceae      Cohnella 1.575136e-01
# 52  Paenibacillaceae Paenibacillus 1.671170e-01
# 53  Paenibacillaceae Paenibacillus 1.733599e-01
# 54  Paenibacillaceae Paenibacillus 1.860798e-01
# 55  Paenibacillaceae Paenibacillus 1.894101e-01
# 56  Paenibacillaceae Paenibacillus 1.911987e-01
# 57  Paenibacillaceae Paenibacillus 2.161679e-01
# 58  Paenibacillaceae Paenibacillus 2.187508e-01
# 59  Paenibacillaceae Paenibacillus 2.283483e-01
# 60  Paenibacillaceae      Cohnella 2.297091e-01
# 61  Paenibacillaceae Paenibacillus 2.373340e-01
# 62  Paenibacillaceae Paenibacillus 2.440955e-01
# 63  Paenibacillaceae Paenibacillus 2.648308e-01
# 64  Paenibacillaceae Paenibacillus 2.830837e-01
# 65  Paenibacillaceae Paenibacillus 3.066908e-01
# 66  Paenibacillaceae Paenibacillus 3.090758e-01
# 67  Paenibacillaceae Paenibacillus 3.194276e-01
# 68  Paenibacillaceae    uncultured 3.217908e-01
# 69  Paenibacillaceae Paenibacillus 3.367994e-01
# 70  Paenibacillaceae Paenibacillus 3.383143e-01
# 71  Paenibacillaceae      Cohnella 3.397781e-01
# 72  Paenibacillaceae Paenibacillus 3.530373e-01
# 73  Paenibacillaceae Paenibacillus 3.544864e-01
# 74  Paenibacillaceae Paenibacillus 3.659244e-01
# 75  Paenibacillaceae Paenibacillus 3.691796e-01
# 76  Paenibacillaceae Paenibacillus 3.745614e-01
# 77  Paenibacillaceae Paenibacillus 3.818576e-01
# 78  Paenibacillaceae Paenibacillus 3.927778e-01
# 79  Paenibacillaceae Paenibacillus 4.104338e-01
# 80  Paenibacillaceae Paenibacillus 4.146673e-01
# 81  Paenibacillaceae Paenibacillus 4.605939e-01
# 82  Paenibacillaceae Paenibacillus 4.914233e-01
# 83  Paenibacillaceae    uncultured 4.989378e-01
# 84  Paenibacillaceae Paenibacillus 5.170327e-01
# 85  Paenibacillaceae Paenibacillus 5.387732e-01
# 86  Paenibacillaceae Paenibacillus 5.394387e-01
# 87  Paenibacillaceae Paenibacillus 5.444733e-01
# 88  Paenibacillaceae Paenibacillus 5.477643e-01
# 89  Paenibacillaceae Paenibacillus 5.689588e-01
# 90  Paenibacillaceae Paenibacillus 5.778495e-01
# 91  Paenibacillaceae Paenibacillus 5.792919e-01
# 92  Paenibacillaceae Paenibacillus 5.882702e-01
# 93  Paenibacillaceae      Cohnella 5.988725e-01
# 94  Paenibacillaceae Paenibacillus 6.082818e-01
# 95  Paenibacillaceae Paenibacillus 6.111749e-01
# 96  Paenibacillaceae Paenibacillus 6.613598e-01
# 97  Paenibacillaceae Paenibacillus 6.646942e-01
# 98  Paenibacillaceae Paenibacillus 6.681723e-01
# 99  Paenibacillaceae Paenibacillus 6.825268e-01
# 100 Paenibacillaceae Paenibacillus 6.872278e-01
# 101 Paenibacillaceae Paenibacillus 7.165215e-01
# 102 Paenibacillaceae Paenibacillus 7.303741e-01
# 103 Paenibacillaceae Paenibacillus 7.477953e-01
# 104 Paenibacillaceae Paenibacillus 7.750826e-01
# 105 Paenibacillaceae Paenibacillus 7.935689e-01
# 106 Paenibacillaceae Paenibacillus 7.969337e-01
# 107 Paenibacillaceae Paenibacillus 8.173717e-01
# 108 Paenibacillaceae      Cohnella 8.239871e-01
# 109 Paenibacillaceae Paenibacillus 8.291061e-01
# 110 Paenibacillaceae Paenibacillus 8.380911e-01
# 111 Paenibacillaceae Paenibacillus 8.559150e-01
# 112 Paenibacillaceae Paenibacillus 8.621460e-01
# 113 Paenibacillaceae Paenibacillus 8.835747e-01
# 114 Paenibacillaceae Paenibacillus 8.879802e-01
# 115 Paenibacillaceae Paenibacillus 8.959264e-01
# 116 Paenibacillaceae Paenibacillus 9.065936e-01
# 117 Paenibacillaceae Paenibacillus 9.218589e-01
# 118 Paenibacillaceae Paenibacillus 9.327204e-01
# 119 Paenibacillaceae Paenibacillus 9.421750e-01
# 120 Paenibacillaceae Paenibacillus 9.489835e-01
# 121 Paenibacillaceae Paenibacillus 9.539740e-01
# 122 Paenibacillaceae Paenibacillus 9.635840e-01
# 123 Paenibacillaceae Paenibacillus 9.661284e-01
# 124 Paenibacillaceae Paenibacillus 9.692944e-01
# 125 Paenibacillaceae Paenibacillus 9.728379e-01
# 126 Paenibacillaceae Paenibacillus 9.810028e-01
# 127 Paenibacillaceae Paenibacillus 9.969592e-01
# 128 Paenibacillaceae    uncultured 1.000000e+00
# 129 Paenibacillaceae      Cohnella 1.000000e+00
# 130 Paenibacillaceae Paenibacillus 1.000000e+00
# 131 Paenibacillaceae Paenibacillus 1.000000e+00
# 132 Paenibacillaceae Paenibacillus 1.000000e+00
# 133 Paenibacillaceae Paenibacillus 1.000000e+00
# 134 Paenibacillaceae Paenibacillus 1.000000e+00
# 135 Paenibacillaceae Paenibacillus 1.000000e+00
# 136 Paenibacillaceae      Cohnella 1.000000e+00
# 137 Paenibacillaceae Paenibacillus 1.000000e+00
# 138 Paenibacillaceae Paenibacillus 1.000000e+00
# 139 Paenibacillaceae Paenibacillus 1.000000e+00
# 140 Paenibacillaceae Paenibacillus 1.000000e+00
# 141 Paenibacillaceae Paenibacillus 1.000000e+00
# 142 Paenibacillaceae    uncultured 1.000000e+00
# 143 Paenibacillaceae      Cohnella 1.000000e+00
# 144 Paenibacillaceae Paenibacillus 1.000000e+00
# 145 Paenibacillaceae    uncultured 1.000000e+00
# 146 Paenibacillaceae      Cohnella 1.000000e+00
# 147 Paenibacillaceae Paenibacillus 1.000000e+00
# 148 Paenibacillaceae Paenibacillus 1.000000e+00
# 149 Paenibacillaceae Paenibacillus 1.000000e+00
# 150 Paenibacillaceae Paenibacillus 1.000000e+00
# 151 Paenibacillaceae Paenibacillus 1.000000e+00
# 152 Paenibacillaceae Paenibacillus 1.000000e+00
# 153 Paenibacillaceae      Cohnella 1.000000e+00
# 154 Paenibacillaceae Paenibacillus 1.000000e+00
# 155 Paenibacillaceae Paenibacillus 1.000000e+00
# 156 Paenibacillaceae Paenibacillus 1.000000e+00
# 157 Paenibacillaceae    uncultured 1.000000e+00
# 158 Paenibacillaceae      Cohnella 1.000000e+00
# 159 Paenibacillaceae Paenibacillus 1.000000e+00
# 160 Paenibacillaceae Paenibacillus 1.000000e+00
# 161 Paenibacillaceae Paenibacillus 1.000000e+00
# 162 Paenibacillaceae Paenibacillus 1.000000e+00
# 163 Paenibacillaceae Paenibacillus 1.000000e+00
# 164 Paenibacillaceae    uncultured 1.000000e+00
# 165 Paenibacillaceae Paenibacillus 1.000000e+00
# 166 Paenibacillaceae Paenibacillus 1.000000e+00
# 167 Paenibacillaceae    uncultured 1.000000e+00
# 168 Paenibacillaceae      Cohnella 1.000000e+00
# 169 Paenibacillaceae Paenibacillus 1.000000e+00
# 170 Paenibacillaceae Paenibacillus 1.000000e+00
# 171 Paenibacillaceae Paenibacillus 1.000000e+00
# 172 Paenibacillaceae Paenibacillus 1.000000e+00
# 173 Paenibacillaceae Paenibacillus 1.000000e+00
# 174 Paenibacillaceae    uncultured 1.000000e+00
# 175 Paenibacillaceae      Cohnella 1.000000e+00
# 176 Paenibacillaceae Paenibacillus 1.000000e+00
# 177 Paenibacillaceae Paenibacillus 1.000000e+00
# 178 Paenibacillaceae Paenibacillus 1.000000e+00
# 179 Paenibacillaceae Paenibacillus 1.000000e+00
# 180 Paenibacillaceae    uncultured 1.000000e+00
# 181 Paenibacillaceae      Cohnella 1.000000e+00
# 182 Paenibacillaceae Paenibacillus 1.000000e+00
# 183 Paenibacillaceae Paenibacillus 1.000000e+00
# 184 Paenibacillaceae    uncultured 1.000000e+00
# 185 Paenibacillaceae      Cohnella 1.000000e+00
# 186 Paenibacillaceae Paenibacillus 1.000000e+00
# 187 Paenibacillaceae Paenibacillus 1.000000e+00
# 188 Paenibacillaceae Paenibacillus 1.000000e+00
# 189 Paenibacillaceae    uncultured 1.000000e+00
# 190 Paenibacillaceae      Cohnella 1.000000e+00
# 191 Paenibacillaceae Paenibacillus 1.000000e+00
# 192 Paenibacillaceae Paenibacillus 1.000000e+00
# 193 Paenibacillaceae Paenibacillus 1.000000e+00
# 194 Paenibacillaceae Paenibacillus 1.000000e+00
# 195 Paenibacillaceae Paenibacillus 1.000000e+00
# 196 Paenibacillaceae    uncultured 1.000000e+00
# 197 Paenibacillaceae Paenibacillus 1.000000e+00
# 198 Paenibacillaceae Paenibacillus 1.000000e+00
# 199 Paenibacillaceae Paenibacillus 1.000000e+00
# 200 Paenibacillaceae    uncultured 1.000000e+00
# 201 Paenibacillaceae Paenibacillus 1.000000e+00
# 202 Paenibacillaceae Paenibacillus 1.000000e+00
# 203 Paenibacillaceae Paenibacillus 1.000000e+00
# 204 Paenibacillaceae Paenibacillus 1.000000e+00
# 205 Paenibacillaceae Paenibacillus 1.000000e+00
# 206 Paenibacillaceae Paenibacillus 1.000000e+00
# 207 Paenibacillaceae Paenibacillus 1.000000e+00
# 208 Paenibacillaceae    uncultured 1.000000e+00
# 209 Paenibacillaceae Paenibacillus 1.000000e+00
# 210 Paenibacillaceae Paenibacillus 1.000000e+00
# 211 Paenibacillaceae Paenibacillus 1.000000e+00
# 212 Paenibacillaceae Paenibacillus 1.000000e+00
# 213 Paenibacillaceae Paenibacillus 1.000000e+00
# 214 Paenibacillaceae    uncultured 1.000000e+00
# 215 Paenibacillaceae      Cohnella 1.000000e+00
# 216 Paenibacillaceae Paenibacillus 1.000000e+00
# 217 Paenibacillaceae Paenibacillus 1.000000e+00
# 218 Paenibacillaceae Paenibacillus 1.000000e+00
# 219 Paenibacillaceae Paenibacillus 1.000000e+00
# 220 Paenibacillaceae Paenibacillus 1.000000e+00
# 221 Paenibacillaceae Paenibacillus 1.000000e+00
# 222 Paenibacillaceae Paenibacillus 1.000000e+00
# 223 Paenibacillaceae    uncultured 1.000000e+00
# 224 Paenibacillaceae Paenibacillus 1.000000e+00
# 225 Paenibacillaceae Paenibacillus 1.000000e+00
# 226 Paenibacillaceae Paenibacillus 1.000000e+00
# 227 Paenibacillaceae Paenibacillus 1.000000e+00
# 228 Paenibacillaceae Paenibacillus 1.000000e+00
# 229 Paenibacillaceae    uncultured 1.000000e+00
# 230 Paenibacillaceae      Cohnella 1.000000e+00
# 231 Paenibacillaceae Paenibacillus 1.000000e+00
# 232 Paenibacillaceae Paenibacillus 1.000000e+00
# 233 Paenibacillaceae Paenibacillus 1.000000e+00
# 234 Paenibacillaceae Paenibacillus 1.000000e+00
# 235 Paenibacillaceae Paenibacillus 1.000000e+00
# 236 Paenibacillaceae Paenibacillus 1.000000e+00
# 237 Paenibacillaceae    uncultured 1.000000e+00
# 238 Paenibacillaceae      Cohnella 1.000000e+00
# 239 Paenibacillaceae Paenibacillus 1.000000e+00
# 240 Paenibacillaceae Paenibacillus 1.000000e+00
# 241 Paenibacillaceae Paenibacillus 1.000000e+00
# 242 Paenibacillaceae Paenibacillus 1.000000e+00
# 243 Paenibacillaceae Paenibacillus 1.000000e+00
# 244 Paenibacillaceae Paenibacillus 1.000000e+00
# 245 Paenibacillaceae Paenibacillus 1.000000e+00
# 246 Paenibacillaceae Paenibacillus 1.000000e+00
# 247 Paenibacillaceae    uncultured 1.000000e+00
# 248 Paenibacillaceae      Cohnella 1.000000e+00
# 249 Paenibacillaceae Paenibacillus 1.000000e+00
# 250 Paenibacillaceae Paenibacillus 1.000000e+00
# 251 Paenibacillaceae Paenibacillus 1.000000e+00
# 252 Paenibacillaceae    uncultured 1.000000e+00
# 253 Paenibacillaceae      Cohnella 1.000000e+00
# 254 Paenibacillaceae Paenibacillus 1.000000e+00
# 255 Paenibacillaceae Paenibacillus 1.000000e+00
# 256 Paenibacillaceae Paenibacillus 1.000000e+00
# 257 Paenibacillaceae Paenibacillus 1.000000e+00
# 258 Paenibacillaceae Paenibacillus 1.000000e+00
# 259 Paenibacillaceae Paenibacillus 1.000000e+00
# 260 Paenibacillaceae Paenibacillus 1.000000e+00
# 261 Paenibacillaceae Paenibacillus 1.000000e+00
# 262 Paenibacillaceae    uncultured 1.000000e+00
# 263 Paenibacillaceae Paenibacillus 1.000000e+00
# 264 Paenibacillaceae Paenibacillus 1.000000e+00
# 265 Paenibacillaceae Paenibacillus 1.000000e+00
# 266 Paenibacillaceae Paenibacillus 1.000000e+00

# %% [markdown]
# ## Gemmatimonadetes

# %%
# %%R -w 800 -h 1000
#
# # phylum selection
# phylum = "Gemmatimonadetes"
# physeq_1phy = subset_taxa(physeq.Full.resp, Rank2==phylum)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank3',
#                    legend.title='Class',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(.6,1.8))
# do.call(grid.arrange, gt)
# Out:
# Error: Faceting variables must have at least one value
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Error: Faceting variables must have at least one value
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %%
# %%R
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
#
# outFile = 'Gemma_sparCut3in3.jpeg'
# outFile = paste(c(figDir, outFile), collapse='/')
#
# jpeg(outFile, width=9, height=9, units = "in", res = 150)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %%
# %%R
# # saving legend
# outFile = 'Gemma_sparCut3in3_leg.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=500 / 65, height=500 / 65)
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)
# dev.off()
# Out:
# png
#   2

# %%
# %%R -i figDir
#
# outFile = 'Gemma_sparCut3in3.pdf'
# outFile = paste(c(figDir, outFile), collapse='/')
# pdf(outFile, width=800 / 65, height=1300 / 65)
# do.call(grid.arrange, gt)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# # Enriched heatmap of only core microbiome

# %%
# %%R
# CoreDF = read.csv(file = "/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTUexploration/CoreTaxa.csv", header = TRUE)
# CoreDF = CoreDF[,-1]

# %%
# %%R
# head(CoreDF)
# Out:
#         OTU MaizeCore C4Core DicotCore PanicoideaeCore PaniceaeCore
# 1    OTU.10         1      1         1               1            1
# 2   OTU.101         1     NA        NA              NA            1
# 3 OTU.10253         1      1         1               1            1
# 4 OTU.10288         1      1         1               1            1
# 5  OTU.1034         1      1         1               1            1
# 6   OTU.104         1     NA         1              NA           NA
#   AndropogoneaeCore ChloridoideaeCore
# 1                 1                 1
# 2                NA                NA
# 3                 1                 1
# 4                 1                 1
# 5                 1                 1
# 6                 1                 1

# %%
# %%R
# #make lists for subsetting phyloseq object
# MaizeCore = filter(CoreDF, MaizeCore == 1) %>% .$OTU %>% as.character
# C4Core = filter(CoreDF, C4Core == 1) %>% .$OTU %>% as.character
# DicotCore = filter(CoreDF, DicotCore == 1) %>% .$OTU %>% as.character
# CoreTaxa = filter(CoreDF, MaizeCore == 1 & C4Core == 1 & DicotCore == 1) %>%
#     .$OTU %>% as.character
# CoreTaxa
# Out:
#  [1] "OTU.10"    "OTU.10253" "OTU.10288" "OTU.1034"  "OTU.108"   "OTU.11012"
#  [7] "OTU.11069" "OTU.114"   "OTU.1243"  "OTU.134"   "OTU.152"   "OTU.189"
# [13] "OTU.196"   "OTU.207"   "OTU.24"    "OTU.284"   "OTU.293"   "OTU.4"
# [19] "OTU.4049"  "OTU.414"   "OTU.4513"  "OTU.4888"  "OTU.49"    "OTU.5436"
# [25] "OTU.68"    "OTU.8"     "OTU.9"     "OTU.9377"  "OTU.9421"  "OTU.9501"
# [31] "OTU.96"

# %%
# %%R
# Maize = c("75-062", "B73", "B97", "H99","Hp301",  "Il14H",  "Ki3", "Mo18", "MS71",
#                        "Oh7B", "Tx303")
# C4 = c("ECHCG",  "ELCOR",  "ERATE", "SETFA",  "SORBI",  "SORSUD")
#
# Dicots = c("AMAPO", "ABUTH", "FAGES", "HELAN", "GLYMA")

# %%
# %%R
# df.l2fc.ord2 %>% head
# Out:
#        OTU y.tree log2FoldChange         p Day Plant     p.adj     RelAbund
# 1 OTU.4087   4981    1.763280694 0.1742325  36 FAGES 0.8275676 1.584121e-05
# 2 OTU.4087   4981    0.006397593 0.5982452  53 AMAPO 1.0000000 0.000000e+00
# 3 OTU.4087   4981    0.536219786 0.4924229  53 ECHCG 1.0000000 0.000000e+00
# 4 OTU.4087   4981    2.929335792 0.0664975  61 SETFA 0.4371311 2.832002e-05
# 5 OTU.4087   4981    1.568190253 0.3024613  72 Il14H 1.0000000 2.405436e-06
# 6 OTU.4087   4981    1.145923874 0.3594904  72  MS71 1.0000000 2.409946e-06

# %%
# %%R -w 600
#
# # function for making incorporator plot
# Core_responders_plot = function(metadata, plot.margin=NULL){
#     if(is.null(plot.margin)){
#         plot.margin = unit(c(0.1,0,0,-0.7), "cm")  # top, right, bottom, left
#     }
#
#
# metadata.ord = metadata %>%
#         mutate(responder = p.adj < 0.05,
#                responder.num = responder %>% as.numeric,
#                Day = Day %>% as.character)
#
#     metadata.ord$Day = reorder(metadata.ord$Day, metadata.ord$Day %>% as.numeric)
#
#     min.y = metadata.ord$y.tree %>% min(na.rm=T)
#     max.y = metadata.ord$y.tree %>% max(na.rm=T)
#
# Responders = filter(metadata.ord, p.adj <0.05 & log2FoldChange > 0)
#     MaizeR = filter(metadata.ord, OTU %in% MaizeCore & Plant %in% Maize)
#     C4R = filter(metadata.ord, OTU %in% C4Core & Plant %in% C4)
#     DicotR = filter(metadata.ord, OTU %in% DicotCore & Plant %in% Dicots)
#     CoreResp = filter(Responders, OTU %in% CoreTaxa)
#     NonResp = filter(metadata.ord, p.adj >0.05 )
#     Filtered = filter(metadata.ord, is.na(p.adj))
#
# p.responder = ggplot() +
#     geom_tile(data = Responders, aes(Day, y.tree, fill = log(RelAbund))) +
#     scale_fill_gradient(low = "Gray", high = "Black") + #, limit = c(.00001733848, .0555003)) +
#     scale_y_continuous(expand=c(0,0)) +
#
#     geom_tile(data = MaizeR, aes(Day, y.tree), fill = "Green") +
#     #scale_fill_gradient( low = "Black", high = "Green", limit = c(.00001733848, .0555003))+
#     scale_y_continuous(expand=c(0,0)) +
#
#     geom_tile(data = C4R, aes(Day, y.tree), fill = "Orange") +
#     #scale_fill_gradient( low = "Black", high = "Green", limit = c(.00001733848, .0555003))+
#     scale_y_continuous(expand=c(0,0))+
#
#     geom_tile(data = DicotR, aes(Day, y.tree), fill = "Purple") +
#     #scale_fill_gradient( low = "Black", high = "Green", limit = c(.00001733848, .0555003))+
#     scale_y_continuous(expand=c(0,0))+
#
#     geom_tile(data = CoreResp, aes(Day, y.tree), fill = "Red") +
#     #scale_fill_gradient( low = "Black", high = "Red", limit = c(.00001733848, .0555003))+
#     scale_y_continuous(expand=c(0,0)) +
#
#
#
#         facet_grid(. ~ Plant, scales='free_x') +
#         theme_bw() +
#         theme(
#             panel.grid.major = element_blank(),
#             panel.grid.minor = element_blank(),
#             panel.margin.x=unit(0.0, "lines"),
#             axis.text.x = element_text(angle=90, vjust=0.5, hjust=1),
#             axis.title.y = element_blank(),
#             axis.text.y = element_blank(),
#             axis.ticks.y = element_blank(),
#             legend.position = 'none',
#             plot.margin = plot.margin
#             )
#     return(p.responder)
#     }
#
# #-- test --#
# p.responders = Core_responders_plot(df.l2fc.ord2)
# p.responders

# %%
# %%R -w 800 -h 1000
#
#
# # Maize,C4 or Dicot Core - microbiome selection
# mytaxa = filter(CoreDF, MaizeCore == 1 | C4Core == 1 | DicotCore == 1) %>% .$OTU %>% as.character
#
#
#
#
# physeq_1phy = prune_taxa(mytaxa, physeq.Full.resp)
#
# # tree plot
# p.tree = plot_tree(physeq_1phy,
#                    color.rank='Rank2',
#                    legend.title='Phylum',
#                    y.expand=c(-0.002,-0.002),
#                    plot.margin=unit(c(0,-0.1,0,0), 'cm'))
#
#
# # order metadata
# df.l2fc.s = df.l2fc %>%
#     select(-Rank1, -Rank2, -Rank3, -Rank4, -Rank5, -Rank6, -Rank7, -Rank8)
# ## substrates by similarity of incorporators (full tree)
# df.l2fc.ord = df.l2fc.s
# df.l2fc.ord = order_plants_by_phylogeny(df.l2fc.ord, physeq.Full, cores=nprocs)
# ## taxa by tree
# df.l2fc.ord = order_metadata_to_tree(physeq_1phy, df.l2fc.ord)
#
# # plotting metadata
# ## plot.margin: top, right, bottom, left
# p.responders = Core_responders_plot(df.l2fc.ord, plot.margin=unit(c(1.52,0,1.33,-0.73), 'cm'))
#
#
#
# # plotting
# gt = resize_ggplots(list(p.tree, p.responders),
#                     widths=c(.6,1.8))
# do.call(grid.arrange, gt)

# %%
# %%R
# my.legend = g_legend(p.tree)
# grid.draw(my.legend)

# %%
# %%R
# coredata = filter(df.l2fc, OTU %in% CoreTaxa)
#
# respdata = filter(df.l2fc, p.adj < 0.05)
# p1 = ggplot() +
#     geom_histogram(data = respdata, aes(x = RelAbund)) +
#     scale_x_log10() +
#     geom_histogram(data = coredata, aes(x = RelAbund, fill = "Red"))
#
#
# p1
