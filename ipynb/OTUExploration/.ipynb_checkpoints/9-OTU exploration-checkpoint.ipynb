# %% [markdown]
# # Description:
#
#     Investigate OTU abundances

# %% [markdown]
# # Setting variables

# %%
workDir = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTUexploration/'
biomFileDir = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/'

biomFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/otu_table_wtax.biom'
metadataFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/metadata_RhizCG_merged.txt'
treeFile = '/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/fasttree/otusn.tree'

# %% [markdown]
# # Init

# %%
import os
from pandas import DataFrame
from IPython.display import FileLink

# %%
# %matplotlib inline
# %load_ext rpy2.ipython

# %%
# %%R
# library(phyloseq)
# library(ggplot2)
# library(foreach)
# library(doParallel)
# library(gridExtra)
# library(dplyr)
# library(tidyr)
# Out:
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: foreach: simple, scalable parallel programming from Revolution Analytics
# Use Revolution R for scalability, fault tolerance and more.
# http://www.revolutionanalytics.com
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: iterators
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: parallel
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘dplyr’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %%
if not os.path.isdir(workDir):
    os.mkdir(workDir)

# %% [markdown]
# # Setting files

# %%
# !cd $workDir; ln -f -s $biomFileDir$biomFile
# !cd $workDir; ln -f -s $biomFileDir'../'$metadataFile
# !cd $workDir; ls -thlc
# Out:
# total 432K
# lrwxrwxrwx 1 bryan bryan  130 Sep 30 06:19 metadata_RhizCG_merged.txt -> /home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/..//home/bryan/RhizCG/data/MiSeq_amplicon/metadata_RhizCG_merged.txt
# lrwxrwxrwx 1 bryan bryan  143 Sep 30 06:19 otu_table_wtax.biom -> /home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning//home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTU_binning/otu_table_wtax.biom
# -rw-rw-r-- 1 bryan bryan 424K Jul 22 19:52 sample_abundance.pdf

# %% [markdown]
# # Loading/editting OTU table

# %%
# %%R -i biomFile -i metadataFile -i workDir -i treeFile
# # loading
# setwd(workDir)
#
# ## biom file
# physeq = import_biom(biomFile, treeFile)
#
# ## loading sample metadata
# sample.data = import_qiime_sample_data(metadataFile)
# physeq = merge_phyloseq(physeq,sample.data)

# %% [markdown]
# ### apply gsub across columns replacing __ w/ "" reload tax_table to phyloseq object

# %%
# %%R
# t = tax_table(physeq)
# t = apply(t, 2, function(y) gsub("__", "", y))
# tax_table(physeq) = t

# %% [markdown]
# ## Filter and transform samples
# Transform to relative abundance and
# remove taxa not seen more than 3 times in at least 5% of the samples

# %%
# %%R
# sparcity.thresh = 0.05
#
# # filtering/normalizing
# #physeq.snorm = transform_sample_counts(physeq, function(x) x/sum(x))
# physeq.thresh = filter_taxa(physeq, function(x) sum(x > 3) > (sparcity.thresh * length(x)), TRUE)
# print(physeq.thresh)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 3635 taxa and 249 samples ]
# sample_data() Sample Data:       [ 249 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 3635 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 3635 tips and 3634 internal nodes ]

# %% [markdown]
# # Taxa distribution

# %% [markdown]
# ## Rank Abundance

# %%
# %%R
# print(physeq.thresh)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 3635 taxa and 249 samples ]
# sample_data() Sample Data:       [ 249 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 3635 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 3635 tips and 3634 internal nodes ]

# %%
# %%R
# # filtering/normalizing
# physeq.R = subset_samples(physeq.thresh, !is.na(DAP))
# sample_data(physeq.R)
# #physeq.trim = prune_samples(sample_sums(physeq.R) >= 10, physeq.R)
# phy = transform_sample_counts(physeq.R, function(OTU) OTU/sum(OTU))
#
# print(phy)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 3635 taxa and 240 samples ]
# sample_data() Sample Data:       [ 240 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 3635 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 3635 tips and 3634 internal nodes ]

# %%
# %%R
# getwd()
# Out:
# [1] "/home/bryan/RhizCG/data/MiSeq_amplicon/MergedRuns/OTUexploration"

# %%
# %%R -w 700 -h 500
# par(mar = c(10, 4, 4, 2) + 0.1) # make more room on bottom margin
# N <- 50
#
# #print to file
# pdf(file = "RankAbundance")
# barplot(sort(taxa_sums(physeq.R), TRUE)[1:N], las=2,
#         main = "Rank Abundance \n Sparsity Threshold x > 3 in 5%")
# dev.off()
#
# #print to screen
# barplot(sort(taxa_sums(physeq.R), TRUE)[1:N], las=2,
#         main = "Rank Abundance \n Sparsity Threshold x > 3 in 5%")

# %% [markdown]
# ## Generate abundance bar plots for each sample

# %%
# %%R
# # Multiple plot function
# #
# # ggplot objects can be passed in ..., or to plotlist (as a list of ggplot objects)
# # - cols:   Number of columns in layout
# # - layout: A matrix specifying the layout. If present, 'cols' is ignored.
# #
# # If the layout is something like matrix(c(1,2,3,3), nrow=2, byrow=TRUE),
# # then plot 1 will go in the upper left, 2 will go in the upper right, and
# # 3 will go all the way across the bottom.
# #
# multiplot <- function(..., plotlist=NULL, file, cols=1, layout=NULL) {
#   library(grid)
#
#   # Make a list from the ... arguments and plotlist
#   plots <- c(list(...), plotlist)
#
#   numPlots = length(plots)
#
#   # If layout is NULL, then use 'cols' to determine layout
#   if (is.null(layout)) {
#     # Make the panel
#     # ncol: Number of columns of plots
#     # nrow: Number of rows needed, calculated from # of cols
#     layout <- matrix(seq(1, cols * ceiling(numPlots/cols)),
#                     ncol = cols, nrow = ceiling(numPlots/cols))
#   }
#
#  if (numPlots==1) {
#     print(plots[[1]])
#
#   } else {
#     # Set up the page
#     grid.newpage()
#     pushViewport(viewport(layout = grid.layout(nrow(layout), ncol(layout))))
#
#     # Make each plot, in the correct location
#     for (i in 1:numPlots) {
#       # Get the i,j matrix positions of the regions that contain this subplot
#       matchidx <- as.data.frame(which(layout == i, arr.ind = TRUE))
#
#       print(plots[[i]], vp = viewport(layout.pos.row = matchidx$row,
#                                       layout.pos.col = matchidx$col))
#     }
#   }
# }

# %%
# %%R
# s.df = sample_data(physeq.R)
# s.df.o =  s.df[with(s.df, order(Plant, Treatment))]
# head(s.df.o) %>% print
# samples = sample_names(s.df.o)
# Out:
#                            X.sample Library Primer_Plate Primer_Well_ID
# sample5-1.22_Nneg sample5-1.22_Nneg       1            1             A4
# sample5-2.29_Nneg sample5-2.29_Nneg       1            1             C4
# sample5-4.28_Nneg sample5-4.28_Nneg       1            1             G4
# sample5-3.27_Nneg sample5-3.27_Nneg       1            1             E4
# sample5-4.28_Npos sample5-4.28_Npos       1            1             H4
# sample5-1.22_Npos sample5-1.22_Npos       1            1             B4
#                   primerFR_ID_byPlate primerFR_ID_total barcode_ID    PlotID
# sample5-1.22_Nneg                  25                25         25 1.22_Nneg
# sample5-2.29_Nneg                  27                27         27 2.29_Nneg
# sample5-4.28_Nneg                  31                31         31 4.28_Nneg
# sample5-3.27_Nneg                  29                29         29 3.27_Nneg
# sample5-4.28_Npos                  32                32         32 4.28_Npos
# sample5-1.22_Npos                  26                26         26 1.22_Npos
#                    Plant Plot Treatment Rep DAP Sampling    PlantSample  Type
# sample5-1.22_Nneg 75-062 1.22      Nneg   1  72  sample5 75-062_sample5 Maize
# sample5-2.29_Nneg 75-062 2.29      Nneg   2  72  sample5 75-062_sample5 Maize
# sample5-4.28_Nneg 75-062 4.28      Nneg   4  72  sample5 75-062_sample5 Maize
# sample5-3.27_Nneg 75-062 3.27      Nneg   3  72  sample5 75-062_sample5 Maize
# sample5-4.28_Npos 75-062 4.28      Npos   4  72  sample5 75-062_sample5 Maize
# sample5-1.22_Npos 75-062 1.22      Npos   1  72  sample5 75-062_sample5 Maize
#                   Grass_Broad Status Subfamily fwd_barcode rev_barcode
# sample5-1.22_Nneg     Monocot   Crop  Paniceae    ATCGTACG    CAGTGAGT
# sample5-2.29_Nneg     Monocot   Crop  Paniceae    TAGCGAGT    CAGTGAGT
# sample5-4.28_Nneg     Monocot   Crop  Paniceae    GGATATCT    CAGTGAGT
# sample5-3.27_Nneg     Monocot   Crop  Paniceae    TCATCGAG    CAGTGAGT
# sample5-4.28_Npos     Monocot   Crop  Paniceae    GACACCGT    CAGTGAGT
# sample5-1.22_Npos     Monocot   Crop  Paniceae    ACTATCTG    CAGTGAGT
#   [1] "sample5-1.22_Nneg" "sample5-2.29_Nneg" "sample5-4.28_Nneg"
#   [4] "sample5-3.27_Nneg" "sample5-4.28_Npos" "sample5-1.22_Npos"
#   [7] "sample5-3.27_Npos" "sample5-2.29_Npos" "sample3-4.18_Nneg"
#  [10] "sample3-1.20_Nneg" "sample3-2.19_Nneg" "sample3-3.30_Nneg"
#  [13] "sample3-1.20_Npos" "sample3-2.19_Npos" "sample3-3.30_Npos"
#  [16] "sample3-4.18_Npos" "sample2-2.08_Nneg" "sample2-3.05_Nneg"
#  [19] "sample2-1.08_Nneg" "sample2-4.25_Nneg" "sample2-2.08_Npos"
#  [22] "sample2-3.05_Npos" "sample2-1.08_Npos" "sample2-4.25_Npos"
#  [25] "sample6-2.26_Nneg" "sample6-3.18_Nneg" "sample6-4.30_Nneg"
#  [28] "sample6-1.12_Nneg" "sample6-4.30_Npos" "sample6-1.12_Npos"
#  [31] "sample6-3.18_Npos" "sample6-2.26_Npos" "sample6-1.15_Nneg"
#  [34] "sample6-4.17_Nneg" "sample6-2.16_Nneg" "sample6-3.01_Nneg"
#  [37] "sample6-3.01_Npos" "sample6-2.16_Npos" "sample6-4.17_Npos"
#  [40] "sample6-1.15_Npos" "sample4-4.27_Nneg" "sample4-1.06_Nneg"
#  [43] "sample2-1.06_Nneg" "sample6-3.07_Nneg" "sample5-3.07_Nneg"
#  [46] "sample4-3.07_Nneg" "sample4-2.05_Nneg" "sample2-4.27_Nneg"
#  [49] "sample1-2.05_Nneg" "sample5-4.27_Nneg" "sample1-3.07_Nneg"
#  [52] "sample2-2.05_Nneg" "sample3-2.05_Nneg" "sample1-4.27_Nneg"
#  [55] "sample6-1.06_Nneg" "sample6-4.27_Nneg" "sample5-1.06_Nneg"
#  [58] "sample3-4.27_Nneg" "sample5-2.05_Nneg" "sample3-3.07_Nneg"
#  [61] "sample6-2.05_Nneg" "sample2-3.07_Nneg" "sample7-1.06_Nneg"
#  [64] "sample3-1.06_Nneg" "sample8-2.05_Nneg" "sample8-3.07_Nneg"
#  [67] "sample7-3.07_Nneg" "sample8-1.06_Nneg" "sample7-2.05_Nneg"
#  [70] "sample8-4.27_Nneg" "sample1-1.06_Nneg" "sample7-4.27_Nneg"
#  [73] "sample2-1.06_Npos" "sample6-4.27_Npos" "sample6-3.07_Npos"
#  [76] "sample3-3.07_Npos" "sample1-4.27_Npos" "sample6-1.06_Npos"
#  [79] "sample5-4.27_Npos" "sample1-2.05_Npos" "sample5-1.06_Npos"
#  [82] "sample2-2.05_Npos" "sample2-4.27_Npos" "sample3-1.06_Npos"
#  [85] "sample4-3.07_Npos" "sample5-3.07_Npos" "sample3-2.05_Npos"
#  [88] "sample1-3.07_Npos" "sample4-2.05_Npos" "sample2-3.07_Npos"
#  [91] "sample8-4.27_Npos" "sample5-2.05_Npos" "sample4-4.27_Npos"
#  [94] "sample4-1.06_Npos" "sample6-2.05_Npos" "sample8-1.06_Npos"
#  [97] "sample7-2.05_Npos" "sample3-4.27_Npos" "sample1-1.06_Npos"
# [100] "sample7-3.07_Npos" "sample8-2.05_Npos" "sample8-3.07_Npos"
# [103] "sample7-1.06_Npos" "sample7-4.27_Npos" "sample2-2.10_Nneg"
# [106] "sample2-3.20_Nneg" "sample2-1.24_Nneg" "sample2-4.16_Nneg"
# [109] "sample2-3.20_Npos" "sample2-1.24_Npos" "sample2-4.16_Npos"
# [112] "sample2-2.10_Npos" "sample8-2.07_Nneg" "sample8-1.19_Nneg"
# [115] "sample8-4.01_Nneg" "sample8-3.03_Nneg" "sample8-3.03_Npos"
# [118] "sample8-1.19_Npos" "sample8-4.01_Npos" "sample8-2.07_Npos"
# [121] "sample5-3.11_Nneg" "sample5-4.06_Nneg" "sample5-2.18_Nneg"
# [124] "sample5-1.29_Nneg" "sample5-1.29_Npos" "sample5-3.11_Npos"
# [127] "sample5-4.06_Npos" "sample5-2.18_Npos" "sample1-2.23_Nneg"
# [130] "sample1-4.24_Nneg" "sample1-1.27_Nneg" "sample1-3.08_Nneg"
# [133] "sample1-3.08_Npos" "sample1-4.24_Npos" "sample1-1.27_Npos"
# [136] "sample1-2.23_Npos" "sample3-2.03_Nneg" "sample3-3.06_Nneg"
# [139] "sample3-4.15_Nneg" "sample3-1.09_Nneg" "sample3-3.06_Npos"
# [142] "sample3-1.09_Npos" "sample3-2.03_Npos" "sample3-4.15_Npos"
# [145] "sample5-2.11_Nneg" "sample5-4.05_Nneg" "sample5-3.16_Nneg"
# [148] "sample5-1.16_Nneg" "sample5-4.05_Npos" "sample5-2.11_Npos"
# [151] "sample5-3.16_Npos" "sample5-1.16_Npos" "sample7-2.12_Nneg"
# [154] "sample7-3.12_Nneg" "sample7-4.03_Nneg" "sample7-1.28_Nneg"
# [157] "sample7-4.03_Npos" "sample7-2.12_Npos" "sample7-1.28_Npos"
# [160] "sample7-3.12_Npos" "sample6-1.18_Nneg" "sample6-3.09_Nneg"
# [163] "sample6-4.13_Nneg" "sample6-2.14_Nneg" "sample6-4.13_Npos"
# [166] "sample6-1.18_Npos" "sample6-2.14_Npos" "sample6-3.09_Npos"
# [169] "sample5-1.25_Nneg" "sample5-3.17_Nneg" "sample5-4.09_Nneg"
# [172] "sample5-2.15_Nneg" "sample5-3.17_Npos" "sample5-4.09_Npos"
# [175] "sample5-1.25_Npos" "sample5-2.15_Npos" "sample8-4.23_Nneg"
# [178] "sample8-2.25_Nneg" "sample8-3.29_Nneg" "sample8-1.23_Nneg"
# [181] "sample8-4.23_Npos" "sample8-1.23_Npos" "sample8-3.29_Npos"
# [184] "sample8-2.25_Npos" "sample8-3.23_Nneg" "sample8-1.10_Nneg"
# [187] "sample8-2.17_Nneg" "sample8-4.04_Nneg" "sample8-2.17_Npos"
# [190] "sample8-1.10_Npos" "sample8-3.23_Npos" "sample8-4.04_Npos"
# [193] "sample5-2.06_Nneg" "sample5-3.13_Nneg" "sample5-1.17_Nneg"
# [196] "sample5-4.08_Nneg" "sample5-2.06_Npos" "sample5-4.08_Npos"
# [199] "sample5-1.17_Npos" "sample5-3.13_Npos" "sample6-2.13_Nneg"
# [202] "sample6-4.12_Nneg" "sample6-3.04_Nneg" "sample6-1.07_Nneg"
# [205] "sample6-4.12_Npos" "sample6-2.13_Npos" "sample6-3.04_Npos"
# [208] "sample6-1.07_Npos" "sample4-2.02_Nneg" "sample4-4.21_Nneg"
# [211] "sample4-1.03_Nneg" "sample4-3.10_Nneg" "sample4-1.03_Npos"
# [214] "sample4-4.21_Npos" "sample4-3.10_Npos" "sample4-2.02_Npos"
# [217] "sample7-3.19_Nneg" "sample7-1.13_Nneg" "sample7-2.30_Nneg"
# [220] "sample7-4.14_Nneg" "sample7-1.13_Npos" "sample7-2.30_Npos"
# [223] "sample7-3.19_Npos" "sample7-4.14_Npos" "sample7-4.02_Nneg"
# [226] "sample7-2.28_Nneg" "sample7-1.04_Nneg" "sample7-3.25_Nneg"
# [229] "sample7-4.02_Npos" "sample7-1.04_Npos" "sample7-3.25_Npos"
# [232] "sample7-2.28_Npos" "sample8-4.07_Nneg" "sample8-1.14_Nneg"
# [235] "sample8-2.22_Nneg" "sample8-3.28_Nneg" "sample8-1.14_Npos"
# [238] "sample8-3.28_Npos" "sample8-2.22_Npos" "sample8-4.07_Npos"

# %%
# %%R -w 600 -h 400
#
# pdf("sample_abundance.pdf", onefile = TRUE)
#
# N = nsamples(physeq.R)
#
# s.df = sample_data(physeq.R)
# s.df.o =  s.df[with(s.df, order(Plant, Treatment))]
# samples = sample_names(s.df.o)
#
#
# for(i in 1:N){
#     samplename = samples[i]
#     sample = subset_samples(physeq.R, X.sample == samplename)
#
#
#     TopOTUs = names(sort(taxa_sums(sample), TRUE)[1:50])
#     Top = prune_taxa(TopOTUs, sample)
#     title = paste(sample_data(Top)$Plant, samplename, sample_sums(Top20), sep = " ")
#     p1 = barplot(sort(taxa_sums(Top), TRUE), las=2,
#         main = title)
#     plots[[i]] = p1  # add each plot into plot list
# }
#
#
#
#
# dev.off()
# Out:
# png
#   2

# %%
# %%R -i workDir
#
# #pdf("sample_abundance.pdf", onefile = TRUE)
#
# N = nsamples(physeq.R)
#
# for(i in 1:1){
#     samplename = sample_names(physeq.R)[i]
#     sample = subset_samples(physeq.R, X.sample == samplename)
#
#
#     TopOTUs = names(sort(taxa_sums(sample), TRUE)[1:20])
#     Top20 = prune_taxa(TopOTUs, sample)
#     title = paste(sample_data(sample)$Plant, samplename, sample_sums(sample), sep = " ")
#     plot = plot_bar(Top20, "Rank4", fill = "Rank5", title = title)
#     print(plot)
# }
#
# #dev.off()

# %%
# %%R
# topNOTUs = names(sort(taxa_sums(physeq.R), TRUE)[1:20])
# Rhiz20 = prune_taxa(topNOTUs, physeq.R)
# print(Rhiz20)
# sample_variables(Rhiz20)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 20 taxa and 240 samples ]
# sample_data() Sample Data:       [ 240 samples by 21 sample variables ]
# tax_table()   Taxonomy Table:    [ 20 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 20 tips and 19 internal nodes ]
#  [1] "X.sample"            "Library"             "Primer_Plate"
#  [4] "Primer_Well_ID"      "primerFR_ID_byPlate" "primerFR_ID_total"
#  [7] "barcode_ID"          "PlotID"              "Plant"
# [10] "Plot"                "Treatment"           "Rep"
# [13] "DAP"                 "Sampling"            "PlantSample"
# [16] "Type"                "Grass_Broad"         "Status"
# [19] "Subfamily"           "fwd_barcode"         "rev_barcode"

# %% [markdown]
# ##Graph abundance by phylum

# %%
# %%R
# colnames(tax_table(physeq.R)) = c("Kingdom", "Phylum",  "Class",   "Order",
#                          "Family",  "Genus",   "Species", "Strain")

# %%
# %%R
# get_taxa_unique(physeq.R, "Phylum")
# Out:
#  [1] "__Acidobacteria"           "__Planctomycetes"
#  [3] "__Proteobacteria"          "__Candidate_division_WS3"
#  [5] "__NPL-UPA2"                "__Nitrospirae"
#  [7] "__Spirochaetes"            "__Verrucomicrobia"
#  [9] NA                          "__Lentisphaerae"
# [11] "__Chloroflexi"             "__Fibrobacteres"
# [13] "__Candidate_division_BRC1" "__Fusobacteria"
# [15] "__Firmicutes"              "__Deferribacteres"
# [17] "__Chlorobi"                "__Bacteroidetes"
# [19] "__GOUTA4"                  "__Elusimicrobia"
# [21] "__JL-ETNP-Z39"             "__Gemmatimonadetes"
# [23] "__Tenericutes"             "__Deinococcus-Thermus"
# [25] "__Armatimonadetes"         "__Cyanobacteria"
# [27] "__TA06"                    "__Thermotogae"
# [29] "__Actinobacteria"          "__BHI80-139"
# [31] "__WCHB1-60"                "__Candidate_division_TM7"
# [33] "__Candidate_division_OD1"  "__Candidate_division_SR1"
# [35] "__Kazan-3B-28"             "__BD1-5"
# [37] "__SM2F11"                  "__Candidate_division_OP11"
# [39] "__Chlamydiae"              "__TM6"
# [41] "__Candidate_division_OP3"

# %%
# %%R -w 600 -h 900
# Rhiz.f = subset_taxa(physeq.R, Phylum == "__Firmicutes")
# topNOTUs = names(sort(taxa_sums(Rhiz.f), TRUE)[1:20])
# Rhiz.ft = prune_taxa(topNOTUs, Rhiz.f)
# plot_tree(Rhiz.ft, color = "Plant", shape = "Family", label.tips = "Genus",
#           size = "abundance", plot.margin = 0.5, ladderize = TRUE)

# %%
# %%R -w 600 -h 900
# p1 = plot_bar(Rhiz.f, x="Plant", fill="Genus")
# p1

# %%
# %%R
# Rhiz.p = subset_taxa(physeq.R, Genus == "__Paenibacillus")
# plot_bar(Rhiz.p, x="Plant", fill="Species")

# %%
# %%R
# head(otu_table(Rhiz.p))
# Out:
# OTU Table:          [6 taxa and 240 samples]
#                      taxa are rows
#           sample2-1.06_Npos sample6-4.27_Npos sample4-4.27_Nneg
# OTU.6805                  0                 1                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  3                 9                 4
# OTU.9974                  0                 0                 0
# OTU.10507                 1                 0                 0
# OTU.12474                 0                 0                 0
#           sample4-1.06_Nneg sample2-1.06_Nneg sample6-3.07_Nneg
# OTU.6805                  2                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 4                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-3.07_Nneg sample6-3.07_Npos sample3-3.07_Npos
# OTU.6805                  1                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  4                 2                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 1                 0
# OTU.12474                 0                 0                 0
#           sample5-1.22_Nneg sample6-4.12_Npos sample1-4.27_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 3                 2
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample4-1.03_Npos sample5-2.06_Npos sample5-4.08_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 0                 3
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample4-3.07_Nneg sample5-4.28_Npos sample6-1.06_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 1
# OTU.1137                  3                 6                 2
# OTU.9974                  1                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample4-2.05_Nneg sample2-4.27_Nneg sample1-2.05_Nneg
# OTU.6805                  1                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  2                 2                 3
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-1.29_Npos sample5-4.27_Npos sample5-4.27_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  1                 5                 5
# OTU.9974                  0                 1                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample1-3.07_Nneg sample4-2.02_Nneg sample4-4.21_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  1                 0                 0
# OTU.1137                  4                 0                 0
# OTU.9974                  0                 0                 1
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample2-2.05_Nneg sample6-2.13_Npos sample5-2.29_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  3                 3                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-2.06_Nneg sample1-2.23_Nneg sample6-2.26_Nneg
# OTU.6805                  1                 0                 0
# OTU.4250                  2                 0                 0
# OTU.1137                  2                 0                 5
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample6-3.18_Nneg sample5-3.13_Nneg sample2-2.08_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  3                 5                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample1-2.05_Npos sample3-2.05_Nneg sample5-1.17_Nneg
# OTU.6805                  0                 0                 1
# OTU.4250                  0                 1                 1
# OTU.1137                  0                 1                 1
# OTU.9974                  0                 1                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample6-3.01_Npos sample3-2.03_Nneg sample5-4.08_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  1                 4                 9
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-4.05_Npos sample5-1.06_Npos sample1-4.27_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 2                 0
# OTU.1137                  4                 3                 3
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 1                 0
# OTU.12474                 0                 0                 0
#           sample6-2.16_Npos sample1-4.24_Nneg sample5-4.28_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  2                 3                 2
# OTU.9974                  1                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample6-2.13_Nneg sample1-3.08_Npos sample6-3.04_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 2                 0
# OTU.1137                  3                 5                 7
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample6-1.06_Nneg sample4-1.03_Nneg sample5-1.22_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  5                 0                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample6-1.15_Nneg sample2-2.05_Npos sample2-4.27_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 1                 0
# OTU.1137                  4                 2                 3
# OTU.9974                  0                 1                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-2.11_Nneg sample4-4.21_Npos sample6-4.12_Nneg
# OTU.6805                  1                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  2                 2                 4
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-1.25_Nneg sample6-4.17_Npos sample3-1.06_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  2                 0                 0
# OTU.1137                  0                64                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 2
#           sample6-3.04_Nneg sample5-3.27_Nneg sample6-1.15_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  7                 3                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-3.11_Nneg sample5-2.11_Npos sample4-3.07_Npos
# OTU.6805                  0                 2                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  3                 0                 2
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-3.17_Npos sample5-3.07_Npos sample5-1.17_Npos
# OTU.6805                  0                 0                 1
# OTU.4250                  0                 0                 0
# OTU.1137                 12                 0                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample3-3.06_Nneg sample3-2.05_Npos sample2-3.05_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  1                 0                 0
# OTU.1137                  7                 4                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 2                 0                 0
# OTU.12474                 0                 0                 0
#           sample6-4.27_Nneg sample6-1.07_Npos sample5-3.13_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 1
# OTU.1137                  2                13                 2
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-1.06_Nneg sample3-4.27_Nneg sample5-4.09_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  1                 2                17
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample6-4.30_Npos sample6-1.12_Npos sample6-3.18_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  9                 0                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 1                 0                 0
#           sample1-4.24_Npos sample3-3.06_Npos sample5-4.06_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                 17                 3                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 1                 0                 1
# OTU.12474                 0                 0                 0
#           sample6-4.17_Nneg sample5-3.11_Npos sample5-3.16_Npos
# OTU.6805                  2                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                 72                 1                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-2.05_Nneg sample3-3.07_Nneg sample1-1.27_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  1                 0                 0
# OTU.1137                  0                 2                16
# OTU.9974                  0                 0                 1
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-4.05_Nneg sample5-1.25_Npos sample6-1.07_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  1                 0                 0
# OTU.1137                  2                 6                 3
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-2.18_Nneg sample6-2.26_Npos sample6-2.05_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  3                 0                 0
# OTU.1137                  0                 7                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample2-3.07_Nneg sample5-3.16_Nneg sample5-4.06_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  1                 4                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample3-1.09_Npos sample3-4.15_Nneg sample1-3.07_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  7                 8                 2
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-2.15_Npos sample4-2.05_Npos sample6-4.30_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  1                 0                 0
# OTU.1137                 19                 3                 3
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-3.27_Npos sample2-3.07_Npos sample6-1.12_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  2                 2                 3
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample4-3.10_Npos sample6-2.16_Nneg sample5-3.17_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 1
# OTU.1137                  0                 2                16
# OTU.9974                  0                 1                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-1.16_Npos sample3-2.03_Npos sample1-2.23_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  1                 1                 0
# OTU.1137                  0                 2                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-4.09_Nneg sample2-2.08_Npos sample2-3.05_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 2                 0
# OTU.1137                  1                 2                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample2-1.08_Nneg sample3-4.15_Npos sample6-3.01_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 3                 1
# OTU.9974                  2                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-1.16_Nneg sample2-1.08_Npos sample1-1.27_Nneg
# OTU.6805                  1                 0                 0
# OTU.4250                  1                 0                 0
# OTU.1137                  2                 2                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample4-3.10_Nneg sample5-1.29_Nneg sample4-2.02_Npos
# OTU.6805                  1                 0                 0
# OTU.4250                  0                 2                 0
# OTU.1137                  4                 2                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample5-2.15_Nneg sample1-3.08_Nneg sample3-1.09_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                 18                 1                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample2-4.25_Nneg sample5-2.18_Npos sample5-2.29_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 1                 0
# OTU.1137                  0                 1                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample2-4.25_Npos sample7-1.13_Npos sample7-4.02_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 2                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-2.07_Nneg sample7-4.02_Nneg sample3-1.20_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 0                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-4.27_Npos sample5-2.05_Npos sample7-1.04_Npos
# OTU.6805                  0                 1                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 2                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-4.23_Nneg sample4-4.27_Npos sample7-3.19_Nneg
# OTU.6805                  0                 1                 0
# OTU.4250                  0                 2                 2
# OTU.1137                  0                 3                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample7-1.06_Nneg sample7-4.03_Npos sample8-1.14_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  2                 0                 5
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample7-2.12_Npos sample3-1.06_Nneg sample3-4.18_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 1                 0
# OTU.1137                  2                 3                 4
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-3.28_Npos sample6-1.18_Nneg sample7-2.12_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  8                 0                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample7-2.28_Nneg sample2-2.10_Nneg sample8-2.17_Npos
# OTU.6805                  0                 2                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  1                 0                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample3-2.19_Npos sample8-2.25_Nneg sample6-3.09_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 0                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-2.05_Nneg sample4-1.06_Npos sample2-3.20_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  2                 0                 1
# OTU.1137                  0                 2                 2
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample6-2.05_Npos sample2-3.20_Nneg sample8-3.07_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 1
# OTU.1137                  2                 1                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 1                 0                 0
#           sample3-3.30_Npos sample8-1.06_Npos sample8-4.23_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  3                 2                 3
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-3.03_Npos sample6-4.13_Npos sample8-4.07_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 1                24
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample6-1.18_Npos sample7-3.25_Npos sample8-3.23_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 2                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample7-2.30_Npos sample7-1.13_Nneg sample8-2.22_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 4                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample7-2.30_Nneg sample2-1.24_Npos sample7-3.07_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 1                 0
# OTU.1137                  0                 0                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample6-2.14_Npos sample8-1.14_Nneg sample3-1.20_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 1
# OTU.1137                  0                 9                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample2-4.16_Npos sample8-1.19_Npos sample7-2.28_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 1
# OTU.1137                  0                 0                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample7-3.19_Npos sample8-1.06_Nneg sample7-1.04_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  1                 2                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 1
#           sample8-1.19_Nneg sample7-3.12_Nneg sample7-4.03_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 2                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample7-1.28_Npos sample7-2.05_Nneg sample8-1.10_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  1                 2                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample7-1.28_Nneg sample7-3.25_Nneg sample7-2.05_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 1                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample2-1.24_Nneg sample8-1.10_Nneg sample8-4.01_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  2                 0                 0
# OTU.1137                  0                 0                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 1                 0                 0
# OTU.12474                 0                 0                 0
#           sample3-4.27_Npos sample7-4.14_Npos sample8-4.01_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  1                 0                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-2.17_Nneg sample6-3.09_Npos sample8-2.22_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  5                 0                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-3.29_Nneg sample1-1.06_Npos sample8-4.07_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 0                24
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-4.27_Nneg sample8-1.23_Npos sample7-3.07_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 0                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-3.28_Nneg sample2-2.10_Npos sample6-4.13_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  6                 0                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample3-2.19_Nneg sample2-4.16_Nneg sample7-3.12_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 1                 0
# OTU.1137                  2                 0                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-3.23_Npos sample8-2.05_Npos sample8-3.29_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 0                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-1.23_Nneg sample6-2.14_Nneg sample8-4.04_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 3                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-3.07_Npos sample3-3.30_Nneg sample7-4.14_Nneg
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 3                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample1-1.06_Nneg sample8-2.07_Npos sample3-4.18_Npos
# OTU.6805                  1                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  2                 0                 1
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample7-4.27_Nneg sample8-4.04_Npos sample8-2.25_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  0                 0                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
#           sample8-3.03_Nneg sample7-1.06_Npos sample7-4.27_Npos
# OTU.6805                  0                 0                 0
# OTU.4250                  0                 0                 0
# OTU.1137                  1                 0                 0
# OTU.9974                  0                 0                 0
# OTU.10507                 0                 0                 0
# OTU.12474                 0                 0                 0
